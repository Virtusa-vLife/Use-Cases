# %% [markdown]
# # vLife Virtusa

# %% [markdown]
# ## Drug Recommendation for Medical Practitioner Usecase
# ### Usecase Description
# ##### Help medical practitioners to prescribe recommended drugs based on their practicing specialty, years of practicing and previous suggested drugs in prescriptions by other providers or practitioners.Recommendation engine for Medical Practioner for recommeding suitable drugs based on their prescribing patterns.Solution is powerd by topic modelling algorithm LDA which recommends drugs based on practioner prescribing patterns

# %% [markdown]
# ### Data Source
# Data for this usecase can be found
# * [Source I](https://www.kaggle.com/tajuddinkh/drugs-prescriptions-with-providers)
# * [Source II](https://www.kaggle.com/roamresearch/prescriptionbasedprediction)

# %% [markdown]
# ### Dataset Description
# ##### You will find specialty is a doctor's or medical practitioners expertise and "years of practice" is the practice duration. each row is a provider's prescription where the drugs are suggested along with others relatively.
# ### Columns
# * Index incremental
# * specialtyMedical Practitioner's Expertise
# * years_practicingYears of experiences to the expertise
# * cms_prescription_countsprescribed medicines in association

# %% [markdown]
# #### Import Necessary Packages and Libraries

# %%
import numpy as np
import pandas as pd
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.tools as tls
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# %matplotlib inline

import pickle
import seaborn as sns
import sklearn.metrics.base
import warnings
from collections import Counter
from pandas.io.json import json_normalize

from scipy.sparse import csr_matrix
from sklearn.decomposition import LatentDirichletAllocation, PCA
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.model_selection import (StratifiedKFold, GridSearchCV, train_test_split,
                                     cross_val_predict)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('/kaggle/input/drugs-prescriptions-with-providers/medicine_prescription_records.csv',nrows=200).drop('Unnamed: 0',axis=1)
data.head()
# Out:
#           specialty  years_practicing  \
# 0        Nephrology                 7
# 1  General Practice                 7
# 2  General Practice                 7
# 3  General Practice                 7
# 4        Nephrology                 6
#
#                              cms_prescription_counts
# 0  DOXAZOSIN MESYLATE, MIDODRINE HCL, MEGESTROL A...
# 1  CEPHALEXIN, AMOXICILLIN, HYDROCODONE-ACETAMINO...
# 2           CEPHALEXIN, AMOXICILLIN, CLINDAMYCIN HCL
# 3                                        AMOXICILLIN
# 4  PIOGLITAZONE HCL, BENAZEPRIL HCL, DIAZEPAM, HY...

# %% [markdown]
# ## Data Wrangling
# ### Exploratory Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
# specialty                  200 non-null object
# years_practicing           200 non-null int64
# cms_prescription_counts    200 non-null object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
print("Dataset contains {} rows and {} columns".format(data.shape[0], data.shape[1]))
# Out:
# Dataset contains 200 rows and 3 columns

# %%
data[data['specialty'] == 'Nephrology']
# Out:
#      specialty  years_practicing  \
# 0   Nephrology                 7
# 4   Nephrology                 6
# 35  Nephrology                 6
# 45  Nephrology                 7
# 46  Nephrology                 8
#
#                               cms_prescription_counts
# 0   DOXAZOSIN MESYLATE, MIDODRINE HCL, MEGESTROL A...
# 4   PIOGLITAZONE HCL, BENAZEPRIL HCL, DIAZEPAM, HY...
# 35  CALCIUM ACETATE, NEXIUM, HYDRALAZINE HCL, SENS...
# 45  MIDODRINE HCL, BENAZEPRIL HCL, GABAPENTIN, MET...
# 46  CALCIUM ACETATE, AMLODIPINE BESYLATE, HYDRALAZ...

# %%
data.groupby("specialty")["years_practicing"].mean().sort_values(ascending=False)
# Out:
# specialty
# Sports Medicine                         8.000000
# Foot and Ankle Surgery                  8.000000
# Pain Medicine                           8.000000
# Cardiovascular Disease                  7.500000
# Pulmonary Disease                       7.250000
# Gastroenterology                        7.200000
# Women's Health                          7.000000
# Oral and Maxillofacial Surgery          7.000000
# Critical Care Medicine                  7.000000
# Gynecology                              7.000000
# Hematology                              7.000000
# Medical Oncology                        7.000000
# Neurology                               7.000000
# Acute Care                              7.000000
# Pediatric Cardiology                    7.000000
# Plastic and Reconstructive Surgery      7.000000
# Radiation Oncology                      7.000000
# Psych/Mental Health, Adult              7.000000
# Nephrology                              6.800000
# Endocrinology, Diabetes & Metabolism    6.750000
# Psychiatry                              6.692308
# General Practice                        6.545455
# Emergency Medical Services              6.500000
# Periodontics                            6.250000
# Medical                                 6.222222
# Hematology & Oncology                   6.166667
# Hospice and Palliative Medicine         6.000000
# Infectious Disease                      6.000000
# Foot Surgery                            6.000000
# Clinical Cardiac Electrophysiology      6.000000
# Hand Surgery                            6.000000
# Endodontics                             6.000000
# Psych/Mental Health                     5.800000
# Geriatric Medicine                      5.500000
# Family                                  4.625000
# Adult Health                            4.600000
# Foot & Ankle Surgery                    4.500000
# Child & Adolescent Psychiatry           4.500000
# Surgical Technologist                   4.500000
# Rheumatology                            1.000000
# Name: years_practicing, dtype: float64

# %%
for column in data.columns.values:
    print(f" Unique values of {column} : {data[column].nunique()}")
# Out:
#  Unique values of specialty : 40
#  Unique values of years_practicing : 8
#  Unique values of cms_prescription_counts : 183

# %%
def missing_data(data):
    total = data.isnull().sum()
    percent = (data.isnull().sum()/data.isnull().count()*100)
    tt = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    types = []
    for col in data.columns:
        dtype = str(data[col].dtype)
        types.append(dtype)
    tt['Types'] = types
    return(np.transpose(tt))
missing_data(data)
# Out:
#         specialty years_practicing cms_prescription_counts
# Total           0                0                       0
# Percent         0                0                       0
# Types      object            int64                  object

# %%
missing_df = data.isnull().sum(axis=0).reset_index()
missing_df.columns = ['column_name', 'missing_count']
missing_df['filling_factor'] = (data.shape[0] 
                                - missing_df['missing_count']) / data.shape[0] * 100
missing_df.sort_values('filling_factor').reset_index(drop = True)
# Out:
#                column_name  missing_count  filling_factor
# 0                specialty              0           100.0
# 1         years_practicing              0           100.0
# 2  cms_prescription_counts              0           100.0

# %%
plt.figure(figsize=(10,10))
counts = pd.Series(data.specialty).value_counts()[:50] 
plt.barh(counts.index, counts.values)
for i, v in enumerate(counts.values):
    plt.text(v, i, '{:.1f}%'.format(100 * v / data.specialty.shape[0]))

# %%
F=data['specialty'].value_counts().sort_values(ascending=False)[:15]
label=F.index
size=F.values
colors = ['skyblue', '#FEBFB3', '#96D38C', '#D0F9B1', 'gold', 'orange', 'lightgrey', 
          'lightblue','lightgreen','aqua','yellow','#D4E157','#D1C4E9','#1A237E','#64B5F6','#009688',
          '#1DE9B6','#66BB6A','#689F38','#FFB300']
trace =go.Pie(labels=label, values=size, marker=dict(colors=colors), hole=.1)
data_trace = [trace]
layout = go.Layout(title='Distribution of specialty')
fig=go.Figure(data=data_trace,layout=layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="f4c44676-77ee-46dc-8cc4-fa5028dd80f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f4c44676-77ee-46dc-8cc4-fa5028dd80f8")) {
#                     Plotly.newPlot(
#                         'f4c44676-77ee-46dc-8cc4-fa5028dd80f8',
#                         [{"hole": 0.1, "labels": ["General Practice", "Psychiatry", "Family", "Cardiovascular Disease", "Adult Health", "Gastroenterology", "Neurology", "Medical", "Pulmonary Disease", "Hematology & Oncology", "Infectious Disease", "Psych/Mental Health", "Nephrology", "Endocrinology, Diabetes & Metabolism", "Periodontics"], "marker": {"colors": ["skyblue", "#FEBFB3", "#96D38C", "#D0F9B1", "gold", "orange", "lightgrey", "lightblue", "lightgreen", "aqua", "yellow", "#D4E157", "#D1C4E9", "#1A237E", "#64B5F6", "#009688", "#1DE9B6", "#66BB6A", "#689F38", "#FFB300"]}, "type": "pie", "values": [33, 26, 24, 10, 10, 10, 9, 9, 8, 6, 5, 5, 5, 4, 4]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
condition_dn = data.groupby(['specialty'])['cms_prescription_counts'].nunique().sort_values(ascending=False)
condition_dn[0:20].plot(kind="bar", figsize = (14,6), fontsize = 10,color="blue")
plt.xlabel("", fontsize = 20)
plt.ylabel("", fontsize = 20)
plt.title("Top20 : The number of Speciality in terms of prescrptions.", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Top20 : The number of Speciality in terms of prescrptions.')

# %% [markdown]
# ## Building Recommendation Engine
# *  Market Basket Analysis - FP Growth
# *  Topic Modelling - LDA (Latent Dirichlet Allocation)

# %%
df = data.copy()
df = df.reset_index()
df = df[['index','cms_prescription_counts']]
display(df)
# Out:
#      index                            cms_prescription_counts
# 0        0  DOXAZOSIN MESYLATE, MIDODRINE HCL, MEGESTROL A...
# 1        1  CEPHALEXIN, AMOXICILLIN, HYDROCODONE-ACETAMINO...
# 2        2           CEPHALEXIN, AMOXICILLIN, CLINDAMYCIN HCL
# 3        3                                        AMOXICILLIN
# 4        4  PIOGLITAZONE HCL, BENAZEPRIL HCL, DIAZEPAM, HY...
# ..     ...                                                ...
# 195    195                                        AMOXICILLIN
# 196    196  SIMVASTATIN, INSULIN SYRINGE, FAMOTIDINE, KLOR...
# 197    197  SERTRALINE HCL, ESCITALOPRAM OXALATE, NAMENDA,...
# 198    198  SIMVASTATIN, XARELTO, HYDRALAZINE HCL, TOPROL ...
# 199    199  CLONAZEPAM, TRIHEXYPHENIDYL HCL, PERPHENAZINE,...
#
# [200 rows x 2 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
def process(df):
    df.columns = ['trans', 'item']
#   df.trans = df.trans.sample(n=20000, random_state=1)
#   df.item = df.item.sample(n=20000, random_state=1)
#   df.trans = pd.to_numeric(df.trans, errors='coerce')
#   df.trans = df.trans.astype(int)
    df.item = df.item.apply(lambda x: str(x).split(','))
    df = df.groupby('trans').agg(lambda x: x)
    return df

df = process(df)
display(df)
# Out:
#                                                     item
# trans
# 0      [DOXAZOSIN MESYLATE,  MIDODRINE HCL,  MEGESTRO...
# 1      [CEPHALEXIN,  AMOXICILLIN,  HYDROCODONE-ACETAM...
# 2           [CEPHALEXIN,  AMOXICILLIN,  CLINDAMYCIN HCL]
# 3                                          [AMOXICILLIN]
# 4      [PIOGLITAZONE HCL,  BENAZEPRIL HCL,  DIAZEPAM,...
# ...                                                  ...
# 195                                        [AMOXICILLIN]
# 196    [SIMVASTATIN,  INSULIN SYRINGE,  FAMOTIDINE,  ...
# 197    [SERTRALINE HCL,  ESCITALOPRAM OXALATE,  NAMEN...
# 198    [SIMVASTATIN,  XARELTO,  HYDRALAZINE HCL,  TOP...
# 199    [CLONAZEPAM,  TRIHEXYPHENIDYL HCL,  PERPHENAZI...
#
# [200 rows x 1 columns]

# %%
print(df['item'][0])
# Out:
# ['DOXAZOSIN MESYLATE', ' MIDODRINE HCL', ' MEGESTROL ACETATE', ' BENAZEPRIL HCL', ' METOLAZONE', ' NOVOLOG', ' DIAZEPAM', ' HYDRALAZINE HCL', ' SENSIPAR', ' LABETALOL HCL', ' PREDNISONE', ' CALCITRIOL', ' HYDROCODONE-ACETAMINOPHEN', ' HYDROCHLOROTHIAZIDE', ' LOSARTAN-HYDROCHLOROTHIAZIDE', ' FENOFIBRATE', ' MINOXIDIL', ' MELOXICAM', ' ATENOLOL', ' CARISOPRODOL', ' GABAPENTIN', ' OMEPRAZOLE', ' KLOR-CON M10', ' LANTUS', ' AMLODIPINE BESYLATE', ' CARVEDILOL', ' LOSARTAN POTASSIUM', ' IRBESARTAN', ' NIFEDICAL XL', ' NIFEDIPINE ER', ' LEVOTHYROXINE SODIUM', ' POTASSIUM CHLORIDE', ' FUROSEMIDE', ' GLYBURIDE', ' CLONIDINE HCL', ' TEMAZEPAM', ' SPIRONOLACTONE', ' LOVASTATIN', ' LISINOPRIL', ' PANTOPRAZOLE SODIUM', ' CALCIUM ACETATE', ' NEXIUM', ' ZOLPIDEM TARTRATE', ' DIOVAN', ' OXYCODONE HCL', ' METOPROLOL SUCCINATE', ' RANITIDINE HCL', ' ATORVASTATIN CALCIUM', ' TAMSULOSIN HCL', ' OXYBUTYNIN CHLORIDE', ' LISINOPRIL-HYDROCHLOROTHIAZIDE', ' METOPROLOL TARTRATE', ' AMLODIPINE BESYLATE-BENAZEPRIL', ' BUMETANIDE', ' BYSTOLIC', ' ISOSORBIDE MONONITRATE ER', ' ALLOPURINOL', ' CLOPIDOGREL', ' RENVELA', ' ABILIFY', ' SERTRALINE HCL', ' CIPROFLOXACIN HCL', ' SIMVASTATIN', ' PRAVASTATIN SODIUM', ' ATENOLOL-CHLORTHALIDONE', ' ALPRAZOLAM', ' AZITHROMYCIN', ' TRAMADOL HCL']

# %% [markdown]
# ### FP Growth Algorithm

# %% [markdown]
# * Variables:
#  - name of the node, a count
#  - nodelink used to link similar items
#  - parent vaiable used to refer to the parent of the node in the tree
#  - node contains an empty dictionary for the children in the node

# %%
class treeNode:
    def __init__(self, nameValue, numOccur, parentNode):
        self.name = nameValue
        self.count = numOccur
        self.nodeLink = None
        self.parent = parentNode      #needs to be updated
        self.children = {} 
#increments the count variable with a given amount    
    def inc(self, numOccur):
        self.count += numOccur
#display tree in text. Useful for debugging        
    def disp(self, ind=1):
        print ('  '*ind, self.name, ' ', self.count)
        for child in self.children.values():
            child.disp(ind+1)

# %%
rootNode = treeNode('pyramid',9,None)

# %%
rootNode.children['eye'] = treeNode('eye',13,None)

# %%
rootNode.disp()
# Out:
#    pyramid   9
#      eye   13

# %% [markdown]
# ### Constructing FP Tree

# %% [markdown]
# >#### Helper function for FP Tree Algorithm

# %%
def createTree(dataSet, minSup=1): #create FP-tree from dataset but don't mine
    headerTable = {}
    #go over dataSet twice
    for trans in dataSet:#first pass counts frequency of occurance
        for item in trans:
            headerTable[item] = headerTable.get(item, 0) + dataSet[trans]
    for k in list(headerTable):  #remove items not meeting minSup
        if headerTable[k] < minSup: 
            del(headerTable[k])
    freqItemSet = set(headerTable.keys())
    #print 'freqItemSet: ',freqItemSet
    if len(freqItemSet) == 0: return None, None  #if no items meet min support -->get out
    for k in headerTable:
        headerTable[k] = [headerTable[k], None] #reformat headerTable to use Node link 
    #print 'headerTable: ',headerTable
    retTree = treeNode('Null Set', 1, None) #create tree
    for tranSet, count in dataSet.items():  #go through dataset 2nd time
        localD = {}
        for item in tranSet:  #put transaction items in order
            if item in freqItemSet:
                localD[item] = headerTable[item][0]
        if len(localD) > 0:
            orderedItems = [v[0] for v in sorted(localD.items(), key=lambda p: p[1], reverse=True)]
            updateTree(orderedItems, retTree, headerTable, count)#populate tree with ordered freq itemset
    return retTree, headerTable #return tree and header table

# %%
def updateTree(items, inTree, headerTable, count):
    if items[0] in inTree.children:#check if orderedItems[0] in retTree.children
        inTree.children[items[0]].inc(count) #incrament count
    else:   #add items[0] to inTree.children
        inTree.children[items[0]] = treeNode(items[0], count, inTree)
        if headerTable[items[0]][1] == None: #update header table 
            headerTable[items[0]][1] = inTree.children[items[0]]
        else:
            updateHeader(headerTable[items[0]][1], inTree.children[items[0]])
    if len(items) > 1:#call updateTree() with remaining ordered items
        updateTree(items[1::], inTree.children[items[0]], headerTable, count)

# %%
def updateHeader(nodeToTest, targetNode):   #this version does not use recursion
    while (nodeToTest.nodeLink != None):    #Do not use recursion to traverse a linked list!
        nodeToTest = nodeToTest.nodeLink
    nodeToTest.nodeLink = targetNode

# %%
def loadSimpDat():
    simpDat =train
    return simpDat

# %%
def createInitSet(dataSet):
    retDict = {}
    for trans in dataSet:
        retDict[frozenset(trans)] = 1
    return retDict

# %%
simpDat = loadSimpDat()
simpDat
# Out:
# [['DOXAZOSIN MESYLATE',
#   ' MIDODRINE HCL',
#   ' MEGESTROL ACETATE',
#   ' BENAZEPRIL HCL',
#   ' METOLAZONE',
#   ' NOVOLOG',
#   ' DIAZEPAM',
#   ' HYDRALAZINE HCL',
#   ' SENSIPAR',
#   ' LABETALOL HCL',
#   ' PREDNISONE',
#   ' CALCITRIOL',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' FENOFIBRATE',
#   ' MINOXIDIL',
#   ' MELOXICAM',
#   ' ATENOLOL',
#   ' CARISOPRODOL',
#   ' GABAPENTIN',
#   ' OMEPRAZOLE',
#   ' KLOR-CON M10',
#   ' LANTUS',
#   ' AMLODIPINE BESYLATE',
#   ' CARVEDILOL',
#   ' LOSARTAN POTASSIUM',
#   ' IRBESARTAN',
#   ' NIFEDICAL XL',
#   ' NIFEDIPINE ER',
#   ' LEVOTHYROXINE SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' FUROSEMIDE',
#   ' GLYBURIDE',
#   ' CLONIDINE HCL',
#   ' TEMAZEPAM',
#   ' SPIRONOLACTONE',
#   ' LOVASTATIN',
#   ' LISINOPRIL',
#   ' PANTOPRAZOLE SODIUM',
#   ' CALCIUM ACETATE',
#   ' NEXIUM',
#   ' ZOLPIDEM TARTRATE',
#   ' DIOVAN',
#   ' OXYCODONE HCL',
#   ' METOPROLOL SUCCINATE',
#   ' RANITIDINE HCL',
#   ' ATORVASTATIN CALCIUM',
#   ' TAMSULOSIN HCL',
#   ' OXYBUTYNIN CHLORIDE',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' METOPROLOL TARTRATE',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' BUMETANIDE',
#   ' BYSTOLIC',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' ALLOPURINOL',
#   ' CLOPIDOGREL',
#   ' RENVELA',
#   ' ABILIFY',
#   ' SERTRALINE HCL',
#   ' CIPROFLOXACIN HCL',
#   ' SIMVASTATIN',
#   ' PRAVASTATIN SODIUM',
#   ' ATENOLOL-CHLORTHALIDONE',
#   ' ALPRAZOLAM',
#   ' AZITHROMYCIN',
#   ' TRAMADOL HCL'],
#  ['CEPHALEXIN', ' AMOXICILLIN', ' HYDROCODONE-ACETAMINOPHEN'],
#  ['CEPHALEXIN', ' AMOXICILLIN', ' CLINDAMYCIN HCL'],
#  ['AMOXICILLIN'],
#  ['PIOGLITAZONE HCL',
#   ' BENAZEPRIL HCL',
#   ' DIAZEPAM',
#   ' HYDRALAZINE HCL',
#   ' SENSIPAR',
#   ' WARFARIN SODIUM',
#   ' ESCITALOPRAM OXALATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' NOVOLIN N',
#   ' METFORMIN HCL',
#   ' FOSRENOL',
#   ' GLIPIZIDE',
#   ' OMEPRAZOLE',
#   ' METOPROLOL TARTRATE',
#   ' QUETIAPINE FUMARATE',
#   ' AMLODIPINE BESYLATE',
#   ' CHLORTHALIDONE',
#   ' SIMVASTATIN',
#   ' LOSARTAN POTASSIUM',
#   ' LABETALOL HCL',
#   ' NIFEDIPINE ER',
#   ' PRANDIN',
#   ' PANTOPRAZOLE SODIUM',
#   ' SYNTHROID',
#   ' ENALAPRIL MALEATE',
#   ' NORTRIPTYLINE HCL',
#   ' CLONIDINE HCL',
#   ' LISINOPRIL',
#   ' LEVOTHYROXINE SODIUM',
#   ' INDERAL LA',
#   ' NEXIUM',
#   ' AMOXICILLIN',
#   ' ACTONEL',
#   ' METHYLPHENIDATE HCL',
#   ' ANDROGEL',
#   ' RANITIDINE HCL',
#   ' ATORVASTATIN CALCIUM',
#   ' BUPROPION HCL',
#   ' DIPHENOXYLATE-ATROPINE',
#   ' CRESTOR',
#   ' ZOLPIDEM TARTRATE',
#   ' ALLOPURINOL',
#   ' LORAZEPAM',
#   ' CLOPIDOGREL',
#   ' RENVELA',
#   ' DONEPEZIL HCL',
#   ' GABAPENTIN',
#   ' ESTRADIOL',
#   ' ATENOLOL',
#   ' PRAVASTATIN SODIUM',
#   ' HYDROXYZINE HCL',
#   ' FLUTICASONE PROPIONATE',
#   ' CALCITONIN-SALMON'],
#  ['AMOXICILLIN',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' CLINDAMYCIN HCL',
#   ' PENICILLIN V POTASSIUM'],
#  ['AMOXICILLIN', ' CLINDAMYCIN HCL', ' IBUPROFEN'],
#  ['CEPHALEXIN'],
#  ['CARAFATE',
#   ' CARBIDOPA-LEVODOPA',
#   ' PREVACID',
#   ' SIMVASTATIN',
#   ' FAMOTIDINE',
#   ' NOVOLOG',
#   ' MORPHINE SULFATE',
#   ' LEVETIRACETAM',
#   ' WARFARIN SODIUM',
#   ' ESCITALOPRAM OXALATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' PREDNISONE',
#   ' ERYTHROMYCIN',
#   ' LATANOPROST',
#   ' METFORMIN HCL',
#   ' LIDOCAINE',
#   ' DIVALPROEX SODIUM',
#   ' CLONAZEPAM',
#   ' VOLTAREN',
#   ' GLIPIZIDE',
#   ' OMEPRAZOLE',
#   ' METOPROLOL TARTRATE',
#   ' QUETIAPINE FUMARATE',
#   ' AMLODIPINE BESYLATE',
#   ' ENALAPRIL MALEATE',
#   ' ENULOSE',
#   ' BUDESONIDE',
#   ' FENTANYL',
#   ' LANTUS',
#   ' DILTIAZEM 24HR CD',
#   ' LEVOTHYROXINE SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' ALBUTEROL SULFATE',
#   ' RANEXA',
#   ' METOPROLOL SUCCINATE',
#   ' POLYETHYLENE GLYCOL 3350',
#   ' DONEPEZIL HCL',
#   ' LISINOPRIL',
#   ' PROTONIX',
#   ' CEPHALEXIN',
#   ' TRIAMCINOLONE ACETONIDE',
#   ' ATORVASTATIN CALCIUM',
#   ' XARELTO',
#   ' CIPROFLOXACIN HCL',
#   ' OXYCODONE HCL',
#   ' ENTACAPONE',
#   ' TAMSULOSIN HCL',
#   ' TRAVATAN Z',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' NYSTATIN',
#   ' GABAPENTIN',
#   ' LEVEMIR',
#   ' IBUPROFEN',
#   ' LEVOFLOXACIN',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' LIDODERM',
#   ' FUROSEMIDE',
#   ' LORAZEPAM',
#   ' LOSARTAN POTASSIUM',
#   ' SPIRONOLACTONE',
#   ' RISPERIDONE',
#   ' AMOX TR-POTASSIUM CLAVULANATE',
#   ' SPIRIVA',
#   ' IPRATROPIUM-ALBUTEROL',
#   ' SERTRALINE HCL',
#   ' DIGOX',
#   ' ADVAIR DISKUS',
#   ' PRAVASTATIN SODIUM',
#   ' PROPRANOLOL HCL',
#   ' CLOPIDOGREL',
#   ' AZITHROMYCIN',
#   ' FLUTICASONE PROPIONATE',
#   ' MONTELUKAST SODIUM'],
#  ['AMOXICILLIN'],
#  ['CYMBALTA',
#   ' RISPERIDONE',
#   ' ZOLPIDEM TARTRATE',
#   ' BUPROPION HCL SR',
#   ' CLONAZEPAM'],
#  ['AMOXICILLIN', ' HYDROCODONE BIT-IBUPROFEN', ' CHLORHEXIDINE GLUCONATE'],
#  ['GABAPENTIN',
#   ' ALLOPURINOL',
#   ' HUMIRA',
#   ' SULFAZINE',
#   ' METHOTREXATE',
#   ' HYDROXYCHLOROQUINE SULFATE',
#   ' PREDNISONE',
#   ' AZATHIOPRINE'],
#  ['AMOXICILLIN', ' IBUPROFEN'],
#  ['CARAFATE',
#   ' OMEPRAZOLE',
#   ' HUMIRA',
#   ' NEXIUM',
#   ' SUPREP',
#   ' SUCRALFATE',
#   ' ASACOL',
#   ' RANITIDINE HCL',
#   ' COLESTIPOL HCL',
#   ' DELZICOL',
#   ' PANTOPRAZOLE SODIUM',
#   ' LACTULOSE',
#   ' METOLAZONE',
#   ' LANSOPRAZOLE'],
#  ['ZOLPIDEM TARTRATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' NEOMYCIN-POLYMYXIN-DEXAMETH',
#   ' BETAMETHASONE DIPROPIONATE',
#   ' PROMETHEGAN',
#   ' POLYETHYLENE GLYCOL 3350',
#   ' ALPRAZOLAM'],
#  ['CLONAZEPAM',
#   ' TRIHEXYPHENIDYL HCL',
#   ' DIAZEPAM',
#   ' LATUDA',
#   ' ESCITALOPRAM OXALATE',
#   ' FLUPHENAZINE HCL',
#   ' ZIPRASIDONE HCL',
#   ' DEXTROAMPHETAMINE SULFATE',
#   ' BUSPIRONE HCL',
#   ' CLOZAPINE',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' VIIBRYD',
#   ' DONEPEZIL HCL',
#   ' NORTRIPTYLINE HCL',
#   ' LITHIUM CARBONATE',
#   ' ABILIFY',
#   ' FLUVOXAMINE MALEATE',
#   ' HYDROXYZINE PAMOATE',
#   ' FLUOXETINE HCL',
#   ' RISPERIDONE ODT',
#   ' SEROQUEL XR',
#   ' PAROXETINE HCL',
#   ' AMPHETAMINE SALT COMBO',
#   ' MIRTAZAPINE',
#   ' METHYLPHENIDATE HCL',
#   ' THIOTHIXENE',
#   ' CYMBALTA',
#   ' RISPERDAL CONSTA',
#   ' PRISTIQ ER',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' DOXEPIN HCL',
#   ' SEROQUEL',
#   ' LORAZEPAM',
#   ' RISPERIDONE',
#   ' BUPROPION HCL',
#   ' SERTRALINE HCL',
#   ' BUPROPION XL',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' VENLAFAXINE HCL',
#   ' HYDROXYZINE HCL',
#   ' ALPRAZOLAM',
#   ' STRATTERA',
#   ' LAMOTRIGINE',
#   ' INVEGA SUSTENNA',
#   ' METHYLPHENIDATE ER',
#   ' TOPIRAMATE'],
#  ['OMEPRAZOLE',
#   ' TARGRETIN',
#   ' LEVOTHYROXINE SODIUM',
#   ' OXYCODONE HCL',
#   ' PREDNISONE'],
#  ['LEVOFLOXACIN',
#   ' OMEPRAZOLE',
#   ' REVLIMID',
#   ' DEXAMETHASONE',
#   ' LORAZEPAM',
#   ' PROCHLORPERAZINE MALEATE',
#   ' GABAPENTIN',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' METOCLOPRAMIDE HCL',
#   ' HYDROMORPHONE HCL',
#   ' ACYCLOVIR',
#   ' METOPROLOL TARTRATE',
#   ' ZOLPIDEM TARTRATE',
#   ' ONDANSETRON HCL'],
#  ['DESIPRAMINE HCL',
#   ' RISPERIDONE',
#   ' CLONAZEPAM',
#   ' PERPHENAZINE',
#   ' DIAZEPAM',
#   ' GABAPENTIN',
#   ' ESCITALOPRAM OXALATE',
#   ' FLUPHENAZINE HCL',
#   ' FLUOXETINE HCL',
#   ' ZIPRASIDONE HCL',
#   ' CLOMIPRAMINE HCL',
#   ' DIVALPROEX SODIUM',
#   ' CLOZAPINE',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' CLORAZEPATE DIPOTASSIUM',
#   ' VIIBRYD',
#   ' TRIAZOLAM',
#   ' NORTRIPTYLINE HCL',
#   ' LITHIUM CARBONATE',
#   ' ABILIFY',
#   ' FLUVOXAMINE MALEATE',
#   ' BUSPIRONE HCL',
#   ' AMPHETAMINE SALT COMBO',
#   ' CARBAMAZEPINE XR',
#   ' PAROXETINE HCL',
#   ' DEXTROAMPHETAMINE-AMPHETAMINE',
#   ' MIRTAZAPINE',
#   ' METHYLPHENIDATE HCL',
#   ' THIOTHIXENE',
#   ' CYMBALTA',
#   ' PRISTIQ ER',
#   ' AMOXAPINE',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' TEMAZEPAM',
#   ' MAPROTILINE HCL',
#   ' NEFAZODONE HCL',
#   ' LORAZEPAM',
#   ' OXCARBAZEPINE',
#   ' DONEPEZIL HCL',
#   ' SERTRALINE HCL',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' PROPRANOLOL HCL',
#   ' ALPRAZOLAM',
#   ' LAMOTRIGINE',
#   ' METHYLPHENIDATE ER',
#   ' FLURAZEPAM HCL',
#   ' TOPIRAMATE'],
#  ['CLONAZEPAM',
#   ' ENALAPRIL MALEATE',
#   ' SOTALOL AF',
#   ' KLOR-CON M20',
#   ' NAPROXEN',
#   ' ATORVASTATIN CALCIUM',
#   ' HYDROCHLOROTHIAZIDE',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' MINOXIDIL',
#   ' CITALOPRAM HBR',
#   ' OMEPRAZOLE',
#   ' METOPROLOL TARTRATE',
#   ' AMLODIPINE BESYLATE',
#   ' CARVEDILOL',
#   ' LOSARTAN POTASSIUM',
#   ' DILTIAZEM HCL',
#   ' LABETALOL HCL',
#   ' ZETIA',
#   ' NIFEDIPINE ER',
#   ' RAMIPRIL',
#   ' LEVOTHYROXINE SODIUM',
#   ' TRIAMTERENE-HCTZ',
#   ' FUROSEMIDE',
#   ' CLONIDINE HCL',
#   ' SPIRONOLACTONE',
#   ' NITROSTAT',
#   ' LISINOPRIL',
#   ' PANTOPRAZOLE SODIUM',
#   ' WARFARIN SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' XARELTO',
#   ' ZOLPIDEM TARTRATE',
#   ' PRADAXA',
#   ' TRIAMTERENE-HYDROCHLOROTHIAZID',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' CRESTOR',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' METOPROLOL SUCCINATE',
#   ' GUANFACINE HCL',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' ALLOPURINOL',
#   ' AMIODARONE HCL',
#   ' SOTALOL',
#   ' VYTORIN',
#   ' GABAPENTIN',
#   ' DIGOX',
#   ' SIMVASTATIN',
#   ' CLOPIDOGREL',
#   ' DIGOXIN'],
#  ['DIOVAN'],
#  ['HYDROXYZINE PAMOATE',
#   ' RISPERIDONE',
#   ' CLONAZEPAM',
#   ' SEROQUEL XR',
#   ' DIAZEPAM',
#   ' PAROXETINE HCL',
#   ' AMPHETAMINE SALT COMBO',
#   ' MIRTAZAPINE',
#   ' METHYLPHENIDATE HCL',
#   ' ESCITALOPRAM OXALATE',
#   ' CYMBALTA',
#   ' FLUOXETINE HCL',
#   ' RISPERDAL CONSTA',
#   ' ZIPRASIDONE HCL',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' GABAPENTIN',
#   ' BUSPIRONE HCL',
#   ' LORAZEPAM',
#   ' AMITRIPTYLINE HCL',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' FLUPHENAZINE HCL',
#   ' SERTRALINE HCL',
#   ' BUPROPION XL',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' ALPRAZOLAM',
#   ' LITHIUM CARBONATE',
#   ' LAMOTRIGINE',
#   ' ABILIFY',
#   ' LATUDA'],
#  ['PROVENTIL HFA',
#   ' ADVAIR DISKUS',
#   ' VENTOLIN HFA',
#   ' FLOVENT HFA',
#   ' NEXIUM',
#   ' LEVEMIR FLEXPEN',
#   ' DALIRESP',
#   ' QVAR',
#   ' PRAMIPEXOLE DIHYDROCHLORIDE',
#   ' LANTUS SOLOSTAR',
#   ' COMBIVENT RESPIMAT',
#   ' HUMALOG',
#   ' NASONEX',
#   ' NOVOLOG FLEXPEN',
#   ' ROPINIROLE HCL',
#   ' ALPRAZOLAM',
#   ' METFORMIN HCL',
#   ' BD ULTRA-FINE PEN NEEDLE',
#   ' ZOLPIDEM TARTRATE',
#   ' PROAIR HFA',
#   ' CLONAZEPAM',
#   ' JANUVIA',
#   ' FORADIL',
#   ' DIOVAN',
#   ' TRAZODONE HCL',
#   ' DULERA',
#   ' TUDORZA PRESSAIR',
#   ' ASMANEX',
#   ' SPIRIVA',
#   ' PREDNISONE',
#   ' GABAPENTIN',
#   ' TRADJENTA',
#   ' SIMVASTATIN',
#   ' DYMISTA',
#   ' LEVOTHYROXINE SODIUM',
#   ' SYNTHROID',
#   ' FUROSEMIDE',
#   ' AZITHROMYCIN',
#   ' SYMBICORT',
#   ' FLUTICASONE PROPIONATE',
#   ' COMBIVENT',
#   ' MONTELUKAST SODIUM'],
#  ['FLUOXETINE HCL',
#   ' BUPROPION HCL SR',
#   ' METHADONE HCL',
#   ' CLONAZEPAM',
#   ' RISPERIDONE',
#   ' METHYLPHENIDATE ER',
#   ' FENTANYL',
#   ' SERTRALINE HCL',
#   ' BUPROPION XL',
#   ' VALIUM',
#   ' PRISTIQ ER',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' INDERAL LA',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' LAMOTRIGINE',
#   ' ALPRAZOLAM'],
#  ['LEVOFLOXACIN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' MENTAX',
#   ' METFORMIN HCL',
#   ' AMMONIUM LACTATE',
#   ' PRAVASTATIN SODIUM'],
#  ['RISPERIDONE',
#   ' CLONAZEPAM',
#   ' TRIHEXYPHENIDYL HCL',
#   ' PERPHENAZINE',
#   ' DIAZEPAM',
#   ' ESCITALOPRAM OXALATE',
#   ' FLUPHENAZINE HCL',
#   ' PRAZOSIN HCL',
#   ' RISPERDAL CONSTA',
#   ' ZIPRASIDONE HCL',
#   ' CARBAMAZEPINE',
#   ' GABAPENTIN',
#   ' DIVALPROEX SODIUM',
#   ' CLOZAPINE',
#   ' AMITRIPTYLINE HCL',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' LEVOTHYROXINE SODIUM',
#   ' LITHIUM CARBONATE',
#   ' DOXEPIN HCL',
#   ' ABILIFY',
#   ' PROPRANOLOL HCL',
#   ' BUSPIRONE HCL',
#   ' HYDROXYZINE PAMOATE',
#   ' FLUOXETINE HCL',
#   ' CARBAMAZEPINE XR',
#   ' PAROXETINE HCL',
#   ' MIRTAZAPINE',
#   ' THIOTHIXENE',
#   ' CYMBALTA',
#   ' INVEGA',
#   ' STRATTERA',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' TEMAZEPAM',
#   ' LORAZEPAM',
#   ' OXCARBAZEPINE',
#   ' BUPROPION HCL',
#   ' SERTRALINE HCL',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' FLUVOXAMINE MALEATE',
#   ' HYDROXYZINE HCL',
#   ' ALPRAZOLAM',
#   ' VALPROIC ACID',
#   ' LAMOTRIGINE',
#   ' INVEGA SUSTENNA'],
#  ['AMOXICILLIN'],
#  ['VENTOLIN HFA',
#   ' FLOVENT HFA',
#   ' ATROVENT HFA',
#   ' FLOVENT DISKUS',
#   ' QVAR',
#   ' OMEPRAZOLE',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' PROAIR HFA',
#   ' METHYLPREDNISOLONE',
#   ' FLUTICASONE PROPIONATE',
#   ' TEMAZEPAM',
#   ' LEVOFLOXACIN',
#   ' CEFUROXIME',
#   ' NASONEX',
#   ' SPIRIVA',
#   ' PREDNISONE',
#   ' SINGULAIR',
#   ' ADVAIR DISKUS',
#   ' SYMBICORT',
#   ' PANTOPRAZOLE SODIUM',
#   ' AZITHROMYCIN',
#   ' PULMICORT FLEXHALER',
#   ' AZELASTINE HCL',
#   ' MONTELUKAST SODIUM'],
#  ['LEVOFLOXACIN',
#   ' SANTYL',
#   ' NAMENDA',
#   ' FAMOTIDINE',
#   ' PREZISTA',
#   ' AMOX TR-POTASSIUM CLAVULANATE',
#   ' BUDESONIDE',
#   ' IPRATROPIUM-ALBUTEROL',
#   ' NORVIR',
#   ' DOXYCYCLINE HYCLATE',
#   ' ISENTRESS',
#   ' KALETRA',
#   ' TRUVADA',
#   ' VANCOMYCIN HCL'],
#  ['TRIFLUOPERAZINE HCL',
#   ' CLONAZEPAM',
#   ' DIAZEPAM',
#   ' ESCITALOPRAM OXALATE',
#   ' FLUPHENAZINE HCL',
#   ' OLANZAPINE ODT',
#   ' HALOPERIDOL DECANOATE',
#   ' SERTRALINE HCL',
#   ' DIVALPROEX SODIUM',
#   ' CLOZAPINE',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' LUNESTA',
#   ' LITHIUM CARBONATE',
#   ' EFFEXOR XR',
#   ' ABILIFY',
#   ' PROPRANOLOL HCL',
#   ' THIORIDAZINE HCL',
#   ' BUSPIRONE HCL',
#   ' HYDROXYZINE PAMOATE',
#   ' FLUOXETINE HCL',
#   ' PAROXETINE HCL',
#   ' MIRTAZAPINE',
#   ' THIOTHIXENE',
#   ' CYMBALTA',
#   ' RISPERDAL CONSTA',
#   ' PRISTIQ ER',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' DIVALPROEX SODIUM ER',
#   ' LORAZEPAM',
#   ' FLUPHENAZINE DECANOATE',
#   ' MODAFINIL',
#   ' RISPERIDONE',
#   ' GABAPENTIN',
#   ' BUPROPION XL',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' FLUVOXAMINE MALEATE',
#   ' AMANTADINE',
#   ' LAMOTRIGINE',
#   ' TOPIRAMATE'],
#  ['BENAZEPRIL HCL',
#   ' INSULIN SYRINGE',
#   ' DIOVAN HCT',
#   ' GABAPENTIN',
#   ' KLOR-CON M20',
#   ' NAPROXEN',
#   ' ATORVASTATIN CALCIUM',
#   ' HYDROCHLOROTHIAZIDE',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' TRIZIVIR',
#   ' PROAIR HFA',
#   ' GLIPIZIDE',
#   ' OMEPRAZOLE',
#   ' METOPROLOL TARTRATE',
#   ' AMITRIPTYLINE HCL',
#   ' AMLODIPINE BESYLATE',
#   ' BUPROPION HCL SR',
#   ' SIMVASTATIN',
#   ' LOSARTAN POTASSIUM',
#   ' IRBESARTAN',
#   ' FLUTICASONE PROPIONATE',
#   ' LANTUS',
#   ' ZETIA',
#   ' NIFEDIPINE ER',
#   ' PANTOPRAZOLE SODIUM',
#   ' TRIAMTERENE-HCTZ',
#   ' FUROSEMIDE',
#   ' ALENDRONATE SODIUM',
#   ' CLONIDINE HCL',
#   ' SPIRONOLACTONE',
#   ' LISINOPRIL',
#   ' LEVOTHYROXINE SODIUM',
#   ' REYATAZ',
#   ' POTASSIUM CHLORIDE',
#   ' DIOVAN',
#   ' TOLTERODINE TARTRATE',
#   ' RANITIDINE HCL',
#   ' CHOLESTYRAMINE',
#   ' VERAPAMIL ER',
#   ' ATRIPLA',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' TRAZODONE HCL',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' CARVEDILOL',
#   ' METOPROLOL SUCCINATE',
#   ' HUMALOG',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' WELCHOL',
#   ' ALLOPURINOL',
#   ' GLIMEPIRIDE',
#   ' SERTRALINE HCL',
#   ' ATENOLOL',
#   ' PRAVASTATIN SODIUM',
#   ' TRUVADA',
#   ' METFORMIN HCL',
#   ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#   ' DILTIAZEM HCL',
#   ' MONTELUKAST SODIUM',
#   ' TRAMADOL HCL'],
#  ['MORPHINE SULFATE ER'],
#  ['LEVOFLOXACIN',
#   ' REYATAZ',
#   ' NORVIR',
#   ' INVANZ',
#   ' SUSTIVA',
#   ' ABACAVIR',
#   ' VIREAD',
#   ' FLUCONAZOLE',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' EPZICOM',
#   ' DOXYCYCLINE HYCLATE',
#   ' TRIZIVIR',
#   ' KALETRA',
#   ' VANCOMYCIN HCL'],
#  ['FLUOXETINE HCL',
#   ' VENTOLIN HFA',
#   ' GABAPENTIN',
#   ' WARFARIN SODIUM',
#   ' RANITIDINE HCL',
#   ' ATORVASTATIN CALCIUM',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' CITALOPRAM HBR',
#   ' METFORMIN HCL',
#   ' METOPROLOL TARTRATE',
#   ' ZOLPIDEM TARTRATE',
#   ' PROAIR HFA',
#   ' IBUPROFEN',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' OMEPRAZOLE',
#   ' LORAZEPAM',
#   ' AMITRIPTYLINE HCL',
#   ' AMLODIPINE BESYLATE',
#   ' CYCLOBENZAPRINE HCL',
#   ' PREDNISONE',
#   ' SERTRALINE HCL',
#   ' SIMVASTATIN',
#   ' LEVOTHYROXINE SODIUM',
#   ' SYNTHROID',
#   ' FUROSEMIDE',
#   ' AZITHROMYCIN',
#   ' TRAMADOL HCL',
#   ' LISINOPRIL',
#   ' BENICAR'],
#  ['CALCIUM ACETATE',
#   ' NEXIUM',
#   ' HYDRALAZINE HCL',
#   ' SENSIPAR',
#   ' LOSARTAN POTASSIUM',
#   ' ATORVASTATIN CALCIUM',
#   ' NIFEDICAL XL',
#   ' NIFEDIPINE ER',
#   ' HYDROCHLOROTHIAZIDE',
#   ' LIDOCAINE-PRILOCAINE',
#   ' FUROSEMIDE',
#   ' CLONIDINE HCL',
#   ' METOPROLOL TARTRATE',
#   ' ZOLPIDEM TARTRATE',
#   ' RENVELA',
#   ' LISINOPRIL',
#   ' PRAVASTATIN SODIUM'],
#  ['RISPERIDONE',
#   ' TRIFLUOPERAZINE HCL',
#   ' CLONAZEPAM',
#   ' TRIHEXYPHENIDYL HCL',
#   ' BUDEPRION SR',
#   ' FLUPHENAZINE DECANOATE',
#   ' FLUPHENAZINE HCL',
#   ' PRAZOSIN HCL',
#   ' HALOPERIDOL DECANOATE',
#   ' BENZTROPINE MESYLATE',
#   ' METFORMIN HCL',
#   ' CARBAMAZEPINE',
#   ' SERTRALINE HCL',
#   ' DIVALPROEX SODIUM',
#   ' CLOZAPINE',
#   ' AMITRIPTYLINE HCL',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' LEVOTHYROXINE SODIUM',
#   ' LITHIUM CARBONATE',
#   ' ABILIFY',
#   ' PROPRANOLOL HCL',
#   ' BUSPIRONE HCL',
#   ' FLUOXETINE HCL',
#   ' NALTREXONE HCL',
#   ' SEROQUEL XR',
#   ' LOXAPINE',
#   ' PAROXETINE HCL',
#   ' MIRTAZAPINE',
#   ' CHLORPROMAZINE HCL',
#   ' HALOPERIDOL DECANOATE 100',
#   ' THIOTHIXENE',
#   ' CYMBALTA',
#   ' ZIPRASIDONE HCL',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' DIVALPROEX SODIUM ER',
#   ' LORAZEPAM',
#   ' ESCITALOPRAM OXALATE',
#   ' OXCARBAZEPINE',
#   ' BUPROPION HCL',
#   ' GABAPENTIN',
#   ' BUPROPION XL',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' FLUVOXAMINE MALEATE',
#   ' ALPRAZOLAM',
#   ' LAMOTRIGINE',
#   ' INVEGA SUSTENNA'],
#  ['NIFEDIPINE ER',
#   ' METOLAZONE',
#   ' HYDRALAZINE HCL',
#   ' DIOVAN',
#   ' WARFARIN SODIUM',
#   ' ISOSORBIDE DINITRATE',
#   ' ATORVASTATIN CALCIUM',
#   ' ZETIA',
#   ' KLOR-CON M20',
#   ' CRESTOR',
#   ' BUMETANIDE',
#   ' METOPROLOL SUCCINATE',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' METOPROLOL TARTRATE',
#   ' ALLOPURINOL',
#   ' AMIODARONE HCL',
#   ' CLOPIDOGREL',
#   ' AMLODIPINE BESYLATE',
#   ' XARELTO',
#   ' SIMVASTATIN',
#   ' LOSARTAN POTASSIUM',
#   ' DIGOX',
#   ' CARVEDILOL',
#   ' PRAVASTATIN SODIUM',
#   ' PANTOPRAZOLE SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' FUROSEMIDE',
#   ' DIGOXIN',
#   ' TORSEMIDE',
#   ' SPIRONOLACTONE',
#   ' LISINOPRIL',
#   ' QUINAPRIL HCL'],
#  ['HYDROCODONE-ACETAMINOPHEN', ' IBUPROFEN'],
#  ['AMPHETAMINE SALT COMBO',
#   ' CLONAZEPAM',
#   ' GABAPENTIN',
#   ' DIAZEPAM',
#   ' LATUDA',
#   ' DEXTROAMPHETAMINE-AMPHETAMINE',
#   ' MIRTAZAPINE',
#   ' METHYLPHENIDATE HCL',
#   ' ESCITALOPRAM OXALATE',
#   ' ZIPRASIDONE HCL',
#   ' TRAZODONE HCL',
#   ' TRAMADOL HCL',
#   ' DOXEPIN HCL',
#   ' SERTRALINE HCL',
#   ' BUSPIRONE HCL',
#   ' LORAZEPAM',
#   ' AMITRIPTYLINE HCL',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' CARBAMAZEPINE',
#   ' SAPHRIS',
#   ' LOXAPINE',
#   ' LITHIUM CARBONATE',
#   ' LAMOTRIGINE',
#   ' ABILIFY',
#   ' ALPRAZOLAM',
#   ' TOPIRAMATE'],
#  ['CARVEDILOL',
#   ' PRAVASTATIN SODIUM',
#   ' AMLODIPINE BESYLATE',
#   ' METOPROLOL TARTRATE',
#   ' ATORVASTATIN CALCIUM',
#   ' LISINOPRIL',
#   ' METOPROLOL SUCCINATE'],
#  ['CEPHALEXIN',
#   ' BISOPROLOL FUMARATE',
#   ' SIMVASTATIN',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' WARFARIN SODIUM',
#   ' PRADAXA',
#   ' HYDROCHLOROTHIAZIDE',
#   ' DIGOX',
#   ' METOPROLOL TARTRATE',
#   ' NADOLOL',
#   ' METOPROLOL SUCCINATE',
#   ' VERAPAMIL HCL',
#   ' AMIODARONE HCL',
#   ' CLOPIDOGREL',
#   ' AMLODIPINE BESYLATE',
#   ' CARVEDILOL',
#   ' LOSARTAN POTASSIUM',
#   ' DILTIAZEM HCL',
#   ' TIKOSYN',
#   ' ATENOLOL',
#   ' MUPIROCIN',
#   ' FLECAINIDE ACETATE',
#   ' DILTIAZEM 24HR ER',
#   ' PANTOPRAZOLE SODIUM',
#   ' FUROSEMIDE',
#   ' DIGOXIN',
#   ' SPIRONOLACTONE',
#   ' LISINOPRIL',
#   ' PRAVASTATIN SODIUM'],
#  ['BUSPIRONE HCL',
#   ' CARBIDOPA-LEVODOPA',
#   ' FLUOXETINE HCL',
#   ' CLONAZEPAM',
#   ' TRIHEXYPHENIDYL HCL',
#   ' SEROQUEL XR',
#   ' PAROXETINE HCL',
#   ' NAMENDA',
#   ' MIRTAZAPINE',
#   ' CHLORPROMAZINE HCL',
#   ' ESCITALOPRAM OXALATE',
#   ' CYMBALTA',
#   ' DIVALPROEX SODIUM',
#   ' ZIPRASIDONE HCL',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' TEMAZEPAM',
#   ' GABAPENTIN',
#   ' OMEPRAZOLE',
#   ' INVEGA',
#   ' EXELON',
#   ' LORAZEPAM',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' DONEPEZIL HCL',
#   ' SERTRALINE HCL',
#   ' BUPROPION XL',
#   ' VENLAFAXINE HCL ER',
#   ' RISPERIDONE',
#   ' LITHIUM CARBONATE',
#   ' LAMOTRIGINE',
#   ' ABILIFY',
#   ' ALPRAZOLAM',
#   ' GALANTAMINE HBR'],
#  ['DIAZEPAM', ' QUETIAPINE FUMARATE'],
#  ['CEPHALEXIN',
#   ' ECONAZOLE NITRATE',
#   ' TRIAMCINOLONE ACETONIDE',
#   ' HYDROCORTISONE',
#   ' DESONIDE',
#   ' KETOCONAZOLE',
#   ' CLOBETASOL PROPIONATE',
#   ' PREDNISONE',
#   ' CLINDAMYCIN PHOSPHATE',
#   ' MUPIROCIN',
#   ' DOXYCYCLINE HYCLATE',
#   ' HYDROXYZINE HCL',
#   ' BETAMETHASONE DIPROPIONATE',
#   ' FLUOCINONIDE',
#   ' METRONIDAZOLE'],
#  ['MIDODRINE HCL',
#   ' BENAZEPRIL HCL',
#   ' GABAPENTIN',
#   ' METOLAZONE',
#   ' LACTATED RINGERS',
#   ' SENSIPAR',
#   ' WARFARIN SODIUM',
#   ' HYDROCHLOROTHIAZIDE',
#   ' DOXAZOSIN MESYLATE',
#   ' TERAZOSIN HCL',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' IMIPRAMINE HCL',
#   ' OMEPRAZOLE',
#   ' METOCLOPRAMIDE HCL',
#   ' CALCITRIOL',
#   ' AMILORIDE HCL',
#   ' FAMOTIDINE',
#   ' ATORVASTATIN CALCIUM',
#   ' PREDNISONE',
#   ' IRBESARTAN',
#   ' LABETALOL HCL',
#   ' LEVOTHYROXINE SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' FUROSEMIDE',
#   ' ALENDRONATE SODIUM',
#   ' SPIRONOLACTONE',
#   ' LISINOPRIL',
#   ' SIMVASTATIN',
#   ' CALCIUM ACETATE',
#   ' CLOPIDOGREL',
#   ' SYNTHROID',
#   ' LOSARTAN POTASSIUM',
#   ' COLCRYS',
#   ' DIOVAN',
#   ' TAMSULOSIN HCL',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' METOPROLOL TARTRATE',
#   ' CARVEDILOL',
#   ' METOPROLOL SUCCINATE',
#   ' JANUVIA',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' ALLOPURINOL',
#   ' LORAZEPAM',
#   ' AMLODIPINE BESYLATE',
#   ' RENVELA',
#   ' LOPERAMIDE',
#   ' VYTORIN',
#   ' OPIUM TINCTURE',
#   ' FLUDROCORTISONE ACETATE',
#   ' CIPROFLOXACIN HCL',
#   ' ATENOLOL',
#   ' PRAVASTATIN SODIUM',
#   ' ZEMPLAR'],
#  ['CALCIUM ACETATE',
#   ' AMLODIPINE BESYLATE',
#   ' HYDRALAZINE HCL',
#   ' ATORVASTATIN CALCIUM',
#   ' LOSARTAN POTASSIUM',
#   ' CALCITRIOL',
#   ' DOXAZOSIN MESYLATE',
#   ' POTASSIUM CHLORIDE',
#   ' FUROSEMIDE',
#   ' ALPRAZOLAM',
#   ' TORSEMIDE',
#   ' SPIRONOLACTONE',
#   ' RENVELA',
#   ' LISINOPRIL',
#   ' LEVOTHYROXINE SODIUM'],
#  ['OXYCONTIN',
#   ' CICLOPIROX',
#   ' PENTOXIFYLLINE',
#   ' LANSOPRAZOLE',
#   ' ATROVENT HFA',
#   ' TESTIM',
#   ' CELEBREX',
#   ' MUPIROCIN',
#   ' TRETINOIN',
#   ' ATORVASTATIN CALCIUM',
#   ' NAPROXEN',
#   ' PIOGLITAZONE HCL',
#   ' CLOBETASOL PROPIONATE',
#   ' VIREAD',
#   ' ROPINIROLE HCL',
#   ' BARACLUDE',
#   ' TRIZIVIR',
#   ' CITALOPRAM HBR',
#   ' LEXIVA',
#   ' ALPRAZOLAM',
#   ' TRAZODONE HCL',
#   ' COREG CR',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' COMBIVENT',
#   ' NIASPAN',
#   ' LOSARTAN POTASSIUM',
#   ' IBANDRONATE SODIUM',
#   ' ZETIA',
#   ' NIFEDIPINE ER',
#   ' SYMBICORT',
#   ' PANTOPRAZOLE SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' ENALAPRIL MALEATE',
#   ' LUNESTA',
#   ' ALENDRONATE SODIUM',
#   ' CLONIDINE HCL',
#   ' AMITIZA',
#   ' LEVOTHYROXINE SODIUM',
#   ' REYATAZ',
#   ' LEVETIRACETAM',
#   ' CYPROHEPTADINE HCL',
#   ' NEXIUM',
#   ' PREZISTA',
#   ' SELZENTRY',
#   ' AMMONIUM LACTATE',
#   ' PAROXETINE HCL',
#   ' OXYCODONE HCL-ACETAMINOPHEN',
#   ' ZOLPIDEM TARTRATE',
#   ' MIRTAZAPINE',
#   ' RANITIDINE HCL',
#   ' LAMIVUDINE',
#   ' CYMBALTA',
#   ' LIDODERM',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' ATRIPLA',
#   ' URSODIOL',
#   ' ACYCLOVIR',
#   ' METOPROLOL TARTRATE',
#   ' CLOTRIMAZOLE-BETAMETHASONE',
#   ' TEMAZEPAM',
#   ' KETOCONAZOLE',
#   ' VALACYCLOVIR',
#   ' IBUPROFEN',
#   ' LORAZEPAM',
#   ' CLINDAMYCIN PHOSPHATE',
#   ' AMLODIPINE BESYLATE',
#   ' LOPERAMIDE',
#   ' INTELENCE',
#   ' BUPROPION XL',
#   ' MELOXICAM',
#   ' SUSTIVA',
#   ' LISINOPRIL',
#   ' CLOPIDOGREL',
#   ' AZITHROMYCIN',
#   ' LEVOFLOXACIN',
#   ' CARVEDILOL',
#   ' KALETRA',
#   ' FAMOTIDINE',
#   ' CREON',
#   ' CLONAZEPAM',
#   ' INSULIN SYRINGE',
#   ' FUROSEMIDE',
#   ' DIAZEPAM',
#   ' ABACAVIR',
#   ' NAMENDA',
#   ' METFORMIN HCL ER',
#   ' ESCITALOPRAM OXALATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' TAMSULOSIN HCL',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' DRONABINOL',
#   ' GAMMAGARD LIQUID',
#   ' PROAIR HFA',
#   ' NASONEX',
#   ' ISENTRESS',
#   ' METFORMIN HCL',
#   ' METOPROLOL SUCCINATE',
#   ' VOLTAREN',
#   ' SERTRALINE HCL',
#   ' OMEPRAZOLE',
#   ' HYDROCORTISONE',
#   ' CHANTIX',
#   ' AMITRIPTYLINE HCL',
#   ' LYRICA',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' SIMVASTATIN',
#   ' PANCRELIPASE 5',
#   '000',
#   ' SEROQUEL XR',
#   ' LOVAZA',
#   ' SYNTHROID',
#   ' EPZICOM',
#   ' STRIBILD',
#   ' LITHIUM CARBONATE',
#   ' TRAMADOL HCL',
#   ' OXANDROLONE',
#   ' SOTALOL',
#   ' PROPRANOLOL HCL',
#   ' NOVOLIN 70-30',
#   ' TRIAMCINOLONE ACETONIDE',
#   ' ADVAIR DISKUS',
#   ' FENOFIBRATE',
#   ' PHOSPHA 250 NEUTRAL',
#   ' MEPRON',
#   ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#   ' DIOVAN',
#   ' DEXILANT',
#   ' ANDROGEL',
#   ' DEPO-TESTOSTERONE',
#   ' DIPHENOXYLATE-ATROPINE',
#   ' IPRATROPIUM BROMIDE',
#   ' COMBIVENT RESPIMAT',
#   ' CRESTOR',
#   ' NYSTATIN',
#   ' EMTRIVA',
#   ' DICYCLOMINE HCL',
#   ' NORVIR',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' VENTOLIN HFA',
#   ' QUETIAPINE FUMARATE',
#   ' CYCLOBENZAPRINE HCL',
#   ' VIRAMUNE XR',
#   ' GABAPENTIN',
#   ' CIPROFLOXACIN HCL',
#   ' ATENOLOL',
#   ' PRAVASTATIN SODIUM',
#   ' TRUVADA',
#   ' TESTOSTERONE CYPIONATE',
#   ' EDURANT',
#   ' FLUTICASONE PROPIONATE',
#   ' MONTELUKAST SODIUM'],
#  ['RISPERIDONE',
#   ' CLONAZEPAM',
#   ' FANAPT',
#   ' LATUDA',
#   ' NAMENDA',
#   ' ESCITALOPRAM OXALATE',
#   ' FLUPHENAZINE HCL',
#   ' INVEGA',
#   ' ZIPRASIDONE HCL',
#   ' CARBAMAZEPINE',
#   ' GABAPENTIN',
#   ' DIVALPROEX SODIUM',
#   ' FAZACLO',
#   ' QUETIAPINE FUMARATE',
#   ' FLUVOXAMINE MALEATE',
#   ' OLANZAPINE',
#   ' VIIBRYD',
#   ' SAPHRIS',
#   ' LEVOTHYROXINE SODIUM',
#   ' LUNESTA',
#   ' LITHIUM CARBONATE',
#   ' ABILIFY',
#   ' ALPRAZOLAM',
#   ' PROPRANOLOL HCL',
#   ' BUSPIRONE HCL',
#   ' HYDROXYZINE PAMOATE',
#   ' FLUOXETINE HCL',
#   ' SEROQUEL XR',
#   ' PAROXETINE HCL',
#   ' MIRTAZAPINE',
#   ' CAMPRAL',
#   ' CYMBALTA',
#   ' RISPERDAL CONSTA',
#   ' PRISTIQ ER',
#   ' LEXAPRO',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' TEMAZEPAM',
#   ' CLOZARIL',
#   ' CLOZAPINE',
#   ' LORAZEPAM',
#   ' OXCARBAZEPINE',
#   ' DONEPEZIL HCL',
#   ' RISPERDAL',
#   ' SERTRALINE HCL',
#   ' BUPROPION XL',
#   ' SIMVASTATIN',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' THIORIDAZINE HCL',
#   ' LAMOTRIGINE',
#   ' INVEGA SUSTENNA',
#   ' TOPIRAMATE'],
#  ['CARBIDOPA-LEVODOPA',
#   ' RISPERIDONE',
#   ' TRIFLUOPERAZINE HCL',
#   ' CLONAZEPAM',
#   ' TRIHEXYPHENIDYL HCL',
#   ' FAMOTIDINE',
#   ' ZIPRASIDONE HCL',
#   ' DIAZEPAM',
#   ' NAMENDA',
#   ' FLUPHENAZINE DECANOATE',
#   ' FLUPHENAZINE HCL',
#   ' HYDROCHLOROTHIAZIDE',
#   ' HALOPERIDOL DECANOATE',
#   ' DOXAZOSIN MESYLATE',
#   ' LUNESTA',
#   ' NASONEX',
#   ' CARBAMAZEPINE',
#   ' SERTRALINE HCL',
#   ' OMEPRAZOLE',
#   ' TRAZODONE HCL',
#   ' CLOZAPINE',
#   ' AMITRIPTYLINE HCL',
#   ' QUETIAPINE FUMARATE',
#   ' TAZORAC',
#   ' BUPROPION HCL SR',
#   ' CLORAZEPATE DIPOTASSIUM',
#   ' ATENOLOL',
#   ' VIIBRYD',
#   ' PERPHENAZINE',
#   ' HALOPERIDOL',
#   ' DONEPEZIL HCL',
#   ' FUROSEMIDE',
#   ' NORTRIPTYLINE HCL',
#   ' LITHIUM CARBONATE',
#   ' OXAZEPAM',
#   ' ABILIFY',
#   ' ALPRAZOLAM',
#   ' NUEDEXTA',
#   ' BUSPIRONE HCL',
#   ' HYDROXYZINE PAMOATE',
#   ' DIVALPROEX SODIUM',
#   ' EXELON',
#   ' SEROQUEL XR',
#   ' ESTAZOLAM',
#   ' PAROXETINE HCL',
#   ' CRESTOR',
#   ' ZOLPIDEM TARTRATE',
#   ' MIRTAZAPINE',
#   ' AVODART',
#   ' THIOTHIXENE',
#   ' CYMBALTA',
#   ' INVEGA',
#   ' PRISTIQ ER',
#   ' VENLAFAXINE HCL',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' METOPROLOL TARTRATE',
#   ' CLOTRIMAZOLE-BETAMETHASONE',
#   ' DIVALPROEX SODIUM ER',
#   ' CHLORPROMAZINE HCL',
#   ' TEMAZEPAM',
#   ' FLUOXETINE HCL',
#   ' LORAZEPAM',
#   ' ESCITALOPRAM OXALATE',
#   ' CLOPIDOGREL',
#   ' RIVASTIGMINE',
#   ' BUPROPION HCL',
#   ' GABAPENTIN',
#   ' BUPROPION XL',
#   ' SIMVASTATIN',
#   ' OLANZAPINE ODT',
#   ' VENLAFAXINE HCL ER',
#   ' THIORIDAZINE HCL',
#   ' HYDROXYZINE HCL',
#   ' OLANZAPINE',
#   ' LAMOTRIGINE',
#   ' LYRICA',
#   ' TOPIRAMATE'],
#  ['INDOMETHACIN',
#   ' LEVETIRACETAM',
#   ' CLONAZEPAM',
#   ' TRAZODONE HCL',
#   ' AMPYRA',
#   ' GABAPENTIN',
#   ' ESCITALOPRAM OXALATE',
#   ' CYMBALTA',
#   ' AMANTADINE',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' PROVIGIL',
#   ' COPAXONE',
#   ' ZOLPIDEM TARTRATE',
#   ' METOPROLOL SUCCINATE',
#   ' BACLOFEN',
#   ' VERAPAMIL HCL',
#   ' VALACYCLOVIR',
#   ' IBUPROFEN',
#   ' AMITRIPTYLINE HCL',
#   ' AVONEX PEN',
#   ' QUETIAPINE FUMARATE',
#   ' DONEPEZIL HCL',
#   ' SERTRALINE HCL',
#   ' ACETAMINOPHEN-CODEINE',
#   ' ENABLEX',
#   ' BETASERON',
#   ' NUVIGIL',
#   ' TYSABRI',
#   ' AVONEX',
#   ' LYRICA',
#   ' ALPRAZOLAM',
#   ' TIZANIDINE HCL'],
#  ['SPIRIVA',
#   ' ADVAIR DISKUS',
#   ' PANTOPRAZOLE SODIUM',
#   ' PROAIR HFA',
#   ' PREDNISONE'],
#  ['RISPERIDONE',
#   ' CLONAZEPAM',
#   ' MIRTAZAPINE',
#   ' METHYLPHENIDATE HCL',
#   ' TEGRETOL XR',
#   ' ESCITALOPRAM OXALATE',
#   ' CYMBALTA',
#   ' FLUOXETINE HCL',
#   ' ZIPRASIDONE HCL',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' DOXEPIN HCL',
#   ' GABAPENTIN',
#   ' CLOZAPINE',
#   ' LORAZEPAM',
#   ' BUPROPION HCL SR',
#   ' VIIBRYD',
#   ' SERTRALINE HCL',
#   ' BUPROPION XL',
#   ' VENLAFAXINE HCL ER',
#   ' FLUVOXAMINE MALEATE',
#   ' LAMOTRIGINE',
#   ' TEMAZEPAM',
#   ' ABILIFY',
#   ' ALPRAZOLAM',
#   ' TOPIRAMATE'],
#  ['BUPROPION HCL SR'],
#  ['DILTIAZEM 24HR ER',
#   ' METOLAZONE',
#   ' HYDRALAZINE HCL',
#   ' JANTOVEN',
#   ' KLOR-CON M20',
#   ' ATORVASTATIN CALCIUM',
#   ' HYDROCHLOROTHIAZIDE',
#   ' TERAZOSIN HCL',
#   ' FENOFIBRATE',
#   ' CARTIA XT',
#   ' CRESTOR',
#   ' AMLODIPINE BESYLATE',
#   ' ATENOLOL',
#   ' LOSARTAN POTASSIUM',
#   ' ZETIA',
#   ' DILTIAZEM 24HR CD',
#   ' RAMIPRIL',
#   ' POTASSIUM CHLORIDE',
#   ' FUROSEMIDE',
#   ' RANEXA',
#   ' CLONIDINE HCL',
#   ' NITROSTAT',
#   ' LISINOPRIL',
#   ' SIMVASTATIN',
#   ' WARFARIN SODIUM',
#   ' EFFIENT',
#   ' XARELTO',
#   ' NIASPAN',
#   ' METOPROLOL TARTRATE',
#   ' LIPITOR',
#   ' PRADAXA',
#   ' MULTAQ',
#   ' KLOR-CON M10',
#   ' METOPROLOL SUCCINATE',
#   ' PRAVASTATIN SODIUM',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' WELCHOL',
#   ' AMIODARONE HCL',
#   ' CLOPIDOGREL',
#   ' LOVASTATIN',
#   ' DIGOX',
#   ' CARVEDILOL',
#   ' VERAPAMIL ER',
#   ' DIGOXIN'],
#  ['PIOGLITAZONE HCL',
#   ' LANSOPRAZOLE',
#   ' FAMOTIDINE',
#   ' TRAMADOL HCL',
#   ' NATEGLINIDE',
#   ' LANTUS SOLOSTAR',
#   ' CYCLOBENZAPRINE HCL',
#   ' NAPROXEN',
#   ' ROPINIROLE HCL',
#   ' CILOSTAZOL',
#   ' METFORMIN HCL',
#   ' DILTIAZEM HCL',
#   ' ELIQUIS',
#   ' IMIPRAMINE HCL',
#   ' QUINAPRIL-HYDROCHLOROTHIAZIDE',
#   ' TRAZODONE HCL',
#   ' METOCLOPRAMIDE HCL',
#   ' MECLIZINE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' LOSARTAN POTASSIUM',
#   ' AZATHIOPRINE',
#   ' LANTUS',
#   ' NIFEDIPINE ER',
#   ' LEVOTHYROXINE SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' ENALAPRIL MALEATE',
#   ' RANEXA',
#   ' ALENDRONATE SODIUM',
#   ' AMIODARONE HCL',
#   ' METOPROLOL SUCCINATE',
#   ' SPIRONOLACTONE',
#   ' CEPHALEXIN',
#   ' AMILORIDE-HYDROCHLOROTHIAZIDE',
#   ' LEVETIRACETAM',
#   ' FLUOXETINE HCL',
#   ' QUETIAPINE FUMARATE',
#   ' NEXIUM',
#   ' NITROFURANTOIN MONO-MACRO',
#   ' METOPROLOL TARTRATE',
#   ' FUROSEMIDE',
#   ' PRAMIPEXOLE DIHYDROCHLORIDE',
#   ' AVODART',
#   ' RANITIDINE HCL',
#   ' PRADAXA',
#   ' TAMSULOSIN HCL',
#   ' OXYBUTYNIN CHLORIDE',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' GLYBURIDE',
#   ' CITALOPRAM HBR',
#   ' WARFARIN SODIUM',
#   ' BUMETANIDE',
#   ' VERAPAMIL HCL',
#   ' ALLOPURINOL',
#   ' IBUPROFEN',
#   ' LORAZEPAM',
#   ' CLOPIDOGREL',
#   ' OXYCONTIN',
#   ' SPIRIVA',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' MELOXICAM',
#   ' POLYETHYLENE GLYCOL 3350',
#   ' VENLAFAXINE HCL ER',
#   ' LISINOPRIL',
#   ' GLIPIZIDE-METFORMIN',
#   ' AZITHROMYCIN',
#   ' GENERLAC',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' CELEBREX',
#   ' CLONAZEPAM',
#   ' CRESTOR',
#   ' FINASTERIDE',
#   ' TRAMADOL HCL-ACETAMINOPHEN',
#   ' KLOR-CON M20',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' DOXAZOSIN MESYLATE',
#   ' FENOFIBRATE',
#   ' PROAIR HFA',
#   ' BACLOFEN',
#   ' OMEPRAZOLE',
#   ' BISOPROLOL-HYDROCHLOROTHIAZIDE',
#   ' LYRICA',
#   ' AMLODIPINE BESYLATE',
#   ' JANUMET',
#   ' CARVEDILOL',
#   ' PREDNISONE',
#   ' FENTANYL',
#   ' NIFEDICAL XL',
#   ' GLIPIZIDE ER',
#   ' DOXYCYCLINE HYCLATE',
#   ' RAMIPRIL',
#   ' OXYCODONE HCL-ACETAMINOPHEN',
#   ' EVISTA',
#   ' LOVASTATIN',
#   ' PROPRANOLOL HCL',
#   ' SIMVASTATIN',
#   ' TRIAMCINOLONE ACETONIDE',
#   ' ADVAIR DISKUS',
#   ' EXELON',
#   ' AMOXICILLIN',
#   ' LEVEMIR FLEXPEN',
#   ' DIOVAN',
#   ' ATORVASTATIN CALCIUM',
#   ' VERAPAMIL ER',
#   ' DIPHENOXYLATE-ATROPINE',
#   ' TORSEMIDE',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' BUSPIRONE HCL',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' FLUTICASONE PROPIONATE',
#   ' DICYCLOMINE HCL',
#   ' JANUVIA',
#   ' NAMENDA',
#   ' METFORMIN HCL ER',
#   ' RIVASTIGMINE',
#   ' DONEPEZIL HCL',
#   ' CYMBALTA',
#   ' GLIMEPIRIDE',
#   ' GABAPENTIN',
#   ' CIPROFLOXACIN HCL',
#   ' ATENOLOL',
#   ' PRAVASTATIN SODIUM',
#   ' HYDROXYZINE HCL',
#   ' ALPRAZOLAM',
#   ' AVAPRO',
#   ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#   ' SULFASALAZINE',
#   ' SERTRALINE HCL',
#   ' MONTELUKAST SODIUM'],
#  ['AMOXICILLIN', ' PILOCARPINE HCL'],
#  ['CLONAZEPAM',
#   ' FAMOTIDINE',
#   ' FINASTERIDE',
#   ' WARFARIN SODIUM',
#   ' ESCITALOPRAM OXALATE',
#   ' HYDROCHLOROTHIAZIDE',
#   ' LOVAZA',
#   ' METFORMIN HCL',
#   ' NASONEX',
#   ' TEKTURNA',
#   ' EDARBI',
#   ' DIOVAN',
#   ' EXFORGE',
#   ' AMLODIPINE BESYLATE',
#   ' ATENOLOL',
#   ' LOSARTAN POTASSIUM',
#   ' IRBESARTAN',
#   ' RAMIPRIL',
#   ' LEVOTHYROXINE SODIUM',
#   ' SYNTHROID',
#   ' FUROSEMIDE',
#   ' MICARDIS',
#   ' METOPROLOL SUCCINATE',
#   ' SPIRONOLACTONE',
#   ' PANTOPRAZOLE SODIUM',
#   ' ALPRAZOLAM',
#   ' SIMVASTATIN',
#   ' FLUOXETINE HCL',
#   ' NEXIUM',
#   ' XARELTO',
#   ' VICTOZA 3-PAK',
#   ' DEXILANT',
#   ' RANITIDINE HCL',
#   ' ATORVASTATIN CALCIUM',
#   ' CYMBALTA',
#   ' COUMADIN',
#   ' CITALOPRAM HBR',
#   ' CRESTOR',
#   ' ZOLPIDEM TARTRATE',
#   ' BYSTOLIC',
#   ' ALLOPURINOL',
#   ' LORAZEPAM',
#   ' ZALEPLON',
#   ' GLIPIZIDE XL',
#   ' METFORMIN HCL ER',
#   ' GABAPENTIN',
#   ' CARVEDILOL',
#   ' PRAVASTATIN SODIUM',
#   ' CLOPIDOGREL',
#   ' DIGOXIN',
#   ' FLUTICASONE PROPIONATE',
#   ' QUINAPRIL HCL',
#   ' MONTELUKAST SODIUM'],
#  ['NORTRIPTYLINE HCL', ' AMOXICILLIN', ' HYDROCODONE-ACETAMINOPHEN'],
#  ['ACYCLOVIR'],
#  ['LEVOFLOXACIN',
#   ' MORPHINE SULFATE ER',
#   ' OMEPRAZOLE',
#   ' PROMETHAZINE HCL',
#   ' AMLODIPINE BESYLATE',
#   ' OXYCODONE HCL-ACETAMINOPHEN',
#   ' CARVEDILOL',
#   ' PREDNISONE',
#   ' GABAPENTIN',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' FLUCONAZOLE',
#   ' POTASSIUM CHLORIDE',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' ACYCLOVIR',
#   ' TRAZODONE HCL',
#   ' LISINOPRIL',
#   ' ONDANSETRON HCL'],
#  ['ENALAPRIL MALEATE', ' ATORVASTATIN CALCIUM'],
#  ['MENEST',
#   ' GLIPIZIDE ER',
#   ' ENALAPRIL MALEATE',
#   ' HYDRALAZINE HCL',
#   ' NOVOFINE',
#   ' GABAPENTIN',
#   ' CYCLOBENZAPRINE HCL',
#   ' NAPROXEN',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' GEMFIBROZIL',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' ADVAIR DISKUS',
#   ' ACYCLOVIR',
#   ' METFORMIN HCL',
#   ' DILTIAZEM ER',
#   ' ATENOLOL',
#   ' BACLOFEN',
#   ' OMEPRAZOLE',
#   ' CRESTOR',
#   ' AMITRIPTYLINE HCL',
#   ' AMLODIPINE BESYLATE',
#   ' ASMANEX',
#   ' CARVEDILOL',
#   ' LOSARTAN POTASSIUM',
#   ' ZETIA',
#   ' RAMIPRIL',
#   ' METHOCARBAMOL',
#   ' LANOXIN',
#   ' FUROSEMIDE',
#   ' FLUNISOLIDE',
#   ' ALENDRONATE SODIUM',
#   ' CLONIDINE HCL',
#   ' PREDNISONE',
#   ' SPIRONOLACTONE',
#   ' MEDROXYPROGESTERONE ACETATE',
#   ' PROPRANOLOL HCL',
#   ' SYNTHROID',
#   ' TRIAMCINOLONE ACETONIDE',
#   ' CYPROHEPTADINE HCL',
#   ' KLOR-CON 8',
#   ' NITROFURANTOIN MONO-MACRO',
#   ' LEVEMIR FLEXPEN',
#   ' RANITIDINE HCL',
#   ' ATORVASTATIN CALCIUM',
#   ' CYMBALTA',
#   ' COUMADIN',
#   ' OXYBUTYNIN CHLORIDE',
#   ' JANUMET',
#   ' FLUOXETINE HCL',
#   ' TRILIPIX',
#   ' CITALOPRAM HBR',
#   ' METOPROLOL TARTRATE',
#   ' ZOLPIDEM TARTRATE',
#   ' TRAMADOL HCL',
#   ' BYSTOLIC',
#   ' JANUVIA',
#   ' PRAMIPEXOLE DIHYDROCHLORIDE',
#   ' PROMETHAZINE HCL',
#   ' ALLOPURINOL',
#   ' IBUPROFEN',
#   ' CLOPIDOGREL',
#   ' DONEPEZIL HCL',
#   ' TAMSULOSIN HCL',
#   ' NOVOLOG FLEXPEN',
#   ' SERTRALINE HCL',
#   ' ZOSTAVAX',
#   ' SIMVASTATIN',
#   ' TORSEMIDE',
#   ' MELOXICAM'],
#  ['ESTRADIOL'],
#  ['DESIPRAMINE HCL',
#   ' WELLBUTRIN XL',
#   ' RISPERIDONE',
#   ' CLONAZEPAM',
#   ' TRIHEXYPHENIDYL HCL',
#   ' PERPHENAZINE',
#   ' DIAZEPAM',
#   ' LATUDA',
#   ' TRAMADOL HCL-ACETAMINOPHEN',
#   ' GABAPENTIN',
#   ' SAVELLA',
#   ' ESCITALOPRAM OXALATE',
#   ' SUBOXONE',
#   ' ROPINIROLE HCL',
#   ' ALPRAZOLAM',
#   ' DEXTROAMPHETAMINE SULFATE',
#   ' CARBAMAZEPINE',
#   ' IMIPRAMINE HCL',
#   ' DIVALPROEX SODIUM',
#   ' CLOZAPINE',
#   ' CHANTIX',
#   ' AMITRIPTYLINE HCL',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' VIIBRYD',
#   ' BUPROPION HCL',
#   ' ZIPRASIDONE HCL',
#   ' NORTRIPTYLINE HCL',
#   ' LITHIUM CARBONATE',
#   ' CLONIDINE HCL',
#   ' TEMAZEPAM',
#   ' ABILIFY',
#   ' FLUVOXAMINE MALEATE',
#   ' BUSPIRONE HCL',
#   ' HYDROXYZINE PAMOATE',
#   ' FLUOXETINE HCL',
#   ' ZONISAMIDE',
#   ' SEROQUEL XR',
#   ' TOPAMAX',
#   ' PAROXETINE HCL',
#   ' DEXTROAMPHETAMINE-AMPHETAMINE',
#   ' MIRTAZAPINE',
#   ' METHYLPHENIDATE HCL',
#   ' CHLORPROMAZINE HCL',
#   ' CYMBALTA',
#   ' INVEGA',
#   ' PRISTIQ ER',
#   ' AMOXAPINE',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' AMPHETAMINE SALT COMBO',
#   ' DOXEPIN HCL',
#   ' NAMENDA',
#   ' LORAZEPAM',
#   ' MODAFINIL',
#   ' OXCARBAZEPINE',
#   ' DONEPEZIL HCL',
#   ' BUPRENORPHINE-NALOXONE',
#   ' CLOMIPRAMINE HCL',
#   ' BUPROPION XL',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' THIORIDAZINE HCL',
#   ' BUPRENORPHINE HCL',
#   ' STRATTERA',
#   ' LAMOTRIGINE',
#   ' SERTRALINE HCL',
#   ' TOPIRAMATE'],
#  ['HYDROXYZINE PAMOATE',
#   ' LAMOTRIGINE',
#   ' LORAZEPAM',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' RISPERIDONE',
#   ' ZOLPIDEM TARTRATE',
#   ' MIRTAZAPINE',
#   ' DIVALPROEX SODIUM ER',
#   ' ESCITALOPRAM OXALATE',
#   ' CYMBALTA',
#   ' HALOPERIDOL',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' BUPROPION XL',
#   ' ABILIFY'],
#  ['AMOXICILLIN', ' HYDROCODONE-ACETAMINOPHEN'],
#  ['AMOXICILLIN',
#   ' DOXYCYCLINE HYCLATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' CHLORHEXIDINE GLUCONATE'],
#  ['AGGRENOX',
#   ' BENAZEPRIL HCL',
#   ' CRESTOR',
#   ' LEVOTHYROXINE SODIUM',
#   ' ENALAPRIL MALEATE',
#   ' TOPROL XL',
#   ' JANTOVEN',
#   ' WARFARIN SODIUM',
#   ' ISOSORBIDE DINITRATE',
#   ' HYDROCHLOROTHIAZIDE',
#   ' GEMFIBROZIL',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' LOVAZA',
#   ' METFORMIN HCL',
#   ' DIOVAN',
#   ' DILTIAZEM ER',
#   ' ATENOLOL',
#   ' ELIQUIS',
#   ' ALPRAZOLAM',
#   ' OMEPRAZOLE',
#   ' BISOPROLOL-HYDROCHLOROTHIAZIDE',
#   ' AMLODIPINE BESYLATE',
#   ' XARELTO',
#   ' NIASPAN',
#   ' SIMVASTATIN',
#   ' LOSARTAN POTASSIUM',
#   ' DILTIAZEM HCL',
#   ' PROPAFENONE HCL',
#   ' NIFEDICAL XL',
#   ' NIFEDIPINE ER',
#   ' RAMIPRIL',
#   ' PANTOPRAZOLE SODIUM',
#   ' TRIAMTERENE-HCTZ',
#   ' FUROSEMIDE',
#   ' RANEXA',
#   ' CLONIDINE HCL',
#   ' METOPROLOL SUCCINATE',
#   ' SOTALOL',
#   ' LOVASTATIN',
#   ' PROPRANOLOL HCL',
#   ' QUINAPRIL HCL',
#   ' MULTAQ',
#   ' EFFIENT',
#   ' DILTIAZEM 24HR CD',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' PLAVIX',
#   ' PAROXETINE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' CARTIA XT',
#   ' LIPITOR',
#   ' ATORVASTATIN CALCIUM',
#   ' TAMSULOSIN HCL',
#   ' EXFORGE',
#   ' COUMADIN',
#   ' METOPROLOL TARTRATE',
#   ' DEPAKOTE',
#   ' KLOR-CON M20',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' BUMETANIDE',
#   ' BYSTOLIC',
#   ' TEMAZEPAM',
#   ' PACERONE',
#   ' ALLOPURINOL',
#   ' LORAZEPAM',
#   ' AMIODARONE HCL',
#   ' PRADAXA',
#   ' SPIRONOLACTONE',
#   ' POTASSIUM CHLORIDE',
#   ' CYCLOBENZAPRINE HCL',
#   ' NITROSTAT',
#   ' TIKOSYN',
#   ' DIGOX',
#   ' CARVEDILOL',
#   ' PRAVASTATIN SODIUM',
#   ' LISINOPRIL',
#   ' CLOPIDOGREL',
#   ' DIGOXIN',
#   ' TORSEMIDE',
#   ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#   ' BENICAR',
#   ' NITROGLYCERIN PATCH',
#   ' KLOR-CON 10'],
#  ['TRAMADOL HCL',
#   ' OXYCONTIN',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' OXYCODONE-ACETAMINOPHEN'],
#  ['AMOXICILLIN'],
#  ['HYDROCODONE-ACETAMINOPHEN'],
#  ['SYNTHROID',
#   ' XARELTO',
#   ' NIASPAN',
#   ' FUROSEMIDE',
#   ' INDAPAMIDE',
#   ' DOXYCYCLINE MONOHYDRATE',
#   ' ATORVASTATIN CALCIUM',
#   ' ESCITALOPRAM OXALATE',
#   ' CYMBALTA',
#   ' HYDROCHLOROTHIAZIDE',
#   ' CRESTOR',
#   ' OMEPRAZOLE',
#   ' LABETALOL HCL',
#   ' AMLODIPINE BESYLATE',
#   ' TIROSINT',
#   ' DONEPEZIL HCL',
#   ' CARVEDILOL',
#   ' LOSARTAN POTASSIUM',
#   ' CIPROFLOXACIN HCL',
#   ' SIMVASTATIN',
#   ' VERAPAMIL ER',
#   ' RAMIPRIL',
#   ' LEVOTHYROXINE SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' CLOPIDOGREL',
#   ' DOXYCYCLINE HYCLATE',
#   ' SPIRONOLACTONE',
#   ' LISINOPRIL'],
#  ['GABAPENTIN',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' TIZANIDINE HCL',
#   ' CYCLOBENZAPRINE HCL',
#   ' CARISOPRODOL'],
#  ['PEG-3350 WITH FLAVOR PACKS',
#   ' SUPREP',
#   ' LANSOPRAZOLE',
#   ' NEXIUM',
#   ' DEXILANT',
#   ' RANITIDINE HCL',
#   ' POLYETHYLENE GLYCOL 3350',
#   ' DIPHENOXYLATE-ATROPINE',
#   ' VIREAD',
#   ' URSODIOL',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' LACTULOSE',
#   ' PEG-3350 AND ELECTROLYTES',
#   ' OMEPRAZOLE',
#   ' GAVILYTE-G',
#   ' METOCLOPRAMIDE HCL',
#   ' AMITRIPTYLINE HCL',
#   ' MOVIPREP',
#   ' NADOLOL',
#   ' SERTRALINE HCL',
#   ' BALSALAZIDE DISODIUM',
#   ' PANTOPRAZOLE SODIUM',
#   ' FUROSEMIDE',
#   ' PEG 3350-ELECTROLYTE',
#   ' AMITIZA',
#   ' SPIRONOLACTONE',
#   ' ASACOL HD',
#   ' XIFAXAN'],
#  ['CLOPIDOGREL',
#   ' NEXIUM',
#   ' FUROSEMIDE',
#   ' DIOVAN',
#   ' OXYCODONE HCL',
#   ' METFORMIN HCL ER',
#   ' CYCLOBENZAPRINE HCL',
#   ' ATORVASTATIN CALCIUM',
#   ' CYMBALTA',
#   ' HYDROCHLOROTHIAZIDE',
#   ' ADVAIR DISKUS',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' PROAIR HFA',
#   ' METOPROLOL TARTRATE',
#   ' ZOLPIDEM TARTRATE',
#   ' METFORMIN HCL',
#   ' METOPROLOL SUCCINATE',
#   ' GABAPENTIN',
#   ' OMEPRAZOLE',
#   ' CRESTOR',
#   ' ALPRAZOLAM',
#   ' SPIRIVA',
#   ' AMLODIPINE BESYLATE',
#   ' GLIPIZIDE XL',
#   ' SIMVASTATIN',
#   ' RANITIDINE HCL',
#   ' SERTRALINE HCL',
#   ' CARVEDILOL',
#   ' PRAVASTATIN SODIUM',
#   ' LEVOTHYROXINE SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' OXYCODONE HCL-ACETAMINOPHEN',
#   ' FLUTICASONE PROPIONATE',
#   ' LOVASTATIN',
#   ' LISINOPRIL',
#   ' QUINAPRIL HCL'],
#  ['AGGRENOX',
#   ' SUMATRIPTAN SUCCINATE',
#   ' DILANTIN',
#   ' BENAZEPRIL HCL',
#   ' PHENYTOIN',
#   ' FAMOTIDINE',
#   ' DIAZEPAM',
#   ' NAMENDA',
#   ' CARBIDOPA-LEVODOPA',
#   ' WARFARIN SODIUM',
#   ' ESCITALOPRAM OXALATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' VIMPAT',
#   ' COPAXONE',
#   ' ROPINIROLE HCL',
#   ' CARBIDOPA-LEVODOPA ER',
#   ' CLONAZEPAM',
#   ' CARBIDOPA-LEVODOPA-ENTACAPONE',
#   ' GABAPENTIN',
#   ' BISOPROLOL-HYDROCHLOROTHIAZIDE',
#   ' PRIMIDONE',
#   ' AMITRIPTYLINE HCL',
#   ' QUETIAPINE FUMARATE',
#   ' AMLODIPINE BESYLATE',
#   ' BUPROPION HCL SR',
#   ' ATENOLOL',
#   ' PREDNISONE',
#   ' CARBAMAZEPINE',
#   ' MYCOPHENOLATE MOFETIL',
#   ' PYRIDOSTIGMINE BROMIDE',
#   ' PRAVASTATIN SODIUM',
#   ' NORTRIPTYLINE HCL',
#   ' EPITOL',
#   ' AVONEX',
#   ' DONEPEZIL HCL',
#   ' PROPRANOLOL HCL',
#   ' SIMVASTATIN',
#   ' FELODIPINE ER',
#   ' SELEGILINE HCL',
#   ' EXELON',
#   ' PAROXETINE HCL',
#   ' MIRTAZAPINE',
#   ' RANITIDINE HCL',
#   ' CYMBALTA',
#   ' DIVALPROEX SODIUM',
#   ' KLOR-CON M20',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' METOPROLOL SUCCINATE',
#   ' PRAMIPEXOLE DIHYDROCHLORIDE',
#   ' LORAZEPAM',
#   ' AUBAGIO',
#   ' CLOPIDOGREL',
#   ' OXCARBAZEPINE',
#   ' LYRICA',
#   ' LEVETIRACETAM',
#   ' CYCLOBENZAPRINE HCL',
#   ' SERTRALINE HCL',
#   ' DEPAKOTE',
#   ' VERAPAMIL ER',
#   ' REBIF',
#   ' ALPRAZOLAM',
#   ' AMANTADINE',
#   ' OLANZAPINE',
#   ' PHENYTOIN SODIUM EXTENDED',
#   ' LAMOTRIGINE',
#   ' PHENOBARBITAL',
#   ' TOPIRAMATE'],
#  ['AGGRENOX',
#   ' VESICARE',
#   ' VENTOLIN HFA',
#   ' DILTIAZEM 24HR ER',
#   ' FAMOTIDINE',
#   ' ENALAPRIL MALEATE',
#   ' TOPROL XL',
#   ' HYDROCODONE-HOMATROPINE MBR',
#   ' ATORVASTATIN CALCIUM',
#   ' LEVOTHYROXINE SODIUM',
#   ' SEREVENT DISKUS',
#   ' METFORMIN HCL',
#   ' COMBIVENT RESPIMAT',
#   ' LACTULOSE',
#   ' FORADIL',
#   ' QUINAPRIL-HYDROCHLOROTHIAZIDE',
#   ' KLOR-CON M10',
#   ' NYSTATIN',
#   ' PULMICORT FLEXHALER',
#   ' LOSARTAN POTASSIUM',
#   ' SYMBICORT',
#   ' PANTOPRAZOLE SODIUM',
#   ' TRIAMTERENE-HCTZ',
#   ' GLIPIZIDE',
#   ' LUNESTA',
#   ' ALENDRONATE SODIUM',
#   ' XOPENEX HFA',
#   ' TEMAZEPAM',
#   ' SPIRONOLACTONE',
#   ' BENICAR',
#   ' DICLOFENAC SODIUM',
#   ' LEVOFLOXACIN',
#   ' FLUOXETINE HCL',
#   ' WARFARIN SODIUM',
#   ' POTASSIUM CHLORIDE',
#   ' NEXIUM',
#   ' THEOPHYLLINE ANHYDROUS',
#   ' PAROXETINE HCL',
#   ' OXYBUTYNIN CHLORIDE ER',
#   ' COLCRYS',
#   ' RANITIDINE HCL',
#   ' PRADAXA',
#   ' CYMBALTA',
#   ' PROMETHAZINE-CODEINE',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' GLYBURIDE',
#   ' CITALOPRAM HBR',
#   ' METOPROLOL TARTRATE',
#   ' TRAMADOL HCL',
#   ' DOXYCYCLINE HYCLATE',
#   ' CARTIA XT',
#   ' PROVENTIL HFA',
#   ' KETOCONAZOLE',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' ALLOPURINOL',
#   ' FUROSEMIDE',
#   ' LORAZEPAM',
#   ' MOEXIPRIL-HYDROCHLOROTHIAZIDE',
#   ' CLOPIDOGREL',
#   ' GLIPIZIDE XL',
#   ' OXYCONTIN',
#   ' SPIRIVA',
#   ' NOVOLOG FLEXPEN',
#   ' BUPROPION XL',
#   ' SIMVASTATIN',
#   ' PROPRANOLOL HCL',
#   ' AZITHROMYCIN',
#   ' METHOTREXATE',
#   ' QUINAPRIL HCL',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' CEPHALEXIN',
#   ' CELEBREX',
#   ' CLONAZEPAM',
#   ' METOLAZONE',
#   ' DIAZEPAM',
#   ' FINASTERIDE',
#   ' TRAMADOL HCL-ACETAMINOPHEN',
#   ' HYDROMET',
#   ' ISOSORBIDE DINITRATE',
#   ' ESCITALOPRAM OXALATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' GEMFIBROZIL',
#   ' DOXAZOSIN MESYLATE',
#   ' FENOFIBRATE',
#   ' ALPRAZOLAM',
#   ' PROAIR HFA',
#   ' NASONEX',
#   ' METOPROLOL SUCCINATE',
#   ' NORVASC',
#   ' SERTRALINE HCL',
#   ' OMEPRAZOLE',
#   ' METHIMAZOLE',
#   ' TRIAMTERENE-HYDROCHLOROTHIAZID',
#   ' DIGOX',
#   ' AMLODIPINE BESYLATE',
#   ' ASMANEX',
#   ' CARVEDILOL',
#   ' PREDNISONE',
#   ' FENTANYL',
#   ' MECLIZINE HCL',
#   ' GLIPIZIDE ER',
#   ' DILTIAZEM 24HR CD',
#   ' RAMIPRIL',
#   ' FLUCONAZOLE',
#   ' SYNTHROID',
#   ' OXYCODONE HCL-ACETAMINOPHEN',
#   ' EVISTA',
#   ' CAPTOPRIL',
#   ' LOVASTATIN',
#   ' LISINOPRIL',
#   ' DIOVAN HCT',
#   ' TRIAMCINOLONE ACETONIDE',
#   ' ADVAIR DISKUS',
#   ' FLOVENT HFA',
#   ' ZOSTAVAX',
#   ' AMOXICILLIN',
#   ' QVAR',
#   ' ACTONEL',
#   ' OXYCODONE HCL',
#   ' CEFUROXIME',
#   ' ZOLPIDEM TARTRATE',
#   ' SURE-PREP ALCOHOL PREP PADS',
#   ' KLOR-CON M20',
#   ' IPRATROPIUM BROMIDE',
#   ' DIOVAN',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' CRESTOR',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#   ' BYSTOLIC',
#   ' JANUVIA',
#   ' NABUMETONE',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' CHOLESTYRAMINE',
#   ' DONEPEZIL HCL',
#   ' TAMSULOSIN HCL',
#   ' METHYLPREDNISOLONE',
#   ' GABAPENTIN',
#   ' CIPROFLOXACIN HCL',
#   ' ATENOLOL',
#   ' PRAVASTATIN SODIUM',
#   ' KLOR-CON',
#   ' TORSEMIDE',
#   ' FLUTICASONE PROPIONATE',
#   ' KLOR-CON 10',
#   ' MONTELUKAST SODIUM'],
#  ['PHENELZINE SULFATE',
#   ' RISPERIDONE',
#   ' DEPAKOTE ER',
#   ' CLONAZEPAM',
#   ' TRIHEXYPHENIDYL HCL',
#   ' PERPHENAZINE',
#   ' DIAZEPAM',
#   ' LATUDA',
#   ' FLUPHENAZINE DECANOATE',
#   ' HALOPERIDOL DECANOATE',
#   ' ZIPRASIDONE HCL',
#   ' DIVALPROEX SODIUM',
#   ' SERTRALINE HCL',
#   ' INVEGA',
#   ' CLOZAPINE',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' VIIBRYD',
#   ' SAPHRIS',
#   ' LITHIUM CARBONATE',
#   ' ABILIFY',
#   ' FLUVOXAMINE MALEATE',
#   ' BUSPIRONE HCL',
#   ' HYDROXYZINE PAMOATE',
#   ' FLUOXETINE HCL',
#   ' RISPERIDONE ODT',
#   ' ABILIFY MAINTENA',
#   ' NALTREXONE HCL',
#   ' SEROQUEL XR',
#   ' PAROXETINE HCL',
#   ' MIRTAZAPINE',
#   ' OLEPTRO ER',
#   ' CYMBALTA',
#   ' RISPERDAL CONSTA',
#   ' PRISTIQ ER',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' CHLORPROMAZINE HCL',
#   ' TEMAZEPAM',
#   ' ALPRAZOLAM ER',
#   ' LORAZEPAM',
#   ' ESCITALOPRAM OXALATE',
#   ' OXCARBAZEPINE',
#   ' GABAPENTIN',
#   ' BUPROPION XL',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' PROPRANOLOL HCL',
#   ' ALPRAZOLAM',
#   ' STRATTERA',
#   ' LAMOTRIGINE',
#   ' INVEGA SUSTENNA',
#   ' TOPIRAMATE'],
#  ['XOPENEX HFA',
#   ' OMEPRAZOLE',
#   ' BUPROPION HCL SR',
#   ' VENTOLIN HFA',
#   ' FLOVENT HFA',
#   ' ADVAIR HFA',
#   ' DALIRESP',
#   ' SPIRIVA',
#   ' PREDNISONE',
#   ' ADVAIR DISKUS',
#   ' NICOTROL',
#   ' SYMBICORT',
#   ' PROAIR HFA',
#   ' ASMANEX',
#   ' DULERA',
#   ' FLUTICASONE PROPIONATE',
#   ' NASONEX',
#   ' COMBIVENT RESPIMAT',
#   ' MONTELUKAST SODIUM',
#   ' CHANTIX'],
#  ['HYDROCODONE-ACETAMINOPHEN',
#   ' CLONAZEPAM',
#   ' LORAZEPAM',
#   ' PHENOBARBITAL',
#   ' TRAMADOL HCL',
#   ' METOPROLOL TARTRATE',
#   ' ALPRAZOLAM',
#   ' TEMAZEPAM'],
#  ['AMOXICILLIN'],
#  ['CLOPIDOGREL', ' METOPROLOL SUCCINATE'],
#  ['LEVOFLOXACIN'],
#  ['GABAPENTIN',
#   ' BACLOFEN',
#   ' SUMATRIPTAN SUCCINATE',
#   ' METHOCARBAMOL',
#   ' TIZANIDINE HCL',
#   ' CYCLOBENZAPRINE HCL',
#   ' DOXEPIN HCL'],
#  ['CEPHALEXIN',
#   ' CIPROFLOXACIN HCL',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' AZITHROMYCIN'],
#  ['PENICILLIN V POTASSIUM',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' SF 5000 PLUS',
#   ' CHLORHEXIDINE GLUCONATE',
#   ' AMOXICILLIN',
#   ' IBUPROFEN',
#   ' AMOX TR-POTASSIUM CLAVULANATE',
#   ' CLINDAMYCIN HCL'],
#  ['AMOXICILLIN'],
#  ['AMOXICILLIN'],
#  ['INDOMETHACIN',
#   ' SUMATRIPTAN SUCCINATE',
#   ' ONDANSETRON ODT',
#   ' CARBAMAZEPINE XR',
#   ' PROCHLORPERAZINE MALEATE',
# ...
#   ' VENTOLIN HFA',
#   ' METRONIDAZOLE',
#   ' DILTIAZEM HCL',
#   ' ENALAPRIL-HYDROCHLOROTHIAZIDE',
#   ' METOPROLOL TARTRATE',
#   ' MECLIZINE HCL',
#   ' NITROFURANTOIN',
#   ' NADOLOL',
#   ' LOSARTAN POTASSIUM',
#   ' IBANDRONATE SODIUM',
#   ' PATANOL',
#   ' NIFEDIPINE ER',
#   ' PANTOPRAZOLE SODIUM',
#   ' TRIAMTERENE-HCTZ',
#   ' ALENDRONATE SODIUM',
#   ' PROMETHAZINE HCL',
#   ' SPIRONOLACTONE',
#   ' IPRATROPIUM-ALBUTEROL',
#   ' UNIFINE PENTIPS',
#   ' FLUOXETINE HCL',
#   ' NEXIUM',
#   ' NITROFURANTOIN MONO-MACRO',
#   ' FUROSEMIDE',
#   ' COLCRYS',
#   ' RANITIDINE HCL',
#   ' TAMSULOSIN HCL',
#   ' JANUMET',
#   ' ATRIPLA',
#   ' BUMETANIDE',
#   ' CLONIDINE',
#   ' PRAMIPEXOLE DIHYDROCHLORIDE',
#   ' LIDODERM',
#   ' AMIODARONE HCL',
#   ' SOTALOL',
#   ' RENVELA',
#   ' GLIPIZIDE XL',
#   ' DIGOX',
#   ' ACETAMINOPHEN-CODEINE',
#   ' AMLODIPINE-ATORVASTATIN',
#   ' ALPRAZOLAM',
#   ' GLIPIZIDE-METFORMIN',
#   ' CLOPIDOGREL',
#   ' HYDROMORPHONE HCL',
#   ' SUCRALFATE',
#   ' NITROGLYCERIN PATCH',
#   ' CARAFATE',
#   ' INSULIN SYRINGE',
#   ' METOLAZONE',
#   ' RELPAX',
#   ' NAMENDA',
#   ' ESCITALOPRAM OXALATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' DOXAZOSIN MESYLATE',
#   ' LATANOPROST',
#   ' NASONEX',
#   ' DILTIAZEM ER',
#   ' BACLOFEN',
#   ' DIOVAN',
#   ' HYDROCORTISONE',
#   ' AMITRIPTYLINE HCL',
#   ' LYRICA',
#   ' AMLODIPINE BESYLATE',
#   ' RAPAFLO',
#   ' PREDNISONE',
#   ' NIFEDICAL XL',
#   ' DILTIAZEM 24HR CD',
#   ' RAMIPRIL',
#   ' OXYCODONE HCL-ACETAMINOPHEN',
#   ' EVISTA',
#   ' HYDROCORTISONE VALERATE',
#   ' ABILIFY',
#   ' LISINOPRIL',
#   ' NOVOLIN 70-30',
#   ' CARBIDOPA-LEVODOPA ER',
#   ' OMEPRAZOLE',
#   ' TRAZODONE HCL',
#   ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#   ' OXYCODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIGOXIN',
#   ' DIPHENOXYLATE-ATROPINE',
#   ' IPRATROPIUM BROMIDE',
#   ' PHENYTOIN SODIUM EXTENDED',
#   ' KEPPRA',
#   ' FLUOCINONIDE',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' CRESTOR',
#   ' CARVEDILOL',
#   ' BYSTOLIC',
#   ' LEVOFLOXACIN',
#   ' RISPERIDONE',
#   ' BUPROPION HCL',
#   ' GLIMEPIRIDE',
#   ' SINGULAIR',
#   ' SERTRALINE HCL',
#   ' CIPROFLOXACIN HCL',
#   ' ALBUTEROL SULFATE',
#   ' ONGLYZA',
#   ' LIDOCAINE-PRILOCAINE',
#   ' HYDROXYZINE HCL',
#   ' FLUTICASONE PROPIONATE',
#   ' MONTELUKAST SODIUM',
#   ' VITAMIN D2',
#   ' MIDODRINE HCL',
#   ' PIOGLITAZONE HCL',
#   ' MEGESTROL ACETATE',
#   ' STROVITE ONE',
#   ' CIPRODEX',
#   ' FAMOTIDINE',
#   ' ENALAPRIL MALEATE',
#   ' HYDRALAZINE HCL',
#   ' AZOR',
#   ' LANTUS SOLOSTAR',
#   ' CYCLOBENZAPRINE HCL',
#   ' NAPROXEN',
#   ' PROCRIT',
#   ' METFORMIN HCL',
#   ' MINOXIDIL',
#   ' HECTOROL',
#   ' LACTULOSE',
#   ' EXFORGE',
#   ' METOCLOPRAMIDE HCL',
#   ' GLYCOPYRROLATE',
#   ' LANTUS',
#   ' SILVER SULFADIAZINE',
#   ' COMBIGAN',
#   ' MEGACE ES',
#   ' LABETALOL HCL',
#   ' PROMETHAZINE-DM',
#   ' SYMBICORT',
#   ' METHOCARBAMOL',
#   ' GLYBURIDE',
#   ' CLONIDINE HCL',
#   ' METOPROLOL SUCCINATE',
#   ' BENICAR',
#   ' CEPHALEXIN',
#   ' CALCIUM ACETATE',
#   ' LEVETIRACETAM',
#   ' POTASSIUM CHLORIDE',
#   ' ULORIC',
#   ' PAROXETINE HCL',
#   ' MIRTAZAPINE',
#   ' QVAR',
#   ' CYMBALTA',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' WARFARIN SODIUM',
#   ' CLOTRIMAZOLE-BETAMETHASONE',
#   ' TEMAZEPAM',
#   ' HUMALOG',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' ALLOPURINOL',
#   ' IBUPROFEN',
#   ' LORAZEPAM',
#   ' OXCARBAZEPINE',
#   ' AMOX TR-POTASSIUM CLAVULANATE',
#   ' SPIRIVA',
#   ' NOVOLOG FLEXPEN',
#   ' MELOXICAM',
#   ' DETROL LA',
#   ' LIDOCAINE',
#   ' DIOVAN HCT',
#   ' AZITHROMYCIN',
#   ' ENOXAPARIN SODIUM',
#   ' SANTYL',
#   ' LEVEMIR',
#   ' CELEBREX',
#   ' BENAZEPRIL HCL',
#   ' NOVOLOG',
#   ' DIAZEPAM',
#   ' LOPERAMIDE',
#   ' SENSIPAR',
#   ' RESTASIS',
#   ' KLOR-CON M20',
#   ' ISOSORBIDE DINITRATE',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' PROAIR HFA',
#   ' VOLTAREN',
#   ' GABAPENTIN',
#   ' DIVALPROEX SODIUM',
#   ' QUETIAPINE FUMARATE',
#   ' BUPROPION HCL SR',
#   ' ATENOLOL',
#   ' FENTANYL',
#   ' DORZOLAMIDE-TIMOLOL',
#   ' DOXYCYCLINE HYCLATE',
#   ' FLUCONAZOLE',
#   ' OXYBUTYNIN CHLORIDE ER',
#   ' TRAMADOL HCL',
#   ' CAPTOPRIL',
#   ' LOVASTATIN',
#   ' GLYBURIDE-METFORMIN HCL',
#   ' ADVAIR DISKUS',
#   ' GLIPIZIDE',
#   ' AMOXICILLIN',
#   ' LEVEMIR FLEXPEN',
#   ' NATEGLINIDE',
#   ' DORZOLAMIDE HCL',
#   ' CARTIA XT',
#   ' CARBIDOPA-LEVODOPA',
#   ' TRAVATAN Z',
#   ' CLARITHROMYCIN',
#   ' COMBIVENT RESPIMAT',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' DIVALPROEX SODIUM ER',
#   ' CITALOPRAM HBR',
#   ' JANUVIA',
#   ' DONEPEZIL HCL',
#   ' METFORMIN HCL ER',
#   ' MUPIROCIN',
#   ' PRAVASTATIN SODIUM',
#   ' OLANZAPINE',
#   ' TORSEMIDE',
#   ' LAMOTRIGINE',
#   ' TOPIRAMATE',
#   ' LEVOCETIRIZINE DIHYDROCHLORIDE',
#   ' CEFADROXIL'],
#  ['PRAVASTATIN SODIUM',
#   ' LEVOTHYROXINE SODIUM',
#   ' AZITHROMYCIN',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' METFORMIN HCL',
#   ' LISINOPRIL',
#   ' DIOVAN HCT'],
#  ['CYMBALTA',
#   ' AMBIEN',
#   ' QUETIAPINE FUMARATE',
#   ' EFFEXOR XR',
#   ' PAROXETINE HCL',
#   ' CLONAZEPAM'],
#  ['SUMATRIPTAN SUCCINATE',
#   ' CARBIDOPA-LEVODOPA',
#   ' DILANTIN',
#   ' CLONAZEPAM',
#   ' TRIHEXYPHENIDYL HCL',
#   ' TOPAMAX',
#   ' OXYCODONE HCL-ACETAMINOPHEN',
#   ' LEVETIRACETAM',
#   ' AZILECT',
#   ' CYMBALTA',
#   ' REBIF',
#   ' PHENYTOIN SODIUM EXTENDED',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' ROPINIROLE HCL',
#   ' AMPYRA',
#   ' COPAXONE',
#   ' ZOLPIDEM TARTRATE',
#   ' CARBIDOPA-LEVODOPA ER',
#   ' PRIMIDONE',
#   ' BACLOFEN',
#   ' PRAMIPEXOLE DIHYDROCHLORIDE',
#   ' NAMENDA',
#   ' AMITRIPTYLINE HCL',
#   ' LORAZEPAM',
#   ' LYRICA',
#   ' MODAFINIL',
#   ' OXCARBAZEPINE',
#   ' DONEPEZIL HCL',
#   ' CYCLOBENZAPRINE HCL',
#   ' CARBAMAZEPINE',
#   ' GABAPENTIN',
#   ' MECLIZINE HCL',
#   ' EPITOL',
#   ' METHOCARBAMOL',
#   ' CARBAMAZEPINE XR',
#   ' LUNESTA',
#   ' TRILEPTAL',
#   ' LAMOTRIGINE',
#   ' PHENOBARBITAL',
#   ' PROPRANOLOL HCL',
#   ' TOPIRAMATE'],
#  ['HYDROCODONE-ACETAMINOPHEN', ' PENICILLIN V POTASSIUM'],
#  ['AZITHROMYCIN',
#   ' CIPROFLOXACIN HCL',
#   ' SIMVASTATIN',
#   ' HYDROCODONE-ACETAMINOPHEN'],
#  ['NAMENDA',
#   ' CELEBREX',
#   ' CLONAZEPAM',
#   ' DIAZEPAM',
#   ' FUROSEMIDE',
#   ' DIOVAN',
#   ' METHYLPHENIDATE HCL',
#   ' MIRTAZAPINE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' WARFARIN SODIUM',
#   ' ZOLPIDEM TARTRATE',
#   ' METOPROLOL SUCCINATE',
#   ' JANUVIA',
#   ' OMEPRAZOLE',
#   ' LORAZEPAM INTENSOL',
#   ' LORAZEPAM',
#   ' QUETIAPINE FUMARATE',
#   ' BUDESONIDE',
#   ' FENTANYL',
#   ' SERTRALINE HCL',
#   ' MORPHINE SULFATE',
#   ' TORSEMIDE',
#   ' IPRATROPIUM-ALBUTEROL',
#   ' ALPRAZOLAM'],
#  ['CEPHALEXIN',
#   ' ECONAZOLE NITRATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' CLINDAMYCIN HCL',
#   ' DICLOFENAC SODIUM',
#   ' AMOX TR-POTASSIUM CLAVULANATE',
#   ' IBUPROFEN'],
#  ['ADVAIR DISKUS',
#   ' VENTOLIN HFA',
#   ' SIMVASTATIN',
#   ' NEXIUM',
#   ' ATROVENT HFA',
#   ' WARFARIN SODIUM',
#   ' HYDROCHLOROTHIAZIDE',
#   ' PREDNISONE',
#   ' METFORMIN HCL',
#   ' METOPROLOL TARTRATE',
#   ' PROAIR HFA',
#   ' JANUVIA',
#   ' CLOPIDOGREL',
#   ' AMLODIPINE BESYLATE',
#   ' FAMOTIDINE',
#   ' ATORVASTATIN CALCIUM',
#   ' LOSARTAN POTASSIUM',
#   ' GABAPENTIN',
#   ' LANTUS',
#   ' CARVEDILOL',
#   ' NIFEDIPINE ER',
#   ' LEVOTHYROXINE SODIUM',
#   ' FUROSEMIDE',
#   ' LISINOPRIL'],
#  ['SIMVASTATIN',
#   ' HYDRALAZINE HCL',
#   ' FUROSEMIDE',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' SPIRONOLACTONE',
#   ' HYDROCHLOROTHIAZIDE',
#   ' CRESTOR',
#   ' METOPROLOL SUCCINATE',
#   ' DIOVAN',
#   ' METOPROLOL TARTRATE',
#   ' AMIODARONE HCL',
#   ' DIGOX',
#   ' CLOPIDOGREL',
#   ' CHLORTHALIDONE',
#   ' ATORVASTATIN CALCIUM',
#   ' LOSARTAN POTASSIUM',
#   ' PROPAFENONE HCL',
#   ' ATENOLOL',
#   ' CARVEDILOL',
#   ' POTASSIUM CHLORIDE',
#   ' AMLODIPINE BESYLATE',
#   ' NITROGLYCERIN PATCH',
#   ' NITROSTAT',
#   ' LISINOPRIL'],
#  ['IBUPROFEN', ' PENICILLIN V POTASSIUM'],
#  ['AMOXICILLIN',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' DEXAMETHASONE',
#   ' CLINDAMYCIN HCL',
#   ' CHLORHEXIDINE GLUCONATE'],
#  ['VALACYCLOVIR'],
#  ['TRAZODONE HCL',
#   ' LORAZEPAM',
#   ' JANTOVEN',
#   ' OXYCODONE HCL',
#   ' WARFARIN SODIUM',
#   ' RANITIDINE HCL',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' FENTANYL',
#   ' FUROSEMIDE',
#   ' HYDROMORPHONE HCL',
#   ' METOPROLOL TARTRATE',
#   ' LEVOTHYROXINE SODIUM'],
#  ['MORPHINE SULFATE ER',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' CLONAZEPAM',
#   ' LORAZEPAM',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' LYRICA',
#   ' OXYCONTIN',
#   ' OXYCODONE HCL',
#   ' FENTANYL'],
#  ['SYNTHROID'],
#  ['AMOXICILLIN', ' HYDROCODONE-ACETAMINOPHEN', ' PENICILLIN V POTASSIUM'],
#  ['ADVAIR DISKUS',
#   ' CLONAZEPAM',
#   ' AMOXICILLIN',
#   ' METOPROLOL TARTRATE',
#   ' ATORVASTATIN CALCIUM',
#   ' CYMBALTA',
#   ' HYDROCHLOROTHIAZIDE',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' FENOFIBRATE',
#   ' ZETIA',
#   ' PROAIR HFA',
#   ' TRAZODONE HCL',
#   ' METFORMIN HCL',
#   ' ATENOLOL',
#   ' METOPROLOL SUCCINATE',
#   ' OMEPRAZOLE',
#   ' CRESTOR',
#   ' TIZANIDINE HCL',
#   ' AMLODIPINE BESYLATE',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' GLIMEPIRIDE',
#   ' GABAPENTIN',
#   ' CIPROFLOXACIN HCL',
#   ' SIMVASTATIN',
#   ' LEVOTHYROXINE SODIUM',
#   ' CLOPIDOGREL',
#   ' AZITHROMYCIN',
#   ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#   ' CARVEDILOL',
#   ' LISINOPRIL',
#   ' TRAMADOL HCL'],
#  ['HYDROXYZINE PAMOATE',
#   ' RISPERIDONE',
#   ' FLUOXETINE HCL',
#   ' CLONAZEPAM',
#   ' SEROQUEL XR',
#   ' DIAZEPAM',
#   ' PAROXETINE HCL',
#   ' MIRTAZAPINE',
#   ' ESCITALOPRAM OXALATE',
#   ' EFFEXOR XR',
#   ' CYMBALTA',
#   ' LEVOTHYROXINE SODIUM',
#   ' PERPHENAZINE',
#   ' ZIPRASIDONE HCL',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' TEMAZEPAM',
#   ' SERTRALINE HCL',
#   ' OMEPRAZOLE',
#   ' DIVALPROEX SODIUM',
#   ' CLOZAPINE',
#   ' AMITRIPTYLINE HCL',
#   ' LORAZEPAM',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' GABAPENTIN',
#   ' BUPROPION XL',
#   ' SIMVASTATIN',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' VENLAFAXINE HCL',
#   ' NORTRIPTYLINE HCL',
#   ' LITHIUM CARBONATE',
#   ' LAMOTRIGINE',
#   ' DOXEPIN HCL',
#   ' ABILIFY',
#   ' ALPRAZOLAM',
#   ' TOPIRAMATE'],
#  ['GABAPENTIN',
#   ' PRAMIPEXOLE DIHYDROCHLORIDE',
#   ' ROPINIROLE HCL',
#   ' ZALEPLON',
#   ' FLUTICASONE PROPIONATE',
#   ' ZOLPIDEM TARTRATE'],
#  ['SERTRALINE HCL', ' BUSPIRONE HCL', ' TRAZODONE HCL'],
#  ['TRAMADOL HCL', ' HYDROCODONE-ACETAMINOPHEN'],
#  ['AMOXICILLIN'],
#  ['SUPREP',
#   ' OMEPRAZOLE',
#   ' METOCLOPRAMIDE HCL',
#   ' NEXIUM',
#   ' BUDESONIDE EC',
#   ' BALSALAZIDE DISODIUM',
#   ' ASACOL HD',
#   ' RANITIDINE HCL',
#   ' POLYETHYLENE GLYCOL 3350',
#   ' PANTOPRAZOLE SODIUM',
#   ' PENTASA',
#   ' LINZESS',
#   ' DICYCLOMINE HCL',
#   ' AZATHIOPRINE',
#   ' ONDANSETRON HCL'],
#  ['CEPHALEXIN', ' PREDNISONE', ' LISINOPRIL'],
#  ['BUSPIRONE HCL',
#   ' HYDROXYZINE PAMOATE',
#   ' BUPROPION HCL SR',
#   ' ZOLPIDEM TARTRATE ER',
#   ' DIAZEPAM',
#   ' PAROXETINE HCL',
#   ' AMPHETAMINE SALT COMBO',
#   ' MIRTAZAPINE',
#   ' METHYLPHENIDATE HCL',
#   ' DOXEPIN HCL',
#   ' CYMBALTA',
#   ' RISPERDAL CONSTA',
#   ' AMANTADINE',
#   ' ALPRAZOLAM',
#   ' BENZTROPINE MESYLATE',
#   ' CITALOPRAM HBR',
#   ' TRAZODONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' LAMOTRIGINE',
#   ' CLONAZEPAM',
#   ' ZOLOFT',
#   ' SAPHRIS',
#   ' FLUOXETINE HCL',
#   ' DIVALPROEX SODIUM',
#   ' LORAZEPAM',
#   ' QUETIAPINE FUMARATE',
#   ' FLUVOXAMINE MALEATE',
#   ' MODAFINIL',
#   ' DIVALPROEX SODIUM ER',
#   ' RISPERIDONE',
#   ' METHYLPHENIDATE ER',
#   ' TRIAZOLAM',
#   ' GABAPENTIN',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL',
#   ' HYDROXYZINE HCL',
#   ' OLANZAPINE',
#   ' CARISOPRODOL',
#   ' LITHIUM CARBONATE',
#   ' CLONIDINE HCL',
#   ' TEMAZEPAM',
#   ' ABILIFY',
#   ' PROPRANOLOL HCL'],
#  ['MYCOPHENOLATE MOFETIL',
#   ' GABAPENTIN',
#   ' PYRIDOSTIGMINE BROMIDE',
#   ' GAMMAGARD LIQUID',
#   ' MESTINON',
#   ' AZATHIOPRINE',
#   ' PREDNISONE'],
#  ['ADVAIR DISKUS',
#   ' ADCIRCA',
#   ' MONTELUKAST SODIUM',
#   ' FUROSEMIDE',
#   ' AZITHROMYCIN',
#   ' SPIRONOLACTONE',
#   ' PROAIR HFA',
#   ' QVAR',
#   ' SPIRIVA',
#   ' PREDNISONE',
#   ' FLUCONAZOLE'],
#  ['CEPHALEXIN',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' OXYCODONE-ACETAMINOPHEN',
#   ' DIAZEPAM',
#   ' ONDANSETRON ODT',
#   ' PREDNISONE'],
#  ['AMOXICILLIN'],
#  ['FLUOXETINE HCL',
#   ' VENTOLIN HFA',
#   ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#   ' AMOXICILLIN',
#   ' PAROXETINE HCL',
#   ' RANITIDINE HCL',
#   ' GLIMEPIRIDE',
#   ' HYDROCHLOROTHIAZIDE',
#   ' PREDNISONE',
#   ' TRIAMTERENE-HYDROCHLOROTHIAZID',
#   ' ROPINIROLE HCL',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' CITALOPRAM HBR',
#   ' CRESTOR',
#   ' FLUTICASONE PROPIONATE',
#   ' OMEPRAZOLE',
#   ' METOPROLOL TARTRATE',
#   ' AMLODIPINE BESYLATE',
#   ' DONEPEZIL HCL',
#   ' LOSARTAN POTASSIUM',
#   ' CIPROFLOXACIN HCL',
#   ' SIMVASTATIN',
#   ' LISINOPRIL',
#   ' PROAIR HFA',
#   ' METFORMIN HCL',
#   ' TRAMADOL HCL',
#   ' SPIRONOLACTONE',
#   ' MONTELUKAST SODIUM',
#   ' LEVOTHYROXINE SODIUM'],
#  ['HUMALOG',
#   ' NOVOLOG',
#   ' PIOGLITAZONE HCL',
#   ' SIMVASTATIN',
#   ' GLUMETZA',
#   ' NIASPAN',
#   ' LOVAZA',
#   ' HUMALOG MIX 50-50',
#   ' LIPITOR',
#   ' LANTUS SOLOSTAR',
#   ' ATORVASTATIN CALCIUM',
#   ' BD ULTRA-FINE PEN NEEDLE',
#   ' HYDROCORTISONE',
#   ' NOVOLOG FLEXPEN',
#   ' JANUMET',
#   ' FENOFIBRATE',
#   ' HUMALOG MIX 75-25',
#   ' METFORMIN HCL',
#   ' HUMULIN N',
#   ' METHIMAZOLE',
#   ' JANUVIA',
#   ' GLIPIZIDE',
#   ' HUMULIN 70-30',
#   ' CRESTOR',
#   ' INSULIN SYRINGE',
#   ' TRADJENTA',
#   ' AMLODIPINE BESYLATE',
#   ' METFORMIN HCL ER',
#   ' LOSARTAN POTASSIUM',
#   ' NOVOLOG MIX 70-30 FLEXPEN',
#   ' LANTUS',
#   ' CARVEDILOL',
#   ' PRAVASTATIN SODIUM',
#   ' RAMIPRIL',
#   ' LEVOTHYROXINE SODIUM',
#   ' SYNTHROID',
#   ' LISINOPRIL'],
#  ['VOLTAREN',
#   ' MELOXICAM',
#   ' IBUPROFEN',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' OXYCODONE-ACETAMINOPHEN'],
#  ['AMOXICILLIN'],
#  ['AMOXICILLIN'],
#  ['SIMVASTATIN',
#   ' INSULIN SYRINGE',
#   ' FAMOTIDINE',
#   ' KLOR-CON M20',
#   ' HYDROCODONE-ACETAMINOPHEN',
#   ' HYDROCHLOROTHIAZIDE',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' FENOFIBRATE',
#   ' METFORMIN HCL',
#   ' HUMULIN N',
#   ' SANDOSTATIN LAR',
#   ' HUMULIN 70-30',
#   ' METOPROLOL TARTRATE',
#   ' AMITRIPTYLINE HCL',
#   ' ESTRADIOL',
#   ' AMLODIPINE BESYLATE',
#   ' ULTRA COMFORT',
#   ' ATORVASTATIN CALCIUM',
#   ' LOSARTAN POTASSIUM',
#   ' NIFEDIPINE ER',
#   ' LEVOTHYROXINE SODIUM',
#   ' TRIAMTERENE-HCTZ',
#   ' FUROSEMIDE',
#   ' LISINOPRIL',
#   ' PANTOPRAZOLE SODIUM',
#   ' NOVOLIN N',
#   ' SYNTHROID',
#   ' NEXIUM',
#   ' QUINAPRIL HCL',
#   ' OMEPRAZOLE',
#   ' NOVOLIN R',
#   ' CRESTOR',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' BD ULTRA-FINE PEN NEEDLE',
#   ' METOPROLOL SUCCINATE',
#   ' LEVOXYL',
#   ' ALLOPURINOL',
#   ' CLOPIDOGREL',
#   ' POTASSIUM CHLORIDE',
#   ' METFORMIN HCL ER',
#   ' GLIMEPIRIDE',
#   ' GABAPENTIN',
#   ' HUMULIN R',
#   ' ATENOLOL',
#   ' PRAVASTATIN SODIUM',
#   ' TRANDOLAPRIL',
#   ' TESTOSTERONE CYPIONATE',
#   ' PREDNISONE',
#   ' NOVOLIN 70-30'],
#  ['SERTRALINE HCL',
#   ' ESCITALOPRAM OXALATE',
#   ' NAMENDA',
#   ' QUETIAPINE FUMARATE',
#   ' TRAZODONE HCL',
#   ' DONEPEZIL HCL',
#   ' GALANTAMINE HBR'],
#  ['SIMVASTATIN',
#   ' XARELTO',
#   ' HYDRALAZINE HCL',
#   ' TOPROL XL',
#   ' DIOVAN',
#   ' WARFARIN SODIUM',
#   ' ATORVASTATIN CALCIUM',
#   ' MULTAQ',
#   ' VERAPAMIL ER',
#   ' COUMADIN',
#   ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#   ' VYTORIN',
#   ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#   ' METOPROLOL TARTRATE',
#   ' AMLODIPINE BESYLATE-BENAZEPRIL',
#   ' DILTIAZEM ER',
#   ' BYSTOLIC',
#   ' ISOSORBIDE MONONITRATE ER',
#   ' ALLOPURINOL',
#   ' AMIODARONE HCL',
#   ' CLOPIDOGREL',
#   ' HYDROCHLOROTHIAZIDE',
#   ' AMLODIPINE BESYLATE',
#   ' CARVEDILOL',
#   ' LOSARTAN POTASSIUM',
#   ' KLOR-CON 10',
#   ' PRADAXA',
#   ' DIGOX',
#   ' ATENOLOL',
#   ' PRAVASTATIN SODIUM',
#   ' DILTIAZEM 24HR ER',
#   ' POTASSIUM CHLORIDE',
#   ' FUROSEMIDE',
#   ' EFFIENT',
#   ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#   ' METOPROLOL SUCCINATE',
#   ' SPIRONOLACTONE',
#   ' NITROSTAT',
#   ' LISINOPRIL',
#   ' QUINAPRIL HCL'],
#  ['CLONAZEPAM',
#   ' TRIHEXYPHENIDYL HCL',
#   ' PERPHENAZINE',
#   ' ROZEREM',
#   ' ESCITALOPRAM OXALATE',
#   ' HALOPERIDOL DECANOATE',
#   ' INVEGA',
#   ' BENZTROPINE MESYLATE',
#   ' DIVALPROEX SODIUM',
#   ' SERTRALINE HCL',
#   ' TRAZODONE HCL',
#   ' CLOZAPINE',
#   ' QUETIAPINE FUMARATE',
#   ' OLANZAPINE',
#   ' BUPROPION HCL SR',
#   ' LUNESTA',
#   ' LITHIUM CARBONATE',
#   ' ABILIFY',
#   ' ALPRAZOLAM',
#   ' FLUOXETINE HCL',
#   ' SEROQUEL XR',
#   ' CARBAMAZEPINE XR',
#   ' PAROXETINE HCL',
#   ' MIRTAZAPINE',
#   ' CYMBALTA',
#   ' RISPERDAL CONSTA',
#   ' PRISTIQ ER',
#   ' ZIPRASIDONE HCL',
#   ' CITALOPRAM HBR',
#   ' BUSPIRONE HCL',
#   ' ZOLPIDEM TARTRATE',
#   ' DIVALPROEX SODIUM ER',
#   ' LORAZEPAM',
#   ' FLUPHENAZINE DECANOATE',
#   ' RISPERIDONE',
#   ' GABAPENTIN',
#   ' BUPROPION XL',
#   ' ATENOLOL',
#   ' HALOPERIDOL',
#   ' VENLAFAXINE HCL ER',
#   ' PROPRANOLOL HCL',
#   ' LAMOTRIGINE',
#   ' INVEGA SUSTENNA',
#   ' TOPIRAMATE']]

# %%
initSet = createInitSet(simpDat)
initSet
# Out:
# {frozenset({' ABILIFY',
#             ' ALLOPURINOL',
#             ' ALPRAZOLAM',
#             ' AMLODIPINE BESYLATE',
#             ' AMLODIPINE BESYLATE-BENAZEPRIL',
#             ' ATENOLOL',
#             ' ATENOLOL-CHLORTHALIDONE',
#             ' ATORVASTATIN CALCIUM',
#             ' AZITHROMYCIN',
#             ' BENAZEPRIL HCL',
#             ' BUMETANIDE',
#             ' BYSTOLIC',
#             ' CALCITRIOL',
#             ' CALCIUM ACETATE',
#             ' CARISOPRODOL',
#             ' CARVEDILOL',
#             ' CIPROFLOXACIN HCL',
#             ' CLONIDINE HCL',
#             ' CLOPIDOGREL',
#             ' DIAZEPAM',
#             ' DIOVAN',
#             ' FENOFIBRATE',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' GLYBURIDE',
#             ' HYDRALAZINE HCL',
#             ' HYDROCHLOROTHIAZIDE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' IRBESARTAN',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' KLOR-CON M10',
#             ' LABETALOL HCL',
#             ' LANTUS',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#             ' LOSARTAN POTASSIUM',
#             ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#             ' LOVASTATIN',
#             ' MEGESTROL ACETATE',
#             ' MELOXICAM',
#             ' METOLAZONE',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' MIDODRINE HCL',
#             ' MINOXIDIL',
#             ' NEXIUM',
#             ' NIFEDICAL XL',
#             ' NIFEDIPINE ER',
#             ' NOVOLOG',
#             ' OMEPRAZOLE',
#             ' OXYBUTYNIN CHLORIDE',
#             ' OXYCODONE HCL',
#             ' PANTOPRAZOLE SODIUM',
#             ' POTASSIUM CHLORIDE',
#             ' PRAVASTATIN SODIUM',
#             ' PREDNISONE',
#             ' RANITIDINE HCL',
#             ' RENVELA',
#             ' SENSIPAR',
#             ' SERTRALINE HCL',
#             ' SIMVASTATIN',
#             ' SPIRONOLACTONE',
#             ' TAMSULOSIN HCL',
#             ' TEMAZEPAM',
#             ' TRAMADOL HCL',
#             ' ZOLPIDEM TARTRATE',
#             'DOXAZOSIN MESYLATE'}): 1,
#  frozenset({' AMOXICILLIN', ' HYDROCODONE-ACETAMINOPHEN', 'CEPHALEXIN'}): 1,
#  frozenset({' AMOXICILLIN', ' CLINDAMYCIN HCL', 'CEPHALEXIN'}): 1,
#  frozenset({'AMOXICILLIN'}): 1,
#  frozenset({' ACTONEL',
#             ' ALLOPURINOL',
#             ' AMLODIPINE BESYLATE',
#             ' AMOXICILLIN',
#             ' ANDROGEL',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' BENAZEPRIL HCL',
#             ' BUPROPION HCL',
#             ' CALCITONIN-SALMON',
#             ' CHLORTHALIDONE',
#             ' CLONIDINE HCL',
#             ' CLOPIDOGREL',
#             ' CRESTOR',
#             ' DIAZEPAM',
#             ' DIPHENOXYLATE-ATROPINE',
#             ' DONEPEZIL HCL',
#             ' ENALAPRIL MALEATE',
#             ' ESCITALOPRAM OXALATE',
#             ' ESTRADIOL',
#             ' FLUTICASONE PROPIONATE',
#             ' FOSRENOL',
#             ' GABAPENTIN',
#             ' GLIPIZIDE',
#             ' HYDRALAZINE HCL',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' HYDROXYZINE HCL',
#             ' INDERAL LA',
#             ' LABETALOL HCL',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LORAZEPAM',
#             ' LOSARTAN POTASSIUM',
#             ' METFORMIN HCL',
#             ' METHYLPHENIDATE HCL',
#             ' METOPROLOL TARTRATE',
#             ' NEXIUM',
#             ' NIFEDIPINE ER',
#             ' NORTRIPTYLINE HCL',
#             ' NOVOLIN N',
#             ' OMEPRAZOLE',
#             ' PANTOPRAZOLE SODIUM',
#             ' PRANDIN',
#             ' PRAVASTATIN SODIUM',
#             ' QUETIAPINE FUMARATE',
#             ' RANITIDINE HCL',
#             ' RENVELA',
#             ' SENSIPAR',
#             ' SIMVASTATIN',
#             ' SYNTHROID',
#             ' WARFARIN SODIUM',
#             ' ZOLPIDEM TARTRATE',
#             'PIOGLITAZONE HCL'}): 1,
#  frozenset({' CLINDAMYCIN HCL',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' OXYCODONE-ACETAMINOPHEN',
#             ' PENICILLIN V POTASSIUM',
#             'AMOXICILLIN'}): 1,
#  frozenset({' CLINDAMYCIN HCL', ' IBUPROFEN', 'AMOXICILLIN'}): 1,
#  frozenset({'CEPHALEXIN'}): 1,
#  frozenset({' ADVAIR DISKUS',
#             ' ALBUTEROL SULFATE',
#             ' AMLODIPINE BESYLATE',
#             ' AMOX TR-POTASSIUM CLAVULANATE',
#             ' ATORVASTATIN CALCIUM',
#             ' AZITHROMYCIN',
#             ' BUDESONIDE',
#             ' CARBIDOPA-LEVODOPA',
#             ' CEPHALEXIN',
#             ' CIPROFLOXACIN HCL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLOPIDOGREL',
#             ' DIGOX',
#             ' DILTIAZEM 24HR CD',
#             ' DIVALPROEX SODIUM',
#             ' DONEPEZIL HCL',
#             ' ENALAPRIL MALEATE',
#             ' ENTACAPONE',
#             ' ENULOSE',
#             ' ERYTHROMYCIN',
#             ' ESCITALOPRAM OXALATE',
#             ' FAMOTIDINE',
#             ' FENTANYL',
#             ' FLUTICASONE PROPIONATE',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' GLIPIZIDE',
#             ' HYDROCHLOROTHIAZIDE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' IBUPROFEN',
#             ' IPRATROPIUM-ALBUTEROL',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' LANTUS',
#             ' LATANOPROST',
#             ' LEVEMIR',
#             ' LEVETIRACETAM',
#             ' LEVOFLOXACIN',
#             ' LEVOTHYROXINE SODIUM',
#             ' LIDOCAINE',
#             ' LIDODERM',
#             ' LISINOPRIL',
#             ' LORAZEPAM',
#             ' LOSARTAN POTASSIUM',
#             ' METFORMIN HCL',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' MONTELUKAST SODIUM',
#             ' MORPHINE SULFATE',
#             ' NOVOLOG',
#             ' NYSTATIN',
#             ' OMEPRAZOLE',
#             ' OXYCODONE HCL',
#             ' POLYETHYLENE GLYCOL 3350',
#             ' POTASSIUM CHLORIDE',
#             ' PRAVASTATIN SODIUM',
#             ' PREDNISONE',
#             ' PREVACID',
#             ' PROPRANOLOL HCL',
#             ' PROTONIX',
#             ' QUETIAPINE FUMARATE',
#             ' RANEXA',
#             ' RISPERIDONE',
#             ' SERTRALINE HCL',
#             ' SIMVASTATIN',
#             ' SPIRIVA',
#             ' SPIRONOLACTONE',
#             ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#             ' TAMSULOSIN HCL',
#             ' TRAVATAN Z',
#             ' TRAZODONE HCL',
#             ' TRIAMCINOLONE ACETONIDE',
#             ' VOLTAREN',
#             ' WARFARIN SODIUM',
#             ' XARELTO',
#             'CARAFATE'}): 1,
#  frozenset({' BUPROPION HCL SR',
#             ' CLONAZEPAM',
#             ' RISPERIDONE',
#             ' ZOLPIDEM TARTRATE',
#             'CYMBALTA'}): 1,
#  frozenset({' CHLORHEXIDINE GLUCONATE',
#             ' HYDROCODONE BIT-IBUPROFEN',
#             'AMOXICILLIN'}): 1,
#  frozenset({' ALLOPURINOL',
#             ' AZATHIOPRINE',
#             ' HUMIRA',
#             ' HYDROXYCHLOROQUINE SULFATE',
#             ' METHOTREXATE',
#             ' PREDNISONE',
#             ' SULFAZINE',
#             'GABAPENTIN'}): 1,
#  frozenset({' IBUPROFEN', 'AMOXICILLIN'}): 1,
#  frozenset({' ASACOL',
#             ' COLESTIPOL HCL',
#             ' DELZICOL',
#             ' HUMIRA',
#             ' LACTULOSE',
#             ' LANSOPRAZOLE',
#             ' METOLAZONE',
#             ' NEXIUM',
#             ' OMEPRAZOLE',
#             ' PANTOPRAZOLE SODIUM',
#             ' RANITIDINE HCL',
#             ' SUCRALFATE',
#             ' SUPREP',
#             'CARAFATE'}): 1,
#  frozenset({' ALPRAZOLAM',
#             ' BETAMETHASONE DIPROPIONATE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' NEOMYCIN-POLYMYXIN-DEXAMETH',
#             ' POLYETHYLENE GLYCOL 3350',
#             ' PROMETHEGAN',
#             'ZOLPIDEM TARTRATE'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' AMPHETAMINE SALT COMBO',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' BUSPIRONE HCL',
#             ' CITALOPRAM HBR',
#             ' CLOZAPINE',
#             ' CYMBALTA',
#             ' DEXTROAMPHETAMINE SULFATE',
#             ' DIAZEPAM',
#             ' DIVALPROEX SODIUM ER',
#             ' DONEPEZIL HCL',
#             ' DOXEPIN HCL',
#             ' ESCITALOPRAM OXALATE',
#             ' FLUOXETINE HCL',
#             ' FLUPHENAZINE HCL',
#             ' FLUVOXAMINE MALEATE',
#             ' HALOPERIDOL',
#             ' HYDROXYZINE HCL',
#             ' HYDROXYZINE PAMOATE',
#             ' INVEGA SUSTENNA',
#             ' LAMOTRIGINE',
#             ' LATUDA',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' METHYLPHENIDATE ER',
#             ' METHYLPHENIDATE HCL',
#             ' MIRTAZAPINE',
#             ' NORTRIPTYLINE HCL',
#             ' OLANZAPINE',
#             ' PAROXETINE HCL',
#             ' PRISTIQ ER',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERDAL CONSTA',
#             ' RISPERIDONE',
#             ' RISPERIDONE ODT',
#             ' SEROQUEL',
#             ' SEROQUEL XR',
#             ' SERTRALINE HCL',
#             ' STRATTERA',
#             ' THIOTHIXENE',
#             ' TOPIRAMATE',
#             ' TRAZODONE HCL',
#             ' TRIHEXYPHENIDYL HCL',
#             ' VENLAFAXINE HCL',
#             ' VENLAFAXINE HCL ER',
#             ' VIIBRYD',
#             ' ZIPRASIDONE HCL',
#             ' ZOLPIDEM TARTRATE',
#             'CLONAZEPAM'}): 1,
#  frozenset({' LEVOTHYROXINE SODIUM',
#             ' OXYCODONE HCL',
#             ' PREDNISONE',
#             ' TARGRETIN',
#             'OMEPRAZOLE'}): 1,
#  frozenset({' ACYCLOVIR',
#             ' DEXAMETHASONE',
#             ' GABAPENTIN',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' HYDROMORPHONE HCL',
#             ' LORAZEPAM',
#             ' METOCLOPRAMIDE HCL',
#             ' METOPROLOL TARTRATE',
#             ' OMEPRAZOLE',
#             ' ONDANSETRON HCL',
#             ' PROCHLORPERAZINE MALEATE',
#             ' REVLIMID',
#             ' ZOLPIDEM TARTRATE',
#             'LEVOFLOXACIN'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' AMOXAPINE',
#             ' AMPHETAMINE SALT COMBO',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL SR',
#             ' BUSPIRONE HCL',
#             ' CARBAMAZEPINE XR',
#             ' CITALOPRAM HBR',
#             ' CLOMIPRAMINE HCL',
#             ' CLONAZEPAM',
#             ' CLORAZEPATE DIPOTASSIUM',
#             ' CLOZAPINE',
#             ' CYMBALTA',
#             ' DEXTROAMPHETAMINE-AMPHETAMINE',
#             ' DIAZEPAM',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' DONEPEZIL HCL',
#             ' ESCITALOPRAM OXALATE',
#             ' FLUOXETINE HCL',
#             ' FLUPHENAZINE HCL',
#             ' FLURAZEPAM HCL',
#             ' FLUVOXAMINE MALEATE',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' LAMOTRIGINE',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' MAPROTILINE HCL',
#             ' METHYLPHENIDATE ER',
#             ' METHYLPHENIDATE HCL',
#             ' MIRTAZAPINE',
#             ' NEFAZODONE HCL',
#             ' NORTRIPTYLINE HCL',
#             ' OLANZAPINE',
#             ' OXCARBAZEPINE',
#             ' PAROXETINE HCL',
#             ' PERPHENAZINE',
#             ' PRISTIQ ER',
#             ' PROPRANOLOL HCL',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERIDONE',
#             ' SERTRALINE HCL',
#             ' TEMAZEPAM',
#             ' THIOTHIXENE',
#             ' TOPIRAMATE',
#             ' TRAZODONE HCL',
#             ' TRIAZOLAM',
#             ' VENLAFAXINE HCL ER',
#             ' VIIBRYD',
#             ' ZIPRASIDONE HCL',
#             ' ZOLPIDEM TARTRATE',
#             'DESIPRAMINE HCL'}): 1,
#  frozenset({' ALLOPURINOL',
#             ' AMIODARONE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' AMLODIPINE BESYLATE-BENAZEPRIL',
#             ' ATORVASTATIN CALCIUM',
#             ' CARVEDILOL',
#             ' CITALOPRAM HBR',
#             ' CLONIDINE HCL',
#             ' CLOPIDOGREL',
#             ' CRESTOR',
#             ' DIGOX',
#             ' DIGOXIN',
#             ' DILTIAZEM HCL',
#             ' ENALAPRIL MALEATE',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' GUANFACINE HCL',
#             ' HYDROCHLOROTHIAZIDE',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' KLOR-CON M20',
#             ' LABETALOL HCL',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#             ' LOSARTAN POTASSIUM',
#             ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' MINOXIDIL',
#             ' NAPROXEN',
#             ' NIFEDIPINE ER',
#             ' NITROSTAT',
#             ' OMEPRAZOLE',
#             ' PANTOPRAZOLE SODIUM',
#             ' POTASSIUM CHLORIDE',
#             ' PRADAXA',
#             ' RAMIPRIL',
#             ' SIMVASTATIN',
#             ' SOTALOL',
#             ' SOTALOL AF',
#             ' SPIRONOLACTONE',
#             ' TRIAMTERENE-HCTZ',
#             ' TRIAMTERENE-HYDROCHLOROTHIAZID',
#             ' VYTORIN',
#             ' WARFARIN SODIUM',
#             ' XARELTO',
#             ' ZETIA',
#             ' ZOLPIDEM TARTRATE',
#             'CLONAZEPAM'}): 1,
#  frozenset({'DIOVAN'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' AMITRIPTYLINE HCL',
#             ' AMPHETAMINE SALT COMBO',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' BUSPIRONE HCL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CYMBALTA',
#             ' DIAZEPAM',
#             ' DIVALPROEX SODIUM ER',
#             ' ESCITALOPRAM OXALATE',
#             ' FLUOXETINE HCL',
#             ' FLUPHENAZINE HCL',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' LAMOTRIGINE',
#             ' LATUDA',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' METHYLPHENIDATE HCL',
#             ' MIRTAZAPINE',
#             ' OLANZAPINE',
#             ' PAROXETINE HCL',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERDAL CONSTA',
#             ' RISPERIDONE',
#             ' SEROQUEL XR',
#             ' SERTRALINE HCL',
#             ' TRAZODONE HCL',
#             ' VENLAFAXINE HCL ER',
#             ' ZIPRASIDONE HCL',
#             ' ZOLPIDEM TARTRATE',
#             'HYDROXYZINE PAMOATE'}): 1,
#  frozenset({' ADVAIR DISKUS',
#             ' ALPRAZOLAM',
#             ' ASMANEX',
#             ' AZITHROMYCIN',
#             ' BD ULTRA-FINE PEN NEEDLE',
#             ' CLONAZEPAM',
#             ' COMBIVENT',
#             ' COMBIVENT RESPIMAT',
#             ' DALIRESP',
#             ' DIOVAN',
#             ' DULERA',
#             ' DYMISTA',
#             ' FLOVENT HFA',
#             ' FLUTICASONE PROPIONATE',
#             ' FORADIL',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' HUMALOG',
#             ' JANUVIA',
#             ' LANTUS SOLOSTAR',
#             ' LEVEMIR FLEXPEN',
#             ' LEVOTHYROXINE SODIUM',
#             ' METFORMIN HCL',
#             ' MONTELUKAST SODIUM',
#             ' NASONEX',
#             ' NEXIUM',
#             ' NOVOLOG FLEXPEN',
#             ' PRAMIPEXOLE DIHYDROCHLORIDE',
#             ' PREDNISONE',
#             ' PROAIR HFA',
#             ' QVAR',
#             ' ROPINIROLE HCL',
#             ' SIMVASTATIN',
#             ' SPIRIVA',
#             ' SYMBICORT',
#             ' SYNTHROID',
#             ' TRADJENTA',
#             ' TRAZODONE HCL',
#             ' TUDORZA PRESSAIR',
#             ' VENTOLIN HFA',
#             ' ZOLPIDEM TARTRATE',
#             'PROVENTIL HFA'}): 1,
#  frozenset({' ALPRAZOLAM',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' FENTANYL',
#             ' INDERAL LA',
#             ' LAMOTRIGINE',
#             ' METHADONE HCL',
#             ' METHYLPHENIDATE ER',
#             ' OXYCODONE-ACETAMINOPHEN',
#             ' PRISTIQ ER',
#             ' RISPERIDONE',
#             ' SERTRALINE HCL',
#             ' TRAZODONE HCL',
#             ' VALIUM',
#             'FLUOXETINE HCL'}): 1,
#  frozenset({' AMMONIUM LACTATE',
#             ' HYDROCHLOROTHIAZIDE',
#             ' MENTAX',
#             ' METFORMIN HCL',
#             ' PRAVASTATIN SODIUM',
#             'LEVOFLOXACIN'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' AMITRIPTYLINE HCL',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL',
#             ' BUPROPION HCL SR',
#             ' BUSPIRONE HCL',
#             ' CARBAMAZEPINE',
#             ' CARBAMAZEPINE XR',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLOZAPINE',
#             ' CYMBALTA',
#             ' DIAZEPAM',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' DOXEPIN HCL',
#             ' ESCITALOPRAM OXALATE',
#             ' FLUOXETINE HCL',
#             ' FLUPHENAZINE HCL',
#             ' FLUVOXAMINE MALEATE',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' HYDROXYZINE HCL',
#             ' HYDROXYZINE PAMOATE',
#             ' INVEGA',
#             ' INVEGA SUSTENNA',
#             ' LAMOTRIGINE',
#             ' LEVOTHYROXINE SODIUM',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' MIRTAZAPINE',
#             ' OLANZAPINE',
#             ' OXCARBAZEPINE',
#             ' PAROXETINE HCL',
#             ' PERPHENAZINE',
#             ' PRAZOSIN HCL',
#             ' PROPRANOLOL HCL',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERDAL CONSTA',
#             ' SERTRALINE HCL',
#             ' STRATTERA',
#             ' TEMAZEPAM',
#             ' THIOTHIXENE',
#             ' TRAZODONE HCL',
#             ' TRIHEXYPHENIDYL HCL',
#             ' VALPROIC ACID',
#             ' VENLAFAXINE HCL ER',
#             ' ZIPRASIDONE HCL',
#             ' ZOLPIDEM TARTRATE',
#             'RISPERIDONE'}): 1,
#  frozenset({' ADVAIR DISKUS',
#             ' ATROVENT HFA',
#             ' AZELASTINE HCL',
#             ' AZITHROMYCIN',
#             ' CEFUROXIME',
#             ' FLOVENT DISKUS',
#             ' FLOVENT HFA',
#             ' FLUTICASONE PROPIONATE',
#             ' LEVOFLOXACIN',
#             ' METHYLPREDNISOLONE',
#             ' MONTELUKAST SODIUM',
#             ' NASONEX',
#             ' OMEPRAZOLE',
#             ' PANTOPRAZOLE SODIUM',
#             ' PREDNISONE',
#             ' PROAIR HFA',
#             ' PULMICORT FLEXHALER',
#             ' QVAR',
#             ' SINGULAIR',
#             ' SPIRIVA',
#             ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#             ' SYMBICORT',
#             ' TEMAZEPAM',
#             'VENTOLIN HFA'}): 1,
#  frozenset({' AMOX TR-POTASSIUM CLAVULANATE',
#             ' BUDESONIDE',
#             ' DOXYCYCLINE HYCLATE',
#             ' FAMOTIDINE',
#             ' IPRATROPIUM-ALBUTEROL',
#             ' ISENTRESS',
#             ' KALETRA',
#             ' NAMENDA',
#             ' NORVIR',
#             ' PREZISTA',
#             ' SANTYL',
#             ' TRUVADA',
#             ' VANCOMYCIN HCL',
#             'LEVOFLOXACIN'}): 1,
#  frozenset({' ABILIFY',
#             ' AMANTADINE',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' BUSPIRONE HCL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLOZAPINE',
#             ' CYMBALTA',
#             ' DIAZEPAM',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' EFFEXOR XR',
#             ' ESCITALOPRAM OXALATE',
#             ' FLUOXETINE HCL',
#             ' FLUPHENAZINE DECANOATE',
#             ' FLUPHENAZINE HCL',
#             ' FLUVOXAMINE MALEATE',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' HALOPERIDOL DECANOATE',
#             ' HYDROXYZINE PAMOATE',
#             ' LAMOTRIGINE',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' LUNESTA',
#             ' MIRTAZAPINE',
#             ' MODAFINIL',
#             ' OLANZAPINE',
#             ' OLANZAPINE ODT',
#             ' PAROXETINE HCL',
#             ' PRISTIQ ER',
#             ' PROPRANOLOL HCL',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERDAL CONSTA',
#             ' RISPERIDONE',
#             ' SERTRALINE HCL',
#             ' THIORIDAZINE HCL',
#             ' THIOTHIXENE',
#             ' TOPIRAMATE',
#             ' TRAZODONE HCL',
#             ' VENLAFAXINE HCL ER',
#             'TRIFLUOPERAZINE HCL'}): 1,
#  frozenset({' ALENDRONATE SODIUM',
#             ' ALLOPURINOL',
#             ' AMITRIPTYLINE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' AMLODIPINE BESYLATE-BENAZEPRIL',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' ATRIPLA',
#             ' BUPROPION HCL SR',
#             ' CARVEDILOL',
#             ' CHOLESTYRAMINE',
#             ' CLONIDINE HCL',
#             ' DILTIAZEM HCL',
#             ' DIOVAN',
#             ' DIOVAN HCT',
#             ' FLUTICASONE PROPIONATE',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' GLIMEPIRIDE',
#             ' GLIPIZIDE',
#             ' HUMALOG',
#             ' HYDROCHLOROTHIAZIDE',
#             ' INSULIN SYRINGE',
#             ' IRBESARTAN',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' KLOR-CON M20',
#             ' LANTUS',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#             ' LOSARTAN POTASSIUM',
#             ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#             ' METFORMIN HCL',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' MONTELUKAST SODIUM',
#             ' NAPROXEN',
#             ' NIFEDIPINE ER',
#             ' OMEPRAZOLE',
#             ' PANTOPRAZOLE SODIUM',
#             ' POTASSIUM CHLORIDE',
#             ' PRAVASTATIN SODIUM',
#             ' PROAIR HFA',
#             ' RANITIDINE HCL',
#             ' REYATAZ',
#             ' SERTRALINE HCL',
#             ' SIMVASTATIN',
#             ' SPIRONOLACTONE',
#             ' TOLTERODINE TARTRATE',
#             ' TRAMADOL HCL',
#             ' TRAZODONE HCL',
#             ' TRIAMTERENE-HCTZ',
#             ' TRIZIVIR',
#             ' TRUVADA',
#             ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#             ' VERAPAMIL ER',
#             ' WELCHOL',
#             ' ZETIA',
#             'BENAZEPRIL HCL'}): 1,
#  frozenset({'MORPHINE SULFATE ER'}): 1,
#  frozenset({' ABACAVIR',
#             ' DOXYCYCLINE HYCLATE',
#             ' EPZICOM',
#             ' FLUCONAZOLE',
#             ' INVANZ',
#             ' KALETRA',
#             ' NORVIR',
#             ' REYATAZ',
#             ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#             ' SUSTIVA',
#             ' TRIZIVIR',
#             ' VANCOMYCIN HCL',
#             ' VIREAD',
#             'LEVOFLOXACIN'}): 1,
#  frozenset({' AMITRIPTYLINE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' ATORVASTATIN CALCIUM',
#             ' AZITHROMYCIN',
#             ' BENICAR',
#             ' CITALOPRAM HBR',
#             ' CYCLOBENZAPRINE HCL',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' HYDROCHLOROTHIAZIDE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' IBUPROFEN',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#             ' LORAZEPAM',
#             ' METFORMIN HCL',
#             ' METOPROLOL TARTRATE',
#             ' OMEPRAZOLE',
#             ' PREDNISONE',
#             ' PROAIR HFA',
#             ' RANITIDINE HCL',
#             ' SERTRALINE HCL',
#             ' SIMVASTATIN',
#             ' SYNTHROID',
#             ' TRAMADOL HCL',
#             ' VENTOLIN HFA',
#             ' WARFARIN SODIUM',
#             ' ZOLPIDEM TARTRATE',
#             'FLUOXETINE HCL'}): 1,
#  frozenset({' ATORVASTATIN CALCIUM',
#             ' CLONIDINE HCL',
#             ' FUROSEMIDE',
#             ' HYDRALAZINE HCL',
#             ' HYDROCHLOROTHIAZIDE',
#             ' LIDOCAINE-PRILOCAINE',
#             ' LISINOPRIL',
#             ' LOSARTAN POTASSIUM',
#             ' METOPROLOL TARTRATE',
#             ' NEXIUM',
#             ' NIFEDICAL XL',
#             ' NIFEDIPINE ER',
#             ' PRAVASTATIN SODIUM',
#             ' RENVELA',
#             ' SENSIPAR',
#             ' ZOLPIDEM TARTRATE',
#             'CALCIUM ACETATE'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' AMITRIPTYLINE HCL',
#             ' BENZTROPINE MESYLATE',
#             ' BUDEPRION SR',
#             ' BUPROPION HCL',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' BUSPIRONE HCL',
#             ' CARBAMAZEPINE',
#             ' CHLORPROMAZINE HCL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLOZAPINE',
#             ' CYMBALTA',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' ESCITALOPRAM OXALATE',
#             ' FLUOXETINE HCL',
#             ' FLUPHENAZINE DECANOATE',
#             ' FLUPHENAZINE HCL',
#             ' FLUVOXAMINE MALEATE',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' HALOPERIDOL DECANOATE',
#             ' HALOPERIDOL DECANOATE 100',
#             ' INVEGA SUSTENNA',
#             ' LAMOTRIGINE',
#             ' LEVOTHYROXINE SODIUM',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' LOXAPINE',
#             ' METFORMIN HCL',
#             ' MIRTAZAPINE',
#             ' NALTREXONE HCL',
#             ' OLANZAPINE',
#             ' OXCARBAZEPINE',
#             ' PAROXETINE HCL',
#             ' PRAZOSIN HCL',
#             ' PROPRANOLOL HCL',
#             ' QUETIAPINE FUMARATE',
#             ' SEROQUEL XR',
#             ' SERTRALINE HCL',
#             ' THIOTHIXENE',
#             ' TRAZODONE HCL',
#             ' TRIFLUOPERAZINE HCL',
#             ' TRIHEXYPHENIDYL HCL',
#             ' VENLAFAXINE HCL ER',
#             ' ZIPRASIDONE HCL',
#             'RISPERIDONE'}): 1,
#  frozenset({' ALLOPURINOL',
#             ' AMIODARONE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' ATORVASTATIN CALCIUM',
#             ' BUMETANIDE',
#             ' CARVEDILOL',
#             ' CLOPIDOGREL',
#             ' CRESTOR',
#             ' DIGOX',
#             ' DIGOXIN',
#             ' DIOVAN',
#             ' FUROSEMIDE',
#             ' HYDRALAZINE HCL',
#             ' ISOSORBIDE DINITRATE',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' KLOR-CON M20',
#             ' LISINOPRIL',
#             ' LOSARTAN POTASSIUM',
#             ' METOLAZONE',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' PANTOPRAZOLE SODIUM',
#             ' POTASSIUM CHLORIDE',
#             ' PRAVASTATIN SODIUM',
#             ' QUINAPRIL HCL',
#             ' SIMVASTATIN',
#             ' SPIRONOLACTONE',
#             ' TORSEMIDE',
#             ' WARFARIN SODIUM',
#             ' XARELTO',
#             ' ZETIA',
#             'NIFEDIPINE ER'}): 1,
#  frozenset({' IBUPROFEN', 'HYDROCODONE-ACETAMINOPHEN'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' AMITRIPTYLINE HCL',
#             ' BUPROPION HCL SR',
#             ' BUSPIRONE HCL',
#             ' CARBAMAZEPINE',
#             ' CLONAZEPAM',
#             ' DEXTROAMPHETAMINE-AMPHETAMINE',
#             ' DIAZEPAM',
#             ' DOXEPIN HCL',
#             ' ESCITALOPRAM OXALATE',
#             ' GABAPENTIN',
#             ' LAMOTRIGINE',
#             ' LATUDA',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' LOXAPINE',
#             ' METHYLPHENIDATE HCL',
#             ' MIRTAZAPINE',
#             ' OLANZAPINE',
#             ' QUETIAPINE FUMARATE',
#             ' SAPHRIS',
#             ' SERTRALINE HCL',
#             ' TOPIRAMATE',
#             ' TRAMADOL HCL',
#             ' TRAZODONE HCL',
#             ' ZIPRASIDONE HCL',
#             'AMPHETAMINE SALT COMBO'}): 1,
#  frozenset({' AMLODIPINE BESYLATE',
#             ' ATORVASTATIN CALCIUM',
#             ' LISINOPRIL',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' PRAVASTATIN SODIUM',
#             'CARVEDILOL'}): 1,
#  frozenset({' AMIODARONE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' ATENOLOL',
#             ' BISOPROLOL FUMARATE',
#             ' CARVEDILOL',
#             ' CLOPIDOGREL',
#             ' DIGOX',
#             ' DIGOXIN',
#             ' DILTIAZEM 24HR ER',
#             ' DILTIAZEM HCL',
#             ' FLECAINIDE ACETATE',
#             ' FUROSEMIDE',
#             ' HYDROCHLOROTHIAZIDE',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' LISINOPRIL',
#             ' LOSARTAN POTASSIUM',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' MUPIROCIN',
#             ' NADOLOL',
#             ' PANTOPRAZOLE SODIUM',
#             ' PRADAXA',
#             ' PRAVASTATIN SODIUM',
#             ' SIMVASTATIN',
#             ' SPIRONOLACTONE',
#             ' TIKOSYN',
#             ' VERAPAMIL HCL',
#             ' WARFARIN SODIUM',
#             'CEPHALEXIN'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' CARBIDOPA-LEVODOPA',
#             ' CHLORPROMAZINE HCL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CYMBALTA',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' DONEPEZIL HCL',
#             ' ESCITALOPRAM OXALATE',
#             ' EXELON',
#             ' FLUOXETINE HCL',
#             ' GABAPENTIN',
#             ' GALANTAMINE HBR',
#             ' INVEGA',
#             ' LAMOTRIGINE',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' MIRTAZAPINE',
#             ' NAMENDA',
#             ' OLANZAPINE',
#             ' OMEPRAZOLE',
#             ' PAROXETINE HCL',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERIDONE',
#             ' SEROQUEL XR',
#             ' SERTRALINE HCL',
#             ' TEMAZEPAM',
#             ' TRAZODONE HCL',
#             ' TRIHEXYPHENIDYL HCL',
#             ' VENLAFAXINE HCL ER',
#             ' ZIPRASIDONE HCL',
#             ' ZOLPIDEM TARTRATE',
#             'BUSPIRONE HCL'}): 1,
#  frozenset({' QUETIAPINE FUMARATE', 'DIAZEPAM'}): 1,
#  frozenset({' BETAMETHASONE DIPROPIONATE',
#             ' CLINDAMYCIN PHOSPHATE',
#             ' CLOBETASOL PROPIONATE',
#             ' DESONIDE',
#             ' DOXYCYCLINE HYCLATE',
#             ' ECONAZOLE NITRATE',
#             ' FLUOCINONIDE',
#             ' HYDROCORTISONE',
#             ' HYDROXYZINE HCL',
#             ' KETOCONAZOLE',
#             ' METRONIDAZOLE',
#             ' MUPIROCIN',
#             ' PREDNISONE',
#             ' TRIAMCINOLONE ACETONIDE',
#             'CEPHALEXIN'}): 1,
#  frozenset({' ALENDRONATE SODIUM',
#             ' ALLOPURINOL',
#             ' AMILORIDE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' BENAZEPRIL HCL',
#             ' CALCITRIOL',
#             ' CALCIUM ACETATE',
#             ' CARVEDILOL',
#             ' CIPROFLOXACIN HCL',
#             ' CLOPIDOGREL',
#             ' COLCRYS',
#             ' DIOVAN',
#             ' DOXAZOSIN MESYLATE',
#             ' FAMOTIDINE',
#             ' FLUDROCORTISONE ACETATE',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' HYDROCHLOROTHIAZIDE',
#             ' IMIPRAMINE HCL',
#             ' IRBESARTAN',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' JANUVIA',
#             ' LABETALOL HCL',
#             ' LACTATED RINGERS',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LOPERAMIDE',
#             ' LORAZEPAM',
#             ' LOSARTAN POTASSIUM',
#             ' METOCLOPRAMIDE HCL',
#             ' METOLAZONE',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' OMEPRAZOLE',
#             ' OPIUM TINCTURE',
#             ' OXYCODONE-ACETAMINOPHEN',
#             ' POTASSIUM CHLORIDE',
#             ' PRAVASTATIN SODIUM',
#             ' PREDNISONE',
#             ' RENVELA',
#             ' SENSIPAR',
#             ' SIMVASTATIN',
#             ' SPIRONOLACTONE',
#             ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#             ' SYNTHROID',
#             ' TAMSULOSIN HCL',
#             ' TERAZOSIN HCL',
#             ' VYTORIN',
#             ' WARFARIN SODIUM',
#             ' ZEMPLAR',
#             'MIDODRINE HCL'}): 1,
#  frozenset({' ALPRAZOLAM',
#             ' AMLODIPINE BESYLATE',
#             ' ATORVASTATIN CALCIUM',
#             ' CALCITRIOL',
#             ' DOXAZOSIN MESYLATE',
#             ' FUROSEMIDE',
#             ' HYDRALAZINE HCL',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LOSARTAN POTASSIUM',
#             ' POTASSIUM CHLORIDE',
#             ' RENVELA',
#             ' SPIRONOLACTONE',
#             ' TORSEMIDE',
#             'CALCIUM ACETATE'}): 1,
#  frozenset({' ABACAVIR',
#             ' ACYCLOVIR',
#             ' ADVAIR DISKUS',
#             ' ALENDRONATE SODIUM',
#             ' ALPRAZOLAM',
#             ' AMITIZA',
#             ' AMITRIPTYLINE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' AMLODIPINE BESYLATE-BENAZEPRIL',
#             ' AMMONIUM LACTATE',
#             ' ANDROGEL',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' ATRIPLA',
#             ' ATROVENT HFA',
#             ' AZITHROMYCIN',
#             ' BARACLUDE',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' CARVEDILOL',
#             ' CELEBREX',
#             ' CHANTIX',
#             ' CICLOPIROX',
#             ' CIPROFLOXACIN HCL',
#             ' CITALOPRAM HBR',
#             ' CLINDAMYCIN PHOSPHATE',
#             ' CLOBETASOL PROPIONATE',
#             ' CLONAZEPAM',
#             ' CLONIDINE HCL',
#             ' CLOPIDOGREL',
#             ' CLOTRIMAZOLE-BETAMETHASONE',
#             ' COMBIVENT',
#             ' COMBIVENT RESPIMAT',
#             ' COREG CR',
#             ' CREON',
#             ' CRESTOR',
#             ' CYCLOBENZAPRINE HCL',
#             ' CYMBALTA',
#             ' CYPROHEPTADINE HCL',
#             ' DEPO-TESTOSTERONE',
#             ' DEXILANT',
#             ' DIAZEPAM',
#             ' DICYCLOMINE HCL',
#             ' DIOVAN',
#             ' DIPHENOXYLATE-ATROPINE',
#             ' DRONABINOL',
#             ' EDURANT',
#             ' EMTRIVA',
#             ' ENALAPRIL MALEATE',
#             ' EPZICOM',
#             ' ESCITALOPRAM OXALATE',
#             ' FAMOTIDINE',
#             ' FENOFIBRATE',
#             ' FLUTICASONE PROPIONATE',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' GAMMAGARD LIQUID',
#             ' HYDROCHLOROTHIAZIDE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' HYDROCORTISONE',
#             ' IBANDRONATE SODIUM',
#             ' IBUPROFEN',
#             ' INSULIN SYRINGE',
#             ' INTELENCE',
#             ' IPRATROPIUM BROMIDE',
#             ' ISENTRESS',
#             ' KALETRA',
#             ' KETOCONAZOLE',
#             ' LAMIVUDINE',
#             ' LANSOPRAZOLE',
#             ' LEVETIRACETAM',
#             ' LEVOFLOXACIN',
#             ' LEVOTHYROXINE SODIUM',
#             ' LEXIVA',
#             ' LIDODERM',
#             ' LISINOPRIL',
#             ' LITHIUM CARBONATE',
#             ' LOPERAMIDE',
#             ' LORAZEPAM',
#             ' LOSARTAN POTASSIUM',
#             ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#             ' LOVAZA',
#             ' LUNESTA',
#             ' LYRICA',
#             ' MELOXICAM',
#             ' MEPRON',
#             ' METFORMIN HCL',
#             ' METFORMIN HCL ER',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' MIRTAZAPINE',
#             ' MONTELUKAST SODIUM',
#             ' MUPIROCIN',
#             ' NAMENDA',
#             ' NAPROXEN',
#             ' NASONEX',
#             ' NEXIUM',
#             ' NIASPAN',
#             ' NIFEDIPINE ER',
#             ' NORVIR',
#             ' NOVOLIN 70-30',
#             ' NYSTATIN',
#             ' OLANZAPINE',
#             ' OMEPRAZOLE',
#             ' OXANDROLONE',
#             ' OXYCODONE HCL-ACETAMINOPHEN',
#             ' OXYCODONE-ACETAMINOPHEN',
#             ' PANCRELIPASE 5',
#             ' PANTOPRAZOLE SODIUM',
#             ' PAROXETINE HCL',
#             ' PENTOXIFYLLINE',
#             ' PHOSPHA 250 NEUTRAL',
#             ' PIOGLITAZONE HCL',
#             ' POTASSIUM CHLORIDE',
#             ' PRAVASTATIN SODIUM',
#             ' PREZISTA',
#             ' PROAIR HFA',
#             ' PROPRANOLOL HCL',
#             ' QUETIAPINE FUMARATE',
#             ' RANITIDINE HCL',
#             ' REYATAZ',
#             ' ROPINIROLE HCL',
#             ' SELZENTRY',
#             ' SEROQUEL XR',
#             ' SERTRALINE HCL',
#             ' SIMVASTATIN',
#             ' SOTALOL',
#             ' STRIBILD',
#             ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#             ' SUSTIVA',
#             ' SYMBICORT',
#             ' SYNTHROID',
#             ' TAMSULOSIN HCL',
#             ' TEMAZEPAM',
#             ' TESTIM',
#             ' TESTOSTERONE CYPIONATE',
#             ' TRAMADOL HCL',
#             ' TRAZODONE HCL',
#             ' TRETINOIN',
#             ' TRIAMCINOLONE ACETONIDE',
#             ' TRIZIVIR',
#             ' TRUVADA',
#             ' URSODIOL',
#             ' VALACYCLOVIR',
#             ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#             ' VENTOLIN HFA',
#             ' VIRAMUNE XR',
#             ' VIREAD',
#             ' VOLTAREN',
#             ' ZETIA',
#             ' ZOLPIDEM TARTRATE',
#             '000',
#             'OXYCONTIN'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION XL',
#             ' BUSPIRONE HCL',
#             ' CAMPRAL',
#             ' CARBAMAZEPINE',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLOZAPINE',
#             ' CLOZARIL',
#             ' CYMBALTA',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' DONEPEZIL HCL',
#             ' ESCITALOPRAM OXALATE',
#             ' FANAPT',
#             ' FAZACLO',
#             ' FLUOXETINE HCL',
#             ' FLUPHENAZINE HCL',
#             ' FLUVOXAMINE MALEATE',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' HYDROXYZINE PAMOATE',
#             ' INVEGA',
#             ' INVEGA SUSTENNA',
#             ' LAMOTRIGINE',
#             ' LATUDA',
#             ' LEVOTHYROXINE SODIUM',
#             ' LEXAPRO',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' LUNESTA',
#             ' MIRTAZAPINE',
#             ' NAMENDA',
#             ' OLANZAPINE',
#             ' OXCARBAZEPINE',
#             ' PAROXETINE HCL',
#             ' PRISTIQ ER',
#             ' PROPRANOLOL HCL',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERDAL',
#             ' RISPERDAL CONSTA',
#             ' SAPHRIS',
#             ' SEROQUEL XR',
#             ' SERTRALINE HCL',
#             ' SIMVASTATIN',
#             ' TEMAZEPAM',
#             ' THIORIDAZINE HCL',
#             ' TOPIRAMATE',
#             ' TRAZODONE HCL',
#             ' VENLAFAXINE HCL ER',
#             ' VIIBRYD',
#             ' ZIPRASIDONE HCL',
#             ' ZOLPIDEM TARTRATE',
#             'RISPERIDONE'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' AMITRIPTYLINE HCL',
#             ' ATENOLOL',
#             ' AVODART',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' BUSPIRONE HCL',
#             ' CARBAMAZEPINE',
#             ' CHLORPROMAZINE HCL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLOPIDOGREL',
#             ' CLORAZEPATE DIPOTASSIUM',
#             ' CLOTRIMAZOLE-BETAMETHASONE',
#             ' CLOZAPINE',
#             ' CRESTOR',
#             ' CYMBALTA',
#             ' DIAZEPAM',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' DONEPEZIL HCL',
#             ' DOXAZOSIN MESYLATE',
#             ' ESCITALOPRAM OXALATE',
#             ' ESTAZOLAM',
#             ' EXELON',
#             ' FAMOTIDINE',
#             ' FLUOXETINE HCL',
#             ' FLUPHENAZINE DECANOATE',
#             ' FLUPHENAZINE HCL',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' HALOPERIDOL DECANOATE',
#             ' HYDROCHLOROTHIAZIDE',
#             ' HYDROXYZINE HCL',
#             ' HYDROXYZINE PAMOATE',
#             ' INVEGA',
#             ' LAMOTRIGINE',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' LUNESTA',
#             ' LYRICA',
#             ' METOPROLOL TARTRATE',
#             ' MIRTAZAPINE',
#             ' NAMENDA',
#             ' NASONEX',
#             ' NORTRIPTYLINE HCL',
#             ' NUEDEXTA',
#             ' OLANZAPINE',
#             ' OLANZAPINE ODT',
#             ' OMEPRAZOLE',
#             ' OXAZEPAM',
#             ' PAROXETINE HCL',
#             ' PERPHENAZINE',
#             ' PRISTIQ ER',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERIDONE',
#             ' RIVASTIGMINE',
#             ' SEROQUEL XR',
#             ' SERTRALINE HCL',
#             ' SIMVASTATIN',
#             ' TAZORAC',
#             ' TEMAZEPAM',
#             ' THIORIDAZINE HCL',
#             ' THIOTHIXENE',
#             ' TOPIRAMATE',
#             ' TRAZODONE HCL',
#             ' TRIFLUOPERAZINE HCL',
#             ' TRIHEXYPHENIDYL HCL',
#             ' VENLAFAXINE HCL',
#             ' VENLAFAXINE HCL ER',
#             ' VIIBRYD',
#             ' ZIPRASIDONE HCL',
#             ' ZOLPIDEM TARTRATE',
#             'CARBIDOPA-LEVODOPA'}): 1,
#  frozenset({' ACETAMINOPHEN-CODEINE',
#             ' ALPRAZOLAM',
#             ' AMANTADINE',
#             ' AMITRIPTYLINE HCL',
#             ' AMPYRA',
#             ' AVONEX',
#             ' AVONEX PEN',
#             ' BACLOFEN',
#             ' BETASERON',
#             ' CLONAZEPAM',
#             ' COPAXONE',
#             ' CYMBALTA',
#             ' DONEPEZIL HCL',
#             ' ENABLEX',
#             ' ESCITALOPRAM OXALATE',
#             ' GABAPENTIN',
#             ' IBUPROFEN',
#             ' LEVETIRACETAM',
#             ' LYRICA',
#             ' METOPROLOL SUCCINATE',
#             ' NUVIGIL',
#             ' OXYCODONE-ACETAMINOPHEN',
#             ' PROVIGIL',
#             ' QUETIAPINE FUMARATE',
#             ' SERTRALINE HCL',
#             ' TIZANIDINE HCL',
#             ' TRAZODONE HCL',
#             ' TYSABRI',
#             ' VALACYCLOVIR',
#             ' VERAPAMIL HCL',
#             ' ZOLPIDEM TARTRATE',
#             'INDOMETHACIN'}): 1,
#  frozenset({' ADVAIR DISKUS',
#             ' PANTOPRAZOLE SODIUM',
#             ' PREDNISONE',
#             ' PROAIR HFA',
#             'SPIRIVA'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLOZAPINE',
#             ' CYMBALTA',
#             ' DOXEPIN HCL',
#             ' ESCITALOPRAM OXALATE',
#             ' FLUOXETINE HCL',
#             ' FLUVOXAMINE MALEATE',
#             ' GABAPENTIN',
#             ' LAMOTRIGINE',
#             ' LORAZEPAM',
#             ' METHYLPHENIDATE HCL',
#             ' MIRTAZAPINE',
#             ' SERTRALINE HCL',
#             ' TEGRETOL XR',
#             ' TEMAZEPAM',
#             ' TOPIRAMATE',
#             ' TRAZODONE HCL',
#             ' VENLAFAXINE HCL ER',
#             ' VIIBRYD',
#             ' ZIPRASIDONE HCL',
#             'RISPERIDONE'}): 1,
#  frozenset({'BUPROPION HCL SR'}): 1,
#  frozenset({' AMIODARONE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' CARTIA XT',
#             ' CARVEDILOL',
#             ' CLONIDINE HCL',
#             ' CLOPIDOGREL',
#             ' CRESTOR',
#             ' DIGOX',
#             ' DIGOXIN',
#             ' DILTIAZEM 24HR CD',
#             ' EFFIENT',
#             ' FENOFIBRATE',
#             ' FUROSEMIDE',
#             ' HYDRALAZINE HCL',
#             ' HYDROCHLOROTHIAZIDE',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' JANTOVEN',
#             ' KLOR-CON M10',
#             ' KLOR-CON M20',
#             ' LIPITOR',
#             ' LISINOPRIL',
#             ' LOSARTAN POTASSIUM',
#             ' LOVASTATIN',
#             ' METOLAZONE',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' MULTAQ',
#             ' NIASPAN',
#             ' NITROSTAT',
#             ' POTASSIUM CHLORIDE',
#             ' PRADAXA',
#             ' PRAVASTATIN SODIUM',
#             ' RAMIPRIL',
#             ' RANEXA',
#             ' SIMVASTATIN',
#             ' TERAZOSIN HCL',
#             ' VERAPAMIL ER',
#             ' WARFARIN SODIUM',
#             ' WELCHOL',
#             ' XARELTO',
#             ' ZETIA',
#             'DILTIAZEM 24HR ER'}): 1,
#  frozenset({' ADVAIR DISKUS',
#             ' ALENDRONATE SODIUM',
#             ' ALLOPURINOL',
#             ' ALPRAZOLAM',
#             ' AMILORIDE-HYDROCHLOROTHIAZIDE',
#             ' AMIODARONE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' AMLODIPINE BESYLATE-BENAZEPRIL',
#             ' AMOXICILLIN',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' AVAPRO',
#             ' AVODART',
#             ' AZATHIOPRINE',
#             ' AZITHROMYCIN',
#             ' BACLOFEN',
#             ' BISOPROLOL-HYDROCHLOROTHIAZIDE',
#             ' BUMETANIDE',
#             ' BUSPIRONE HCL',
#             ' CARVEDILOL',
#             ' CELEBREX',
#             ' CEPHALEXIN',
#             ' CILOSTAZOL',
#             ' CIPROFLOXACIN HCL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLOPIDOGREL',
#             ' CRESTOR',
#             ' CYCLOBENZAPRINE HCL',
#             ' CYMBALTA',
#             ' DICYCLOMINE HCL',
#             ' DILTIAZEM HCL',
#             ' DIOVAN',
#             ' DIPHENOXYLATE-ATROPINE',
#             ' DONEPEZIL HCL',
#             ' DOXAZOSIN MESYLATE',
#             ' DOXYCYCLINE HYCLATE',
#             ' ELIQUIS',
#             ' ENALAPRIL MALEATE',
#             ' EVISTA',
#             ' EXELON',
#             ' FAMOTIDINE',
#             ' FENOFIBRATE',
#             ' FENTANYL',
#             ' FINASTERIDE',
#             ' FLUOXETINE HCL',
#             ' FLUTICASONE PROPIONATE',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' GENERLAC',
#             ' GLIMEPIRIDE',
#             ' GLIPIZIDE ER',
#             ' GLIPIZIDE-METFORMIN',
#             ' GLYBURIDE',
#             ' HYDROCHLOROTHIAZIDE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' HYDROXYZINE HCL',
#             ' IBUPROFEN',
#             ' IMIPRAMINE HCL',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' JANUMET',
#             ' JANUVIA',
#             ' KLOR-CON M20',
#             ' LANSOPRAZOLE',
#             ' LANTUS',
#             ' LANTUS SOLOSTAR',
#             ' LEVEMIR FLEXPEN',
#             ' LEVETIRACETAM',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#             ' LORAZEPAM',
#             ' LOSARTAN POTASSIUM',
#             ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#             ' LOVASTATIN',
#             ' LYRICA',
#             ' MECLIZINE HCL',
#             ' MELOXICAM',
#             ' METFORMIN HCL',
#             ' METFORMIN HCL ER',
#             ' METOCLOPRAMIDE HCL',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' MONTELUKAST SODIUM',
#             ' NAMENDA',
#             ' NAPROXEN',
#             ' NATEGLINIDE',
#             ' NEXIUM',
#             ' NIFEDICAL XL',
#             ' NIFEDIPINE ER',
#             ' NITROFURANTOIN MONO-MACRO',
#             ' OMEPRAZOLE',
#             ' OXYBUTYNIN CHLORIDE',
#             ' OXYCODONE HCL-ACETAMINOPHEN',
#             ' OXYCODONE-ACETAMINOPHEN',
#             ' OXYCONTIN',
#             ' POLYETHYLENE GLYCOL 3350',
#             ' POTASSIUM CHLORIDE',
#             ' PRADAXA',
#             ' PRAMIPEXOLE DIHYDROCHLORIDE',
#             ' PRAVASTATIN SODIUM',
#             ' PREDNISONE',
#             ' PROAIR HFA',
#             ' PROPRANOLOL HCL',
#             ' QUETIAPINE FUMARATE',
#             ' QUINAPRIL-HYDROCHLOROTHIAZIDE',
#             ' RAMIPRIL',
#             ' RANEXA',
#             ' RANITIDINE HCL',
#             ' RIVASTIGMINE',
#             ' ROPINIROLE HCL',
#             ' SERTRALINE HCL',
#             ' SIMVASTATIN',
#             ' SPIRIVA',
#             ' SPIRONOLACTONE',
#             ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#             ' SULFASALAZINE',
#             ' TAMSULOSIN HCL',
#             ' TORSEMIDE',
#             ' TRAMADOL HCL',
#             ' TRAMADOL HCL-ACETAMINOPHEN',
#             ' TRAZODONE HCL',
#             ' TRIAMCINOLONE ACETONIDE',
#             ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#             ' VENLAFAXINE HCL ER',
#             ' VERAPAMIL ER',
# ...
#             ' LYRICA',
#             ' MECLIZINE HCL',
#             ' METHOCARBAMOL',
#             ' MODAFINIL',
#             ' NAMENDA',
#             ' OXCARBAZEPINE',
#             ' OXYCODONE HCL-ACETAMINOPHEN',
#             ' PHENOBARBITAL',
#             ' PHENYTOIN SODIUM EXTENDED',
#             ' PRAMIPEXOLE DIHYDROCHLORIDE',
#             ' PRIMIDONE',
#             ' PROPRANOLOL HCL',
#             ' REBIF',
#             ' ROPINIROLE HCL',
#             ' TOPAMAX',
#             ' TOPIRAMATE',
#             ' TRIHEXYPHENIDYL HCL',
#             ' TRILEPTAL',
#             ' ZOLPIDEM TARTRATE',
#             'SUMATRIPTAN SUCCINATE'}): 1,
#  frozenset({' CIPROFLOXACIN HCL',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' SIMVASTATIN',
#             'AZITHROMYCIN'}): 1,
#  frozenset({' ALPRAZOLAM',
#             ' BUDESONIDE',
#             ' CELEBREX',
#             ' CLONAZEPAM',
#             ' DIAZEPAM',
#             ' DIOVAN',
#             ' FENTANYL',
#             ' FUROSEMIDE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' IPRATROPIUM-ALBUTEROL',
#             ' JANUVIA',
#             ' LORAZEPAM',
#             ' LORAZEPAM INTENSOL',
#             ' METHYLPHENIDATE HCL',
#             ' METOPROLOL SUCCINATE',
#             ' MIRTAZAPINE',
#             ' MORPHINE SULFATE',
#             ' OMEPRAZOLE',
#             ' OXYCODONE-ACETAMINOPHEN',
#             ' QUETIAPINE FUMARATE',
#             ' SERTRALINE HCL',
#             ' TORSEMIDE',
#             ' WARFARIN SODIUM',
#             ' ZOLPIDEM TARTRATE',
#             'NAMENDA'}): 1,
#  frozenset({' AMOX TR-POTASSIUM CLAVULANATE',
#             ' CLINDAMYCIN HCL',
#             ' DICLOFENAC SODIUM',
#             ' ECONAZOLE NITRATE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' IBUPROFEN',
#             'CEPHALEXIN'}): 1,
#  frozenset({' AMLODIPINE BESYLATE',
#             ' ATORVASTATIN CALCIUM',
#             ' ATROVENT HFA',
#             ' CARVEDILOL',
#             ' CLOPIDOGREL',
#             ' FAMOTIDINE',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' HYDROCHLOROTHIAZIDE',
#             ' JANUVIA',
#             ' LANTUS',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LOSARTAN POTASSIUM',
#             ' METFORMIN HCL',
#             ' METOPROLOL TARTRATE',
#             ' NEXIUM',
#             ' NIFEDIPINE ER',
#             ' PREDNISONE',
#             ' PROAIR HFA',
#             ' SIMVASTATIN',
#             ' VENTOLIN HFA',
#             ' WARFARIN SODIUM',
#             'ADVAIR DISKUS'}): 1,
#  frozenset({' AMIODARONE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' CARVEDILOL',
#             ' CHLORTHALIDONE',
#             ' CLOPIDOGREL',
#             ' CRESTOR',
#             ' DIGOX',
#             ' DIOVAN',
#             ' FUROSEMIDE',
#             ' HYDRALAZINE HCL',
#             ' HYDROCHLOROTHIAZIDE',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' LISINOPRIL',
#             ' LOSARTAN POTASSIUM',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' NITROGLYCERIN PATCH',
#             ' NITROSTAT',
#             ' POTASSIUM CHLORIDE',
#             ' PROPAFENONE HCL',
#             ' SPIRONOLACTONE',
#             'SIMVASTATIN'}): 1,
#  frozenset({' PENICILLIN V POTASSIUM', 'IBUPROFEN'}): 1,
#  frozenset({' CHLORHEXIDINE GLUCONATE',
#             ' CLINDAMYCIN HCL',
#             ' DEXAMETHASONE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             'AMOXICILLIN'}): 1,
#  frozenset({'VALACYCLOVIR'}): 1,
#  frozenset({' FENTANYL',
#             ' FUROSEMIDE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' HYDROMORPHONE HCL',
#             ' JANTOVEN',
#             ' LEVOTHYROXINE SODIUM',
#             ' LORAZEPAM',
#             ' METOPROLOL TARTRATE',
#             ' OXYCODONE HCL',
#             ' RANITIDINE HCL',
#             ' WARFARIN SODIUM',
#             'TRAZODONE HCL'}): 1,
#  frozenset({' CLONAZEPAM',
#             ' FENTANYL',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' LORAZEPAM',
#             ' LYRICA',
#             ' OXYCODONE HCL',
#             ' OXYCODONE-ACETAMINOPHEN',
#             ' OXYCONTIN',
#             'MORPHINE SULFATE ER'}): 1,
#  frozenset({'SYNTHROID'}): 1,
#  frozenset({' HYDROCODONE-ACETAMINOPHEN',
#             ' PENICILLIN V POTASSIUM',
#             'AMOXICILLIN'}): 1,
#  frozenset({' AMLODIPINE BESYLATE',
#             ' AMOXICILLIN',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' AZITHROMYCIN',
#             ' CARVEDILOL',
#             ' CIPROFLOXACIN HCL',
#             ' CLONAZEPAM',
#             ' CLOPIDOGREL',
#             ' CRESTOR',
#             ' CYMBALTA',
#             ' FENOFIBRATE',
#             ' GABAPENTIN',
#             ' GLIMEPIRIDE',
#             ' HYDROCHLOROTHIAZIDE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#             ' METFORMIN HCL',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' OMEPRAZOLE',
#             ' PROAIR HFA',
#             ' SIMVASTATIN',
#             ' TIZANIDINE HCL',
#             ' TRAMADOL HCL',
#             ' TRAZODONE HCL',
#             ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#             ' ZETIA',
#             'ADVAIR DISKUS'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' AMITRIPTYLINE HCL',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLOZAPINE',
#             ' CYMBALTA',
#             ' DIAZEPAM',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' DOXEPIN HCL',
#             ' EFFEXOR XR',
#             ' ESCITALOPRAM OXALATE',
#             ' FLUOXETINE HCL',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' LAMOTRIGINE',
#             ' LEVOTHYROXINE SODIUM',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' MIRTAZAPINE',
#             ' NORTRIPTYLINE HCL',
#             ' OLANZAPINE',
#             ' OMEPRAZOLE',
#             ' PAROXETINE HCL',
#             ' PERPHENAZINE',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERIDONE',
#             ' SEROQUEL XR',
#             ' SERTRALINE HCL',
#             ' SIMVASTATIN',
#             ' TEMAZEPAM',
#             ' TOPIRAMATE',
#             ' TRAZODONE HCL',
#             ' VENLAFAXINE HCL',
#             ' VENLAFAXINE HCL ER',
#             ' ZIPRASIDONE HCL',
#             ' ZOLPIDEM TARTRATE',
#             'HYDROXYZINE PAMOATE'}): 1,
#  frozenset({' FLUTICASONE PROPIONATE',
#             ' PRAMIPEXOLE DIHYDROCHLORIDE',
#             ' ROPINIROLE HCL',
#             ' ZALEPLON',
#             ' ZOLPIDEM TARTRATE',
#             'GABAPENTIN'}): 1,
#  frozenset({' BUSPIRONE HCL', ' TRAZODONE HCL', 'SERTRALINE HCL'}): 1,
#  frozenset({' HYDROCODONE-ACETAMINOPHEN', 'TRAMADOL HCL'}): 1,
#  frozenset({' ASACOL HD',
#             ' AZATHIOPRINE',
#             ' BALSALAZIDE DISODIUM',
#             ' BUDESONIDE EC',
#             ' DICYCLOMINE HCL',
#             ' LINZESS',
#             ' METOCLOPRAMIDE HCL',
#             ' NEXIUM',
#             ' OMEPRAZOLE',
#             ' ONDANSETRON HCL',
#             ' PANTOPRAZOLE SODIUM',
#             ' PENTASA',
#             ' POLYETHYLENE GLYCOL 3350',
#             ' RANITIDINE HCL',
#             'SUPREP'}): 1,
#  frozenset({' LISINOPRIL', ' PREDNISONE', 'CEPHALEXIN'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' AMANTADINE',
#             ' AMPHETAMINE SALT COMBO',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL SR',
#             ' CARISOPRODOL',
#             ' CITALOPRAM HBR',
#             ' CLONAZEPAM',
#             ' CLONIDINE HCL',
#             ' CYMBALTA',
#             ' DIAZEPAM',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' DOXEPIN HCL',
#             ' FLUOXETINE HCL',
#             ' FLUVOXAMINE MALEATE',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' HYDROXYZINE HCL',
#             ' HYDROXYZINE PAMOATE',
#             ' LAMOTRIGINE',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' METHYLPHENIDATE ER',
#             ' METHYLPHENIDATE HCL',
#             ' MIRTAZAPINE',
#             ' MODAFINIL',
#             ' OLANZAPINE',
#             ' PAROXETINE HCL',
#             ' PROPRANOLOL HCL',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERDAL CONSTA',
#             ' RISPERIDONE',
#             ' SAPHRIS',
#             ' TEMAZEPAM',
#             ' TRAZODONE HCL',
#             ' TRIAZOLAM',
#             ' VENLAFAXINE HCL',
#             ' ZOLOFT',
#             ' ZOLPIDEM TARTRATE',
#             ' ZOLPIDEM TARTRATE ER',
#             'BUSPIRONE HCL'}): 1,
#  frozenset({' AZATHIOPRINE',
#             ' GABAPENTIN',
#             ' GAMMAGARD LIQUID',
#             ' MESTINON',
#             ' PREDNISONE',
#             ' PYRIDOSTIGMINE BROMIDE',
#             'MYCOPHENOLATE MOFETIL'}): 1,
#  frozenset({' ADCIRCA',
#             ' AZITHROMYCIN',
#             ' FLUCONAZOLE',
#             ' FUROSEMIDE',
#             ' MONTELUKAST SODIUM',
#             ' PREDNISONE',
#             ' PROAIR HFA',
#             ' QVAR',
#             ' SPIRIVA',
#             ' SPIRONOLACTONE',
#             'ADVAIR DISKUS'}): 1,
#  frozenset({' DIAZEPAM',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' ONDANSETRON ODT',
#             ' OXYCODONE-ACETAMINOPHEN',
#             ' PREDNISONE',
#             'CEPHALEXIN'}): 1,
#  frozenset({' AMLODIPINE BESYLATE',
#             ' AMOXICILLIN',
#             ' CIPROFLOXACIN HCL',
#             ' CITALOPRAM HBR',
#             ' CRESTOR',
#             ' DONEPEZIL HCL',
#             ' FLUTICASONE PROPIONATE',
#             ' GLIMEPIRIDE',
#             ' HYDROCHLOROTHIAZIDE',
#             ' LEVOTHYROXINE SODIUM',
#             ' LISINOPRIL',
#             ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#             ' LOSARTAN POTASSIUM',
#             ' METFORMIN HCL',
#             ' METOPROLOL TARTRATE',
#             ' MONTELUKAST SODIUM',
#             ' OMEPRAZOLE',
#             ' PAROXETINE HCL',
#             ' PREDNISONE',
#             ' PROAIR HFA',
#             ' RANITIDINE HCL',
#             ' ROPINIROLE HCL',
#             ' SIMVASTATIN',
#             ' SPIRONOLACTONE',
#             ' SULFAMETHOXAZOLE-TRIMETHOPRIM',
#             ' TRAMADOL HCL',
#             ' TRIAMTERENE-HYDROCHLOROTHIAZID',
#             ' VENTOLIN HFA',
#             'FLUOXETINE HCL'}): 1,
#  frozenset({' AMLODIPINE BESYLATE',
#             ' ATORVASTATIN CALCIUM',
#             ' BD ULTRA-FINE PEN NEEDLE',
#             ' CARVEDILOL',
#             ' CRESTOR',
#             ' FENOFIBRATE',
#             ' GLIPIZIDE',
#             ' GLUMETZA',
#             ' HUMALOG MIX 50-50',
#             ' HUMALOG MIX 75-25',
#             ' HUMULIN 70-30',
#             ' HUMULIN N',
#             ' HYDROCORTISONE',
#             ' INSULIN SYRINGE',
#             ' JANUMET',
#             ' JANUVIA',
#             ' LANTUS',
#             ' LANTUS SOLOSTAR',
#             ' LEVOTHYROXINE SODIUM',
#             ' LIPITOR',
#             ' LISINOPRIL',
#             ' LOSARTAN POTASSIUM',
#             ' LOVAZA',
#             ' METFORMIN HCL',
#             ' METFORMIN HCL ER',
#             ' METHIMAZOLE',
#             ' NIASPAN',
#             ' NOVOLOG',
#             ' NOVOLOG FLEXPEN',
#             ' NOVOLOG MIX 70-30 FLEXPEN',
#             ' PIOGLITAZONE HCL',
#             ' PRAVASTATIN SODIUM',
#             ' RAMIPRIL',
#             ' SIMVASTATIN',
#             ' SYNTHROID',
#             ' TRADJENTA',
#             'HUMALOG'}): 1,
#  frozenset({' HYDROCODONE-ACETAMINOPHEN',
#             ' IBUPROFEN',
#             ' MELOXICAM',
#             ' OXYCODONE-ACETAMINOPHEN',
#             'VOLTAREN'}): 1,
#  frozenset({' ALLOPURINOL',
#             ' AMITRIPTYLINE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' BD ULTRA-FINE PEN NEEDLE',
#             ' CLOPIDOGREL',
#             ' CRESTOR',
#             ' ESTRADIOL',
#             ' FAMOTIDINE',
#             ' FENOFIBRATE',
#             ' FUROSEMIDE',
#             ' GABAPENTIN',
#             ' GLIMEPIRIDE',
#             ' HUMULIN 70-30',
#             ' HUMULIN N',
#             ' HUMULIN R',
#             ' HYDROCHLOROTHIAZIDE',
#             ' HYDROCODONE-ACETAMINOPHEN',
#             ' INSULIN SYRINGE',
#             ' KLOR-CON M20',
#             ' LEVOTHYROXINE SODIUM',
#             ' LEVOXYL',
#             ' LISINOPRIL',
#             ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#             ' LOSARTAN POTASSIUM',
#             ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#             ' METFORMIN HCL',
#             ' METFORMIN HCL ER',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' NEXIUM',
#             ' NIFEDIPINE ER',
#             ' NOVOLIN 70-30',
#             ' NOVOLIN N',
#             ' NOVOLIN R',
#             ' OMEPRAZOLE',
#             ' PANTOPRAZOLE SODIUM',
#             ' POTASSIUM CHLORIDE',
#             ' PRAVASTATIN SODIUM',
#             ' PREDNISONE',
#             ' QUINAPRIL HCL',
#             ' SANDOSTATIN LAR',
#             ' SYNTHROID',
#             ' TESTOSTERONE CYPIONATE',
#             ' TRANDOLAPRIL',
#             ' TRIAMTERENE-HCTZ',
#             ' ULTRA COMFORT',
#             'SIMVASTATIN'}): 1,
#  frozenset({' DONEPEZIL HCL',
#             ' ESCITALOPRAM OXALATE',
#             ' GALANTAMINE HBR',
#             ' NAMENDA',
#             ' QUETIAPINE FUMARATE',
#             ' TRAZODONE HCL',
#             'SERTRALINE HCL'}): 1,
#  frozenset({' ALLOPURINOL',
#             ' AMIODARONE HCL',
#             ' AMLODIPINE BESYLATE',
#             ' AMLODIPINE BESYLATE-BENAZEPRIL',
#             ' ATENOLOL',
#             ' ATORVASTATIN CALCIUM',
#             ' BYSTOLIC',
#             ' CARVEDILOL',
#             ' CLOPIDOGREL',
#             ' COUMADIN',
#             ' DIGOX',
#             ' DILTIAZEM 24HR ER',
#             ' DILTIAZEM ER',
#             ' DIOVAN',
#             ' EFFIENT',
#             ' FUROSEMIDE',
#             ' HYDRALAZINE HCL',
#             ' HYDROCHLOROTHIAZIDE',
#             ' ISOSORBIDE MONONITRATE ER',
#             ' KLOR-CON 10',
#             ' LISINOPRIL',
#             ' LISINOPRIL-HYDROCHLOROTHIAZIDE',
#             ' LOSARTAN POTASSIUM',
#             ' LOSARTAN-HYDROCHLOROTHIAZIDE',
#             ' METOPROLOL SUCCINATE',
#             ' METOPROLOL TARTRATE',
#             ' MULTAQ',
#             ' NITROSTAT',
#             ' POTASSIUM CHLORIDE',
#             ' PRADAXA',
#             ' PRAVASTATIN SODIUM',
#             ' QUINAPRIL HCL',
#             ' SPIRONOLACTONE',
#             ' TOPROL XL',
#             ' VALSARTAN-HYDROCHLOROTHIAZIDE',
#             ' VERAPAMIL ER',
#             ' VYTORIN',
#             ' WARFARIN SODIUM',
#             ' XARELTO',
#             'SIMVASTATIN'}): 1,
#  frozenset({' ABILIFY',
#             ' ALPRAZOLAM',
#             ' ATENOLOL',
#             ' BENZTROPINE MESYLATE',
#             ' BUPROPION HCL SR',
#             ' BUPROPION XL',
#             ' BUSPIRONE HCL',
#             ' CARBAMAZEPINE XR',
#             ' CITALOPRAM HBR',
#             ' CLOZAPINE',
#             ' CYMBALTA',
#             ' DIVALPROEX SODIUM',
#             ' DIVALPROEX SODIUM ER',
#             ' ESCITALOPRAM OXALATE',
#             ' FLUOXETINE HCL',
#             ' FLUPHENAZINE DECANOATE',
#             ' GABAPENTIN',
#             ' HALOPERIDOL',
#             ' HALOPERIDOL DECANOATE',
#             ' INVEGA',
#             ' INVEGA SUSTENNA',
#             ' LAMOTRIGINE',
#             ' LITHIUM CARBONATE',
#             ' LORAZEPAM',
#             ' LUNESTA',
#             ' MIRTAZAPINE',
#             ' OLANZAPINE',
#             ' PAROXETINE HCL',
#             ' PERPHENAZINE',
#             ' PRISTIQ ER',
#             ' PROPRANOLOL HCL',
#             ' QUETIAPINE FUMARATE',
#             ' RISPERDAL CONSTA',
#             ' RISPERIDONE',
#             ' ROZEREM',
#             ' SEROQUEL XR',
#             ' SERTRALINE HCL',
#             ' TOPIRAMATE',
#             ' TRAZODONE HCL',
#             ' TRIHEXYPHENIDYL HCL',
#             ' VENLAFAXINE HCL ER',
#             ' ZIPRASIDONE HCL',
#             ' ZOLPIDEM TARTRATE',
#             'CLONAZEPAM'}): 1}

# %%
myFPtree, myHeaderTab = createTree(initSet, 3)
myFPtree.disp()
# Out:
#    Null Set   1
#       GABAPENTIN   61
#         HYDROCODONE-ACETAMINOPHEN   29
#           ZOLPIDEM TARTRATE   24
#             ALPRAZOLAM   17
#               SERTRALINE HCL   13
#                 OMEPRAZOLE   1
#                   LISINOPRIL   1
#                     ATORVASTATIN CALCIUM   1
#                       FUROSEMIDE   1
#                         AMLODIPINE BESYLATE   1
#                           SIMVASTATIN   1
#                             LEVOTHYROXINE SODIUM   1
#                               METOPROLOL TARTRATE   1
#                                 HYDROCHLOROTHIAZIDE   1
#                                   METOPROLOL SUCCINATE   1
#                                     LOSARTAN POTASSIUM   1
#                                       PREDNISONE   1
#                                         CLOPIDOGREL   1
#                                           PANTOPRAZOLE SODIUM   1
#                                             CARVEDILOL   1
#                                               PRAVASTATIN SODIUM   1
#                                                 POTASSIUM CHLORIDE   1
#                                                   ATENOLOL   1
#                                                     SPIRONOLACTONE   1
#                                                       DIAZEPAM   1
#                                                         ABILIFY   1
#                                                           TRAMADOL HCL   1
#                                                             NEXIUM   1
#                                                               RANITIDINE HCL   1
#                                                                 TEMAZEPAM   1
#                                                                   AZITHROMYCIN   1
#                                                                     ALLOPURINOL   1
#                                                                       DIOVAN   1
#                                                                         CLONIDINE HCL   1
#                                                                           CIPROFLOXACIN HCL   1
#                                                                             LISINOPRIL-HYDROCHLOROTHIAZIDE   1
#                                                                               ISOSORBIDE MONONITRATE ER   1
#                                                                                 NIFEDIPINE ER   1
#                                                                                   LOSARTAN-HYDROCHLOROTHIAZIDE   1
#                                                                                     TAMSULOSIN HCL   1
#                                                                                       HYDRALAZINE HCL   1
#                                                                                         OXYCODONE HCL   1
#                                                                                           LOVASTATIN   1
#                                                                                             MELOXICAM   1
#                                                                                               AMLODIPINE BESYLATE-BENAZEPRIL   1
#                                                                                                 FENOFIBRATE   1
#                                                                                                   LANTUS   1
#                                                                                                     BYSTOLIC   1
#                                                                                                       BENAZEPRIL HCL   1
#                                                                                                         METOLAZONE   1
#                                                                                                           GLYBURIDE   1
#                                                                                                             IRBESARTAN   1
#                                                                                                               NIFEDICAL XL   1
#                                                                                                                 BUMETANIDE   1
#                                                                                                                   LABETALOL HCL   1
#                                                                                                                     RENVELA   1
#                                                                                                                       NOVOLOG   1
#                                                                                                                         CARISOPRODOL   1
#                                                                                                                           SENSIPAR   1
#                                                                                                                             MEGESTROL ACETATE   1
#                                                                                                                               MINOXIDIL   1
#                                                                                                                                 KLOR-CON M10   1
#                                                                                                                                   CALCITRIOL   1
#                                                                                                                                     OXYBUTYNIN CHLORIDE   1
#                                                                                                                                       CALCIUM ACETATE   1
#                 LORAZEPAM   8
#                   CYMBALTA   8
#                     CLONAZEPAM   5
#                       CITALOPRAM HBR   4
#                         OMEPRAZOLE   3
#                           LISINOPRIL   3
#                             TRAZODONE HCL   2
#                               ATORVASTATIN CALCIUM   2
#                                 FUROSEMIDE   2
#                                   AMLODIPINE BESYLATE   2
#                                     SIMVASTATIN   2
#                                       METOPROLOL TARTRATE   2
#                                         LEVOTHYROXINE SODIUM   2
#                                           HYDROCHLOROTHIAZIDE   2
#                                             ESCITALOPRAM OXALATE   1
#                                               QUETIAPINE FUMARATE   1
#                                                 METOPROLOL SUCCINATE   1
#                                                   LOSARTAN POTASSIUM   1
#                                                     CLOPIDOGREL   1
#                                                       PANTOPRAZOLE SODIUM   1
#                                                         CARVEDILOL   1
#                                                           MIRTAZAPINE   1
#                                                             CRESTOR   1
#                                                               PRAVASTATIN SODIUM   1
#                                                                 METFORMIN HCL   1
#                                                                   BUPROPION HCL SR   1
#                                                                     AMITRIPTYLINE HCL   1
#                                                                       ATENOLOL   1
#                                                                         PAROXETINE HCL   1
#                                                                           POTASSIUM CHLORIDE   1
#                                                                             BUPROPION XL   1
#                                                                               DIAZEPAM   1
#                                                                                 OLANZAPINE   1
#                                                                                   FLUTICASONE PROPIONATE   1
#                                                                                     TRAMADOL HCL   1
#                                                                                       NEXIUM   1
#                                                                                         PROPRANOLOL HCL   1
#                                                                                           OXYCODONE-ACETAMINOPHEN   1
#                                                                                             RANITIDINE HCL   1
#                                                                                               TEMAZEPAM   1
#                                                                                                 AZITHROMYCIN   1
#                                                                                                   LITHIUM CARBONATE   1
#                                                                                                     PROAIR HFA   1
#                                                                                                       DIOVAN   1
#                                                                                                         IBUPROFEN   1
#                                                                                                           CIPROFLOXACIN HCL   1
#                                                                                                             CLONIDINE HCL   1
#                                                                                                               ADVAIR DISKUS   1
#                                                                                                                 CYCLOBENZAPRINE HCL   1
#                                                                                                                   MONTELUKAST SODIUM   1
#                                                                                                                     NAMENDA   1
#                                                                                                                       FAMOTIDINE   1
#                                                                                                                         SULFAMETHOXAZOLE-TRIMETHOPRIM   1
#                                                                                                                           NIFEDIPINE ER   1
#                                                                                                                             LOSARTAN-HYDROCHLOROTHIAZIDE   1
#                                                                                                                               TAMSULOSIN HCL   1
#                                                                                                                                 SYNTHROID   1
#                                                                                                                                   SEROQUEL XR   1
#                                                                                                                                     LYRICA   1
#                                                                                                                                       ENALAPRIL MALEATE   1
#                                                                                                                                         ROPINIROLE HCL   1
#                                                                                                                                           OXYCODONE HCL-ACETAMINOPHEN   1
#                                                                                                                                             MELOXICAM   1
#                                                                                                                                               AMLODIPINE BESYLATE-BENAZEPRIL   1
#                                                                                                                                                 LUNESTA   1
#                                                                                                                                                   FENOFIBRATE   1
#                                                                                                                                                     LEVETIRACETAM   1
#                                                                                                                                                       METFORMIN HCL ER   1
#                                                                                                                                                         VALSARTAN-HYDROCHLOROTHIAZIDE   1
#                                                                                                                                                           VENTOLIN HFA   1
#                                                                                                                                                             NASONEX   1
#                                                                                                                                                               TRIAMCINOLONE ACETONIDE   1
#                                                                                                                                                                 CELEBREX   1
#                                                                                                                                                                   ALENDRONATE SODIUM   1
#                                                                                                                                                                     ACYCLOVIR   1
#                                                                                                                                                                       ZETIA   1
#                                                                                                                                                                         SOTALOL   1
#                                                                                                                                                                           LANSOPRAZOLE   1
#                                                                                                                                                                             LEVOFLOXACIN   1
#                                                                                                                                                                               NIASPAN   1
#                                                                                                                                                                                 NAPROXEN   1
#                                                                                                                                                                                   COMBIVENT RESPIMAT   1
#                                                                                                                                                                                     LOVAZA   1
#                                                                                                                                                                                       SYMBICORT   1
#                                                                                                                                                                                         INSULIN SYRINGE   1
#                                                                                                                                                                                           URSODIOL   1
#                                                                                                                                                                                             AMITIZA   1
#                                                                                                                                                                                               DEXILANT   1
#                                                                                                                                                                                                 VALACYCLOVIR   1
#                                                                                                                                                                                                   MUPIROCIN   1
#                                                                                                                                                                                                     DIPHENOXYLATE-ATROPINE   1
#                                                                                                                                                                                                       NORVIR   1
#                                                                                                                                                                                                         REYATAZ   1
#                                                                                                                                                                                                           DICYCLOMINE HCL   1
#                                                                                                                                                                                                             KETOCONAZOLE   1
#                                                                                                                                                                                                               KALETRA   1
#                                                                                                                                                                                                                 IPRATROPIUM BROMIDE   1
#                                                                                                                                                                                                                   VIREAD   1
#                                                                                                                                                                                                                     ATRIPLA   1
#                                                                                                                                                                                                                       NYSTATIN   1
#                                                                                                                                                                                                                         VOLTAREN   1
#                                                                                                                                                                                                                           TRUVADA   1
#                                                                                                                                                                                                                             HYDROCORTISONE   1
#                                                                                                                                                                                                                               EPZICOM   1
#                                                                                                                                                                                                                                 CLOBETASOL PROPIONATE   1
#                                                                                                                                                                                                                                   AMMONIUM LACTATE   1
#                                                                                                                                                                                                                                     NOVOLIN 70-30   1
#                                                                                                                                                                                                                                       LIDODERM   1
#                                                                                                                                                                                                                                         CLOTRIMAZOLE-BETAMETHASONE   1
#                                                                                                                                                                                                                                           PIOGLITAZONE HCL   1
#                                                                                                                                                                                                                                             COMBIVENT   1
#                                                                                                                                                                                                                                               LOPERAMIDE   1
#                                                                                                                                                                                                                                                 CHANTIX   1
#                                                                                                                                                                                                                                                   TRIZIVIR   1
#                                                                                                                                                                                                                                                     TESTOSTERONE CYPIONATE   1
#                                                                                                                                                                                                                                                       LAMIVUDINE   1
#                                                                                                                                                                                                                                                         ATROVENT HFA   1
#                                                                                                                                                                                                                                                           ISENTRESS   1
#                                                                                                                                                                                                                                                             IBANDRONATE SODIUM   1
#                                                                                                                                                                                                                                                               SUSTIVA   1
#                                                                                                                                                                                                                                                                 PREZISTA   1
#                                             QUETIAPINE FUMARATE   1
#                                               PREDNISONE   1
#                                                 METOPROLOL SUCCINATE   1
#                                                   LOSARTAN POTASSIUM   1
#                                                     CLOPIDOGREL   1
#                                                       CARVEDILOL   1
#                                                         FLUOXETINE HCL   1
#                                                           CRESTOR   1
#                                                             PRAVASTATIN SODIUM   1
#                                                               METFORMIN HCL   1
#                                                                 ATENOLOL   1
#                                                                   POTASSIUM CHLORIDE   1
#                                                                     WARFARIN SODIUM   1
#                                                                       SPIRONOLACTONE   1
#                                                                         VENLAFAXINE HCL ER   1
#                                                                           FLUTICASONE PROPIONATE   1
#                                                                             TRAMADOL HCL   1
#                                                                               NEXIUM   1
#                                                                                 PROPRANOLOL HCL   1
#                                                                                   OXYCODONE-ACETAMINOPHEN   1
#                                                                                     RANITIDINE HCL   1
#                                                                                       AZITHROMYCIN   1
#                                                                                         DONEPEZIL HCL   1
#                                                                                           PROAIR HFA   1
#                                                                                             ALLOPURINOL   1
#                                                                                               DIOVAN   1
#                                                                                                 BUSPIRONE HCL   1
#                                                                                                   IBUPROFEN   1
#                                                                                                     CIPROFLOXACIN HCL   1
#                                                                                                       LISINOPRIL-HYDROCHLOROTHIAZIDE   1
#                                                                                                         ADVAIR DISKUS   1
#                                                                                                           ISOSORBIDE MONONITRATE ER   1
#                                                                                                             CYCLOBENZAPRINE HCL   1
#                                                                                                               MONTELUKAST SODIUM   1
#                                                                                                                 NAMENDA   1
#                                                                                                                   FAMOTIDINE   1
#                                                                                                                     SULFAMETHOXAZOLE-TRIMETHOPRIM   1
#                                                                                                                       NIFEDIPINE ER   1
#                                                                                                                         LOSARTAN-HYDROCHLOROTHIAZIDE   1
#                                                                                                                           SPIRIVA   1
#                                                                                                                             RAMIPRIL   1
#                                                                                                                               TAMSULOSIN HCL   1
#                                                                                                                                 KLOR-CON M20   1
#                                                                                                                                   LYRICA   1
#                                                                                                                                     AMOXICILLIN   1
#                                                                                                                                       ENALAPRIL MALEATE   1
#                                                                                                                                         ROPINIROLE HCL   1
#                                                                                                                                           JANUVIA   1
#                                                                                                                                             LOVASTATIN   1
#                                                                                                                                               OXYCODONE HCL-ACETAMINOPHEN   1
#                                                                                                                                                 VERAPAMIL ER   1
#                                                                                                                                                   MELOXICAM   1
#                                                                                                                                                     AMLODIPINE BESYLATE-BENAZEPRIL   1
#                                                                                                                                                       HYDROXYZINE HCL   1
#                                                                                                                                                         DOXYCYCLINE HYCLATE   1
#                                                                                                                                                           FENOFIBRATE   1
#                                                                                                                                                             LANTUS   1
#                                                                                                                                                               LEVETIRACETAM   1
#                                                                                                                                                                 FENTANYL   1
#                                                                                                                                                                   AMIODARONE HCL   1
#                                                                                                                                                                     PRADAXA   1
#                                                                                                                                                                       METFORMIN HCL ER   1
#                                                                                                                                                                         VALSARTAN-HYDROCHLOROTHIAZIDE   1
#                                                                                                                                                                           METOCLOPRAMIDE HCL   1
#                                                                                                                                                                             OXYCONTIN   1
#                                                                                                                                                                               BACLOFEN   1
#                                                                                                                                                                                 TRIAMCINOLONE ACETONIDE   1
#                                                                                                                                                                                   GLIMEPIRIDE   1
#                                                                                                                                                                                     CELEBREX   1
#                                                                                                                                                                                       POLYETHYLENE GLYCOL 3350   1
#                                                                                                                                                                                         TORSEMIDE   1
#                                                                                                                                                                                           PRAMIPEXOLE DIHYDROCHLORIDE   1
#                                                                                                                                                                                             ALENDRONATE SODIUM   1
#                                                                                                                                                                                               DOXAZOSIN MESYLATE   1
#                                                                                                                                                                                                 LANSOPRAZOLE   1
#                                                                                                                                                                                                   DILTIAZEM HCL   1
#                                                                                                                                                                                                     CEPHALEXIN   1
#                                                                                                                                                                                                       LANTUS SOLOSTAR   1
#                                                                                                                                                                                                         NAPROXEN   1
#                                                                                                                                                                                                           GLYBURIDE   1
#                                                                                                                                                                                                             AZATHIOPRINE   1
#                                                                                                                                                                                                               MECLIZINE HCL   1
#                                                                                                                                                                                                                 JANUMET   1
#                                                                                                                                                                                                                   NIFEDICAL XL   1
#                                                                                                                                                                                                                     BUMETANIDE   1
#                                                                                                                                                                                                                       EXELON   1
#                                                                                                                                                                                                                         DIPHENOXYLATE-ATROPINE   1
#                                                                                                                                                                                                                           FINASTERIDE   1
#                                                                                                                                                                                                                             DICYCLOMINE HCL   1
#                                                                                                                                                                                                                               EVISTA   1
#                                                                                                                                                                                                                                 LEVEMIR FLEXPEN   1
#                                                                                                                                                                                                                                   IMIPRAMINE HCL   1
#                                                                                                                                                                                                                                     TRAMADOL HCL-ACETAMINOPHEN   1
#                                                                                                                                                                                                                                       BISOPROLOL-HYDROCHLOROTHIAZIDE   1
#                                                                                                                                                                                                                                         RANEXA   1
#                                                                                                                                                                                                                                           GLIPIZIDE ER   1
#                                                                                                                                                                                                                                             VERAPAMIL HCL   1
#                                                                                                                                                                                                                                               AVODART   1
#                                                                                                                                                                                                                                                 SULFASALAZINE   1
#                                                                                                                                                                                                                                                   OXYBUTYNIN CHLORIDE   1
#                                                                                                                                                                                                                                                     RIVASTIGMINE   1
#                                                                                                                                                                                                                                                       NITROFURANTOIN MONO-MACRO   1
#                                                                                                                                                                                                                                                         ELIQUIS   1
#                             ATORVASTATIN CALCIUM   1
#                               FUROSEMIDE   1
#                                 AMLODIPINE BESYLATE   1
#                                   SIMVASTATIN   1
#                                     METOPROLOL TARTRATE   1
#                                       LEVOTHYROXINE SODIUM   1
#                                         HYDROCHLOROTHIAZIDE   1
#                                           ESCITALOPRAM OXALATE   1
#                                             PREDNISONE   1
#                                               METOPROLOL SUCCINATE   1
#                                                 LOSARTAN POTASSIUM   1
#                                                   CLOPIDOGREL   1
#                                                     PANTOPRAZOLE SODIUM   1
#                                                       CARVEDILOL   1
#                                                         FLUOXETINE HCL   1
#                                                           CRESTOR   1
#                                                             PRAVASTATIN SODIUM   1
#                                                               METFORMIN HCL   1
#                                                                 ATENOLOL   1
#                                                                   PAROXETINE HCL   1
#                                                                     POTASSIUM CHLORIDE   1
#                                                                       WARFARIN SODIUM   1
#                                                                         SPIRONOLACTONE   1
#                                                                           BUPROPION XL   1
#                                                                             DIAZEPAM   1
#                                                                               FLUTICASONE PROPIONATE   1
#                                                                                 TRAMADOL HCL   1
#                                                                                   NEXIUM   1
#                                                                                     PROPRANOLOL HCL   1
#                                                                                       OXYCODONE-ACETAMINOPHEN   1
#                                                                                         RANITIDINE HCL   1
#                                                                                           TEMAZEPAM   1
#                                                                                             AZITHROMYCIN   1
#                                                                                               DONEPEZIL HCL   1
#                                                                                                 PROAIR HFA   1
#                                                                                                   ALLOPURINOL   1
#                                                                                                     DIOVAN   1
#                                                                                                       CIPROFLOXACIN HCL   1
#                                                                                                         LISINOPRIL-HYDROCHLOROTHIAZIDE   1
#                                                                                                           ADVAIR DISKUS   1
#                                                                                                             ISOSORBIDE MONONITRATE ER   1
#                                                                                                               MONTELUKAST SODIUM   1
#                                                                                                                 FAMOTIDINE   1
#                                                                                                                   SULFAMETHOXAZOLE-TRIMETHOPRIM   1
#                                                                                                                     DIGOX   1
#                                                                                                                       LOSARTAN-HYDROCHLOROTHIAZIDE   1
#                                                                                                                         SPIRIVA   1
#                                                                                                                           RAMIPRIL   1
#                                                                                                                             TAMSULOSIN HCL   1
#                                                                                                                               KLOR-CON M20   1
#                                                                                                                                 SYNTHROID   1
#                                                                                                                                   AMOXICILLIN   1
#                                                                                                                                     ENALAPRIL MALEATE   1
#                                                                                                                                       OXYCODONE HCL   1
#                                                                                                                                         JANUVIA   1
#                                                                                                                                           LOVASTATIN   1
#                                                                                                                                             OXYCODONE HCL-ACETAMINOPHEN   1
#                                                                                                                                               AMLODIPINE BESYLATE-BENAZEPRIL   1
#                                                                                                                                                 LUNESTA   1
#                                                                                                                                                   DOXYCYCLINE HYCLATE   1
# ...
#                                                                                                   VYTORIN   1
#                                                                                                     NITROGLYCERIN PATCH   1
#                                                                                                      DILTIAZEM 24HR ER   1
#                                                                                                         FLECAINIDE ACETATE   1
#               METOPROLOL TARTRATE   3
#                 HYDROCHLOROTHIAZIDE   3
#                   METOPROLOL SUCCINATE   3
#                     LOSARTAN POTASSIUM   3
#                       CLOPIDOGREL   3
#                         CARVEDILOL   3
#                           CRESTOR   2
#                             PRAVASTATIN SODIUM   1
#                               POTASSIUM CHLORIDE   1
#                                 WARFARIN SODIUM   1
#                                   ATENOLOL   1
#                                     DIOVAN   1
#                                       CLONIDINE HCL   1
#                                         ISOSORBIDE MONONITRATE ER   1
#                                           DIGOX   1
#                                             LOSARTAN-HYDROCHLOROTHIAZIDE   1
#                                               HYDRALAZINE HCL   1
#                                                 VERAPAMIL ER   1
#                                                   XARELTO   1
#                                                     PRADAXA   1
#                                                       VALSARTAN-HYDROCHLOROTHIAZIDE   1
#                                                         DILTIAZEM 24HR CD   1
#                                                           DILTIAZEM 24HR ER   1
#                                                            SIMVASTATIN   1
#                                                               KLOR-CON 10   1
#                                                                 ELIQUIS   1
#                             POTASSIUM CHLORIDE   1
#                               ATENOLOL   1
#                                 SPIRONOLACTONE   1
#                                   DIOVAN   1
#                                     ISOSORBIDE MONONITRATE ER   1
#                                       DIGOX   1
#                                         HYDRALAZINE HCL   1
#                                           AMIODARONE HCL   1
#                                             NITROSTAT   1
#                                              SIMVASTATIN   1
#                                                 NITROGLYCERIN PATCH   1
#                                                   CHLORTHALIDONE   1
#                                                     PROPAFENONE HCL   1
#                           PRAVASTATIN SODIUM   1
#                             POTASSIUM CHLORIDE   1
#                               WARFARIN SODIUM   1
#                                 ATENOLOL   1
#                                   SPIRONOLACTONE   1
#                                     DIOVAN   1
#                                       ALLOPURINOL   1
#                                         LISINOPRIL-HYDROCHLOROTHIAZIDE   1
#                                           ISOSORBIDE MONONITRATE ER   1
#                                             DIGOX   1
#                                               LOSARTAN-HYDROCHLOROTHIAZIDE   1
#                                                 HYDRALAZINE HCL   1
#                                                   VERAPAMIL ER   1
#                                                     XARELTO   1
#                                                       AMLODIPINE BESYLATE-BENAZEPRIL   1
#                                                         AMIODARONE HCL   1
#                                                           BYSTOLIC   1
#                                                             PRADAXA   1
#                                                               VALSARTAN-HYDROCHLOROTHIAZIDE   1
#                                                                 DILTIAZEM ER   1
#                                                                   QUINAPRIL HCL   1
#                                                                     DILTIAZEM 24HR ER   1
#                                                                       NITROSTAT   1
#                                                                        SIMVASTATIN   1
#                                                                           KLOR-CON 10   1
#                                                                             MULTAQ   1
#                                                                               COUMADIN   1
#                                                                                 TOPROL XL   1
#                                                                                   VYTORIN   1
#                                                                                     EFFIENT   1
#           AMLODIPINE BESYLATE   2
#             METOPROLOL TARTRATE   1
#               METOPROLOL SUCCINATE   1
#                 PRAVASTATIN SODIUM   1
#             SIMVASTATIN   1
#               LEVOTHYROXINE SODIUM   1
#                 LOSARTAN POTASSIUM   1
#                   CARVEDILOL   1
#                     METFORMIN HCL   1
#                       CRESTOR   1
#                         PRAVASTATIN SODIUM   1
#                           RAMIPRIL   1
#                             SYNTHROID   1
#                               JANUVIA   1
#                                 FENOFIBRATE   1
#                                   LANTUS   1
#                                     GLIPIZIDE   1
#                                       METFORMIN HCL ER   1
#                                         BD ULTRA-FINE PEN NEEDLE   1
#                                           NOVOLOG FLEXPEN   1
#                                             LOVAZA   1
#                                               LANTUS SOLOSTAR   1
#                                                 INSULIN SYRINGE   1
#                                                   NIASPAN   1
#                                                     JANUMET   1
#                                                       NOVOLOG   1
#                                                         HYDROCORTISONE   1
#                                                           TRADJENTA   1
#                                                             METHIMAZOLE   1
#                                                               PIOGLITAZONE HCL   1
#                                                                 LIPITOR   1
#           SIMVASTATIN   2
#             METOPROLOL TARTRATE   1
#               METOPROLOL SUCCINATE   1
#                 CLOPIDOGREL   1
#                   CARVEDILOL   1
#                     BUPROPION XL   1
#                       FLUTICASONE PROPIONATE   1
#                        CEPHALEXIN   1
#                           BD ULTRA-FINE PEN NEEDLE   1
#                             NIASPAN   1
#             LEVOTHYROXINE SODIUM   1
#               METFORMIN HCL   1
#                 CRESTOR   1
#                   SYNTHROID   1
#                     JANUVIA   1
#                       LANTUS   1
#                         GLIPIZIDE   1
#                           METFORMIN HCL ER   1
#                             GLIMEPIRIDE   1
#                               ALENDRONATE SODIUM   1
#                                 BD ULTRA-FINE PEN NEEDLE   1
#                                   NOVOLOG FLEXPEN   1
#                                     LANTUS SOLOSTAR   1
#                                       INSULIN SYRINGE   1
#                                         NOVOLOG   1
#                                           TRADJENTA   1
#                                             METHIMAZOLE   1
#                                               NOVOLIN 70-30   1
#                                                 LEVEMIR   1
#                                                   TESTOSTERONE CYPIONATE   1
#         FUROSEMIDE   1
#           AMLODIPINE BESYLATE   1
#             SIMVASTATIN   1
#               METOPROLOL TARTRATE   1
#                 HYDROCHLOROTHIAZIDE   1
#                   METOPROLOL SUCCINATE   1
#                     LOSARTAN POTASSIUM   1
#                       CLOPIDOGREL   1
#                         PANTOPRAZOLE SODIUM   1
#                           CARVEDILOL   1
#                             PRAVASTATIN SODIUM   1
#                               WARFARIN SODIUM   1
#                                 ATENOLOL   1
#                                   SPIRONOLACTONE   1
#                                     ISOSORBIDE MONONITRATE ER   1
#                                       DIGOX   1
#                                        CEPHALEXIN   1
#                                           DIGOXIN   1
#                                             AMIODARONE HCL   1
#                                               PRADAXA   1
#                                                 DILTIAZEM HCL   1
#                                                   DILTIAZEM 24HR ER   1
#                                                     NADOLOL   1
#                                                       MUPIROCIN   1
#                                                         VERAPAMIL HCL   1
#                                                           FLECAINIDE ACETATE   1
#         PANTOPRAZOLE SODIUM   1
#          SIMVASTATIN   1
#         LEVOTHYROXINE SODIUM   1
#           METFORMIN HCL   1
#             AZITHROMYCIN   1
#               LISINOPRIL-HYDROCHLOROTHIAZIDE   1
#                 DIOVAN HCT   1
#         PREDNISONE   1
#          CEPHALEXIN   1
#       QUETIAPINE FUMARATE   1
#       ATORVASTATIN CALCIUM   1
#      HYDROCODONE-ACETAMINOPHEN   1
#       CYMBALTA   1
#         OMEPRAZOLE   1
#           LISINOPRIL   1
#             ATORVASTATIN CALCIUM   1
#               FUROSEMIDE   1
#                 AMLODIPINE BESYLATE   1
#                   SIMVASTATIN   1
#                     LEVOTHYROXINE SODIUM   1
#                       HYDROCHLOROTHIAZIDE   1
#                         ESCITALOPRAM OXALATE   1
#                           LOSARTAN POTASSIUM   1
#                             CLOPIDOGREL   1
#                               CARVEDILOL   1
#                                 CRESTOR   1
#                                   POTASSIUM CHLORIDE   1
#                                     SPIRONOLACTONE   1
#                                       DONEPEZIL HCL   1
#                                         CIPROFLOXACIN HCL   1
#                                           RAMIPRIL   1
#                                             VERAPAMIL ER   1
#                                               XARELTO   1
#                                                 DOXYCYCLINE HYCLATE   1
#                                                   NIASPAN   1
#                                                     LABETALOL HCL   1
#       SERTRALINE HCL   1
#         OMEPRAZOLE   1
#           FUROSEMIDE   1
#             PANTOPRAZOLE SODIUM   1
#               AMITRIPTYLINE HCL   1
#                 SPIRONOLACTONE   1
#                   NEXIUM   1
#                     RANITIDINE HCL   1
#                       AMLODIPINE BESYLATE-BENAZEPRIL   1
#                         POLYETHYLENE GLYCOL 3350   1
#                           METOCLOPRAMIDE HCL   1
#                             LANSOPRAZOLE   1
#                               AMITIZA   1
#                                 NADOLOL   1
#                                   DEXILANT   1
#                                     URSODIOL   1
#                                       DIPHENOXYLATE-ATROPINE   1
#                                         LACTULOSE   1
#                                           VIREAD   1
#                                             ASACOL HD   1
#                                               MOVIPREP   1
#                                                 BALSALAZIDE DISODIUM   1
#                                                  PEG-3350 WITH FLAVOR PACKS   1
#                                                     PEG-3350 AND ELECTROLYTES   1
#                                                       GAVILYTE-G   1
#                                                         SUPREP   1
#       METOPROLOL SUCCINATE   1
#      LEVOFLOXACIN   1
#       CYCLOBENZAPRINE HCL   1
#         DOXEPIN HCL   1
#           BACLOFEN   1
#             TIZANIDINE HCL   1
#               METHOCARBAMOL   1
#                GABAPENTIN   1
#                   SUMATRIPTAN SUCCINATE   1
#       ESTRADIOL   1
#         EVISTA   1
#           PREMARIN   1
#       CLONAZEPAM   2
#         LAMOTRIGINE   1
#           BUPROPION HCL SR   1
#             TEMAZEPAM   1
#         QUETIAPINE FUMARATE   1
#           PAROXETINE HCL   1
#             EFFEXOR XR   1
#       FLUTICASONE PROPIONATE   1
#         METHYLPREDNISOLONE   1
#          OMEPRAZOLE   1
#             IPRATROPIUM BROMIDE   1
#       HYDROXYZINE HCL   1
#         TRIAMCINOLONE ACETONIDE   1
#           KETOCONAZOLE   1
#             FLUOCINONIDE   1
#               CLOBETASOL PROPIONATE   1
#                 DESONIDE   1
#       SOTALOL   1
#       FLUCONAZOLE   1
#         PREMARIN   1
#       CITALOPRAM HBR   2
#         OMEPRAZOLE   2
#           METOPROLOL SUCCINATE   1
#           LISINOPRIL   1
#             AMLODIPINE BESYLATE   1
#               SIMVASTATIN   1
#                 LEVOTHYROXINE SODIUM   1
#                   METOPROLOL TARTRATE   1
#                     HYDROCHLOROTHIAZIDE   1
#                       LOSARTAN POTASSIUM   1
#                         PREDNISONE   1
#                           METFORMIN HCL   1
#                             CRESTOR   1
#                               PAROXETINE HCL   1
#                                 SPIRONOLACTONE   1
#                                   FLUTICASONE PROPIONATE   1
#                                     TRAMADOL HCL   1
#                                       RANITIDINE HCL   1
#                                         DONEPEZIL HCL   1
#                                           PROAIR HFA   1
#                                             CIPROFLOXACIN HCL   1
#                                               LISINOPRIL-HYDROCHLOROTHIAZIDE   1
#                                                 MONTELUKAST SODIUM   1
#                                                   SULFAMETHOXAZOLE-TRIMETHOPRIM   1
#                                                     AMOXICILLIN   1
#                                                       ROPINIROLE HCL   1
#                                                         VENTOLIN HFA   1
#                                                           GLIMEPIRIDE   1
#                                                             TRIAMTERENE-HYDROCHLOROTHIAZID   1
#                                                              FLUOXETINE HCL   1
#       ONDANSETRON HCL   1
#         DEXAMETHASONE   1
#       MONTELUKAST SODIUM   1
#        CEPHALEXIN   1
#           ACYCLOVIR   1
#             VALACYCLOVIR   1
#               ATRIPLA   1
#                 TRUVADA   1
#                   NORVIR   1
#                     KALETRA   1
#                       REYATAZ   1
#                         VIREAD   1
#                           EPZICOM   1
#                             VANCOMYCIN HCL   1
#                               INVANZ   1
#                                 LAMIVUDINE   1
#                                   SUSTIVA   1
#       TRIAMCINOLONE ACETONIDE   1
#         METRONIDAZOLE   1
#           MUPIROCIN   1
#             AMMONIUM LACTATE   1
#               FLUOCINONIDE   1
#                 CLOBETASOL PROPIONATE   1
#                   DESONIDE   1
#       PENICILLIN V POTASSIUM   2
#        HYDROCODONE-ACETAMINOPHEN   1
#       TRAZODONE HCL   2
#         BUSPIRONE HCL   1
#         ESCITALOPRAM OXALATE   1
#           QUETIAPINE FUMARATE   1
#             DONEPEZIL HCL   1
#               NAMENDA   1
#       FUROSEMIDE   1
#         PREDNISONE   1
#           SPIRONOLACTONE   1
#             AZITHROMYCIN   1
#               PROAIR HFA   1
#                 MONTELUKAST SODIUM   1
#                   SPIRIVA   1
#                     FLUCONAZOLE   1
#                       QVAR   1
#                        ADVAIR DISKUS   1

# %%
def ascendTree(leafNode, prefixPath): #ascends from leaf node to root
    if leafNode.parent != None:
        prefixPath.append(leafNode.name)
        ascendTree(leafNode.parent, prefixPath)

# %%
def findPrefixPath(basePat, treeNode): #treeNode comes from header table
    condPats = {}
    while treeNode != None:
        prefixPath = []
        ascendTree(treeNode, prefixPath)
        if len(prefixPath) > 1: 
            condPats[frozenset(prefixPath[1:])] = treeNode.count
        treeNode = treeNode.nodeLink
    return condPats

# %%
findPrefixPath('AMOXICILLIN', myHeaderTab['AMOXICILLIN'][1])
# Out:
# {frozenset({' HYDROCODONE-ACETAMINOPHEN', ' OXYCODONE-ACETAMINOPHEN'}): 1,
#  frozenset({' IBUPROFEN'}): 3,
#  frozenset({' HYDROCODONE-ACETAMINOPHEN'}): 6}

# %%
{frozenset({'AMOXICILLIN'}): 3}
findPrefixPath('AMOXICILLIN', myHeaderTab['AMOXICILLIN'][1])
# Out:
# {frozenset({' HYDROCODONE-ACETAMINOPHEN', ' OXYCODONE-ACETAMINOPHEN'}): 1,
#  frozenset({' IBUPROFEN'}): 3,
#  frozenset({' HYDROCODONE-ACETAMINOPHEN'}): 6}

# %% [markdown]
# ### Topic Modelling
# > When looking at word counts in a natural language corpus, a similar power law pattern to the one seen above in the drug frequency emerges. A common exploratory technique used in the analysis of language is topic modelling, which refers to the unsupervised identification of topics, or groups of related words, in text. Latent Dirichlet Allocation (LDA) is one such model.

# %%
data_json = pd.read_json('/kaggle/input/prescriptionbasedprediction/roam_prescription_based_prediction.jsonl', lines=True)

# %% [markdown]
# > Ignoring rows corresponding to specialties with fewer than 50 records and those for which there are fewer than 50 unique drugs prescribed.

# %%
data_json.head()
# Out:
#                              cms_prescription_counts  \
# 0  {'DOXAZOSIN MESYLATE': 26, 'MIDODRINE HCL': 12...
# 1  {'CEPHALEXIN': 23, 'AMOXICILLIN': 52, 'HYDROCO...
# 2  {'CEPHALEXIN': 28, 'AMOXICILLIN': 73, 'CLINDAM...
# 3                                {'AMOXICILLIN': 63}
# 4  {'PIOGLITAZONE HCL': 24, 'BENAZEPRIL HCL': 29,...
#
#                                   provider_variables         npi
# 0  {'settlement_type': 'non-urban', 'generic_rx_c...  1295763035
# 1  {'settlement_type': 'non-urban', 'generic_rx_c...  1992715205
# 2  {'settlement_type': 'non-urban', 'generic_rx_c...  1578587630
# 3  {'settlement_type': 'non-urban', 'generic_rx_c...  1932278405
# 4  {'settlement_type': 'non-urban', 'generic_rx_c...  1437366804

# %% [markdown]
# ### Data Preprocessing
# * Extracting Medications from Json bound csv.
# * Filter out rows for providers with <50 unique prescribed drugs. Then, remove providers that correspond to specialties with <50 providers in the filtered dataset.

# %%
data = data_json[data_json.cms_prescription_counts.apply(lambda x: len(x.keys())) >= 50]
specialty_counts = Counter(data_json.provider_variables.apply(lambda x: x['specialty']))
specialties_to_ignore = set(
    specialty for specialty, _ in filter(lambda x: x[1] < 50, specialty_counts.items()))
data = data_json[data_json.provider_variables.apply(lambda x: x['specialty'] not in specialties_to_ignore)]
data.head()
# Out:
#                              cms_prescription_counts  \
# 0  {'DOXAZOSIN MESYLATE': 26, 'MIDODRINE HCL': 12...
# 1  {'CEPHALEXIN': 23, 'AMOXICILLIN': 52, 'HYDROCO...
# 2  {'CEPHALEXIN': 28, 'AMOXICILLIN': 73, 'CLINDAM...
# 3                                {'AMOXICILLIN': 63}
# 4  {'PIOGLITAZONE HCL': 24, 'BENAZEPRIL HCL': 29,...
#
#                                   provider_variables         npi
# 0  {'settlement_type': 'non-urban', 'generic_rx_c...  1295763035
# 1  {'settlement_type': 'non-urban', 'generic_rx_c...  1992715205
# 2  {'settlement_type': 'non-urban', 'generic_rx_c...  1578587630
# 3  {'settlement_type': 'non-urban', 'generic_rx_c...  1932278405
# 4  {'settlement_type': 'non-urban', 'generic_rx_c...  1437366804

# %% [markdown]
# > Transform prescription count column into sparse matrix.

# %%
vectorizer = DictVectorizer(sparse=True)
X = vectorizer.fit_transform(data.cms_prescription_counts)

# %%
top_n_drugs = 15
top_n = 500
values = np.array(X.sum(axis=0))[0]
sort_order = np.argsort(values)[::-1][:top_n]
top_drugs_df = pd.DataFrame({
    'Drug Name': np.array(vectorizer.feature_names_)[sort_order[:top_n_drugs]],
    'Count': list(map(int, values[sort_order[:top_n_drugs]]))
})
top_drugs_df['Proportion of All Prescriptions'] = top_drugs_df['Count'] / values.sum()
top_drugs_df['Cumulative Proportion of All Prescriptions'] = \
    top_drugs_df['Proportion of All Prescriptions'].cumsum()
top_drugs_df
# Out:
#                     Drug Name    Count  Proportion of All Prescriptions  \
# 0                  LISINOPRIL  5729022                         0.024693
# 1   HYDROCODONE-ACETAMINOPHEN  5710110                         0.024612
# 2         AMLODIPINE BESYLATE  5449497                         0.023488
# 3                  OMEPRAZOLE  5153955                         0.022214
# 4                 SIMVASTATIN  4902841                         0.021132
# 5                  FUROSEMIDE  4698444                         0.020251
# 6        ATORVASTATIN CALCIUM  4523598                         0.019498
# 7        LEVOTHYROXINE SODIUM  4370769                         0.018839
# 8                  GABAPENTIN  3992260                         0.017207
# 9         METOPROLOL TARTRATE  3852483                         0.016605
# 10                CLOPIDOGREL  3478055                         0.014991
# 11       METOPROLOL SUCCINATE  3429140                         0.014780
# 12                 CARVEDILOL  3255538                         0.014032
# 13            WARFARIN SODIUM  3142389                         0.013544
# 14                 CLONAZEPAM  2998484                         0.012924
#
#     Cumulative Proportion of All Prescriptions
# 0                                     0.024693
# 1                                     0.049305
# 2                                     0.072793
# 3                                     0.095008
# 4                                     0.116140
# 5                                     0.136391
# 6                                     0.155888
# 7                                     0.174727
# 8                                     0.191934
# 9                                     0.208539
# 10                                    0.223530
# 11                                    0.238311
# 12                                    0.252343
# 13                                    0.265887
# 14                                    0.278811

# %%
drug_correlations = np.corrcoef(X.todense(), rowvar=False)
np.fill_diagonal(drug_correlations, 0)
drug_correlations = np.triu(drug_correlations)

# %%
unique_provider_counts = np.array((X > 0).sum(axis=0))[0]
correlated_pairs = zip(*(drug_correlations > .85).nonzero())
pd.DataFrame(
    sorted([
        (vectorizer.feature_names_[i], vectorizer.feature_names_[j], drug_correlations[i, j],
         unique_provider_counts[i], unique_provider_counts[j])
        for i, j in correlated_pairs
        if unique_provider_counts[i] > 1 and unique_provider_counts[j] > 1],
        key=lambda x: x[2], reverse=True),
    columns=['Drug 1', 'Drug 2', 'Correlation', 'Drug 1 Provider Count', 'Drug 2 Provider Count'])
# Out:
#                         Drug 1           Drug 2  Correlation  \
# 0                       NORVIR         PREZISTA     0.954613
# 1                       NORVIR          TRUVADA     0.948239
# 2                   JENTADUETO         ULTICARE     0.922101
# 3                       NORVIR          REYATAZ     0.918318
# 4                     PREZISTA          TRUVADA     0.909870
# 5                    ISENTRESS          TRUVADA     0.908878
# 6                   NEPHROCAPS      TRIPHROCAPS     0.907011
# 7              DOXORUBICIN HCL     VINCASAR PFS     0.893974
# 8                      DUREZOL           ILEVRO     0.893869
# 9                    ISENTRESS           NORVIR     0.886815
# 10                     REYATAZ          TRUVADA     0.879831
# 11                   TYPHIM VI           YF-VAX     0.874115
# 12                   ISENTRESS         PREZISTA     0.873458
# 13                      HAVRIX           YF-VAX     0.871385
# 14                     EPZICOM           NORVIR     0.868015
# 15    BD ULTRA-FINE PEN NEEDLE  LANTUS SOLOSTAR     0.865969
# 16  HYDROXYCHLOROQUINE SULFATE     METHOTREXATE     0.865459
# 17                     RENVELA         SENSIPAR     0.863290
# 18                   COSOPT PF          ZIOPTAN     0.858162
# 19                        IPOL        TYPHIM VI     0.851989
# 20               BOOSTRIX TDAP         ZOSTAVAX     0.851631
#
#     Drug 1 Provider Count  Drug 2 Provider Count
# 0                    2646                   2050
# 1                    2646                   2671
# 2                     149                    449
# 3                    2646                   2003
# 4                    2050                   2671
# 5                    2250                   2671
# 6                      14                     50
# 7                       3                      2
# 8                      46                      5
# 9                    2250                   2646
# 10                   2003                   2671
# 11                     11                     11
# 12                   2250                   2050
# 13                     14                     11
# 14                   1529                   2646
# 15                   9797                  12420
# 16                   5049                   5563
# 17                   5853                   5967
# 18                      4                      5
# 19                      4                     11
# 20                     80                   1483

# %% [markdown]
# > Fit LDA model fixing k at 50.

# %%
# %%time
lda = LatentDirichletAllocation(n_components=50, random_state=523)
lda.fit(X)
# Out:
# CPU times: user 1h 12min 32s, sys: 37min 53s, total: 1h 50min 25s
# Wall time: 53min 22s
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=50, n_jobs=None,
#                           perp_tol=0.1, random_state=523, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %% [markdown]
# > Save Persisted Model

# %%
with open('/kaggle/working/my_dumped_classifier.pkl', 'wb') as fid:
    pickle.dump(lda, fid)    

# load it again
with open('/kaggle/working/my_dumped_classifier.pkl', 'rb') as fid:
    model_loaded = pickle.load(fid)

# %%
p_w = np.array(X.sum(axis=0))[0] / X.sum()

def relevance(phi_kw, lambda_=.6):
    """Given a topic vector (probability of each drug given the topic) return a
    relevance score vector."""
    return lambda_ * np.log(phi_kw) + (1 - lambda_) * np.log (phi_kw / p_w)

# %% [markdown]
# > Extract the distribution over drugs for each topic, apply the relevance weighting above and show the top N drugs for each topic

# %%
def lda_summary_df(lda, top_n_drugs=3, **kwargs):
    topic_term_distribution = lda.components_ / lda.components_.sum(axis=1)[:, np.newaxis]
    rows = []
    for i in range(lda.n_components):
        top_term_indices = np.argsort(
            relevance(topic_term_distribution[i], **kwargs))[::-1][:top_n_drugs]
        rows.append(np.array(vectorizer.feature_names_)[top_term_indices])
    top_drugs_per_topic = pd.DataFrame(rows)
    top_drugs_per_topic.index = map(lambda x: 'Topic {}'.format(x), range(lda.n_components))
    top_drugs_per_topic.columns = map(lambda x: 'Drug #{}'.format(x+1), range(top_n_drugs))
    return top_drugs_per_topic

# %%
lda_summary = lda_summary_df(lda)
lda_summary
# Out:
#                             Drug #1                         Drug #2  \
# Topic 0                  GABAPENTIN                  TIZANIDINE HCL
# Topic 1                 LAMOTRIGINE                         ABILIFY
# Topic 2                METHOTREXATE      HYDROXYCHLOROQUINE SULFATE
# Topic 3                   IBUPROFEN                 NAPROXEN SODIUM
# Topic 4                     RENVELA                        SENSIPAR
# Topic 5              RANITIDINE HCL                      OMEPRAZOLE
# Topic 6   PEG-3350 AND ELECTROLYTES                      TACROLIMUS
# Topic 7                AZITHROMYCIN               CIPROFLOXACIN HCL
# Topic 8          CARBIDOPA-LEVODOPA           CARBIDOPA-LEVODOPA ER
# Topic 9               OXYCODONE HCL             MORPHINE SULFATE ER
# Topic 10                  MELOXICAM  LISINOPRIL-HYDROCHLOROTHIAZIDE
# Topic 11                 OMEPRAZOLE             PANTOPRAZOLE SODIUM
# Topic 12  HYDROCODONE-ACETAMINOPHEN         OXYCODONE-ACETAMINOPHEN
# Topic 13                 LISINOPRIL                   METFORMIN HCL
# Topic 14                  SYNTHROID            LEVOTHYROXINE SODIUM
# Topic 15   BD ULTRA-FINE PEN NEEDLE                 LANTUS SOLOSTAR
# Topic 16             SERTRALINE HCL                  CITALOPRAM HBR
# Topic 17       BENZTROPINE MESYLATE                     RISPERIDONE
# Topic 18               KETOCONAZOLE           CLOBETASOL PROPIONATE
# Topic 19                    SPIRIVA                   ADVAIR DISKUS
# Topic 20                  MODAFINIL             METHYLPHENIDATE HCL
# Topic 21                   SUBOXONE                  VANCOMYCIN HCL
# Topic 22            WARFARIN SODIUM                      FUROSEMIDE
# Topic 23                     LOVAZA                         CRESTOR
# Topic 24              LEVETIRACETAM                   DONEPEZIL HCL
# Topic 25                    NAMENDA                   DONEPEZIL HCL
# Topic 26                 OMEPRAZOLE                   TRAZODONE HCL
# Topic 27                     NORVIR                         TRUVADA
# Topic 28                  ESTRADIOL                        PREMARIN
# Topic 29            WARFARIN SODIUM            METOPROLOL SUCCINATE
# Topic 30               BUPROPION XL            ESCITALOPRAM OXALATE
# Topic 31              DEXAMETHASONE        PROCHLORPERAZINE MALEATE
# Topic 32                ANASTROZOLE                       LETROZOLE
# Topic 33                CLOPIDOGREL            ATORVASTATIN CALCIUM
# Topic 34                SIMVASTATIN              LOSARTAN POTASSIUM
# Topic 35               CARISOPRODOL                        BACLOFEN
# Topic 36          ECONAZOLE NITRATE                      CICLOPIROX
# Topic 37                  LORAZEPAM                        FENTANYL
# Topic 38                 CEPHALEXIN           ACETAMINOPHEN-CODEINE
# Topic 39           AMMONIUM LACTATE                        VOLTAREN
# Topic 40     FLUTICASONE PROPIONATE                  AZELASTINE HCL
# Topic 41                 ALPRAZOLAM               ZOLPIDEM TARTRATE
# Topic 42        METOPROLOL TARTRATE                      CARVEDILOL
# Topic 43                AMOXICILLIN         CHLORHEXIDINE GLUCONATE
# Topic 44                  LACTULOSE               ALBUTEROL SULFATE
# Topic 45        AMLODIPINE BESYLATE                   NIFEDIPINE ER
# Topic 46              BUSPIRONE HCL               NORTRIPTYLINE HCL
# Topic 47             TAMSULOSIN HCL                     FINASTERIDE
# Topic 48       ATORVASTATIN CALCIUM                    KLOR-CON M20
# Topic 49                MIRTAZAPINE                   DONEPEZIL HCL
#
#                                 Drug #3
# Topic 0                          LYRICA
# Topic 1                   TRAZODONE HCL
# Topic 2                      PREDNISONE
# Topic 3                 SODIUM FLUORIDE
# Topic 4                      CALCITRIOL
# Topic 5                          NEXIUM
# Topic 6                      GAVILYTE-G
# Topic 7   SULFAMETHOXAZOLE-TRIMETHOPRIM
# Topic 8     PRAMIPEXOLE DIHYDROCHLORIDE
# Topic 9     OXYCODONE HCL-ACETAMINOPHEN
# Topic 10             POTASSIUM CHLORIDE
# Topic 11                         NEXIUM
# Topic 12                   TRAMADOL HCL
# Topic 13            HYDROCHLOROTHIAZIDE
# Topic 14            LIOTHYRONINE SODIUM
# Topic 15                        HUMALOG
# Topic 16                  TRAZODONE HCL
# Topic 17                     OLANZAPINE
# Topic 18        TRIAMCINOLONE ACETONIDE
# Topic 19                      SYMBICORT
# Topic 20                       COPAXONE
# Topic 21                SODIUM CHLORIDE
# Topic 22          IPRATROPIUM-ALBUTEROL
# Topic 23                         NEXIUM
# Topic 24                     TOPIRAMATE
# Topic 25           LEVOTHYROXINE SODIUM
# Topic 26                 CITALOPRAM HBR
# Topic 27                      ISENTRESS
# Topic 28                        VAGIFEM
# Topic 29                       RAMIPRIL
# Topic 30             VENLAFAXINE HCL ER
# Topic 31                ONDANSETRON HCL
# Topic 32              TAMOXIFEN CITRATE
# Topic 33                     CARVEDILOL
# Topic 34                       ATENOLOL
# Topic 35               PROMETHAZINE HCL
# Topic 36  AMOX TR-POTASSIUM CLAVULANATE
# Topic 37        OXYCODONE-ACETAMINOPHEN
# Topic 38                     CILOSTAZOL
# Topic 39                   CLOTRIMAZOLE
# Topic 40                        NASONEX
# Topic 41                     CLONAZEPAM
# Topic 42                     LISINOPRIL
# Topic 43                CLINDAMYCIN HCL
# Topic 44       POLYETHYLENE GLYCOL 3350
# Topic 45                     FUROSEMIDE
# Topic 46                 PAROXETINE HCL
# Topic 47                    LATANOPROST
# Topic 48                  ADVAIR DISKUS
# Topic 49                        NAMENDA

# %% [markdown]
# > Display the most prevalent topics found in the dataset measured by the mean probability assigned to that topic across all rows

# %%
# %%time
provider_topic_matrix = lda.transform(X)
topic_prevalence = provider_topic_matrix.mean(axis=0)
topic_order = np.argsort(topic_prevalence)[::-1]
lda_topic_prevalence = pd.DataFrame(
    dict(Topic=topic_order, Prevalence=topic_prevalence[topic_order]))
lda_topic_prevalence['Top 3 Drugs from Topic'] = \
    lda_topic_prevalence.Topic.apply(lambda x: ', '.join(lda_summary.iloc[x]))
lda_topic_prevalence
# Out:
# CPU times: user 5min 27s, sys: 3min 19s, total: 8min 47s
# Wall time: 3min 46s
#     Topic  Prevalence                             Top 3 Drugs from Topic
# 0      43    0.186959  AMOXICILLIN, CHLORHEXIDINE GLUCONATE, CLINDAMY...
# 1      12    0.084670  HYDROCODONE-ACETAMINOPHEN, OXYCODONE-ACETAMINO...
# 2      13    0.047117     LISINOPRIL, METFORMIN HCL, HYDROCHLOROTHIAZIDE
# 3       1    0.040478                LAMOTRIGINE, ABILIFY, TRAZODONE HCL
# 4      11    0.040173            OMEPRAZOLE, PANTOPRAZOLE SODIUM, NEXIUM
# 5      42    0.037058        METOPROLOL TARTRATE, CARVEDILOL, LISINOPRIL
# 6       7    0.029358  AZITHROMYCIN, CIPROFLOXACIN HCL, SULFAMETHOXAZ...
# 7      33    0.025570      CLOPIDOGREL, ATORVASTATIN CALCIUM, CARVEDILOL
# 8      17    0.023899      BENZTROPINE MESYLATE, RISPERIDONE, OLANZAPINE
# 9      38    0.023169      CEPHALEXIN, ACETAMINOPHEN-CODEINE, CILOSTAZOL
# 10     41    0.021485          ALPRAZOLAM, ZOLPIDEM TARTRATE, CLONAZEPAM
# 11      9    0.020730  OXYCODONE HCL, MORPHINE SULFATE ER, OXYCODONE ...
# 12      4    0.019996                      RENVELA, SENSIPAR, CALCITRIOL
# 13     30    0.019963  BUPROPION XL, ESCITALOPRAM OXALATE, VENLAFAXIN...
# 14     24    0.019828           LEVETIRACETAM, DONEPEZIL HCL, TOPIRAMATE
# 15     19    0.019506                  SPIRIVA, ADVAIR DISKUS, SYMBICORT
# 16     28    0.018731                       ESTRADIOL, PREMARIN, VAGIFEM
# 17      0    0.017303                 GABAPENTIN, TIZANIDINE HCL, LYRICA
# 18      2    0.017021  METHOTREXATE, HYDROXYCHLOROQUINE SULFATE, PRED...
# 19     31    0.016967  DEXAMETHASONE, PROCHLORPERAZINE MALEATE, ONDAN...
# 20     15    0.016621  BD ULTRA-FINE PEN NEEDLE, LANTUS SOLOSTAR, HUM...
# 21     45    0.016276     AMLODIPINE BESYLATE, NIFEDIPINE ER, FUROSEMIDE
# 22     29    0.015895    WARFARIN SODIUM, METOPROLOL SUCCINATE, RAMIPRIL
# 23     34    0.013354          SIMVASTATIN, LOSARTAN POTASSIUM, ATENOLOL
# 24     32    0.013300          ANASTROZOLE, LETROZOLE, TAMOXIFEN CITRATE
# 25     49    0.012414                MIRTAZAPINE, DONEPEZIL HCL, NAMENDA
# 26     14    0.011978  SYNTHROID, LEVOTHYROXINE SODIUM, LIOTHYRONINE ...
# 27      3    0.011869        IBUPROFEN, NAPROXEN SODIUM, SODIUM FLUORIDE
# 28     18    0.011605  KETOCONAZOLE, CLOBETASOL PROPIONATE, TRIAMCINO...
# 29     47    0.010789           TAMSULOSIN HCL, FINASTERIDE, LATANOPROST
# 30     40    0.010086    FLUTICASONE PROPIONATE, AZELASTINE HCL, NASONEX
# 31     10    0.009961  MELOXICAM, LISINOPRIL-HYDROCHLOROTHIAZIDE, POT...
# 32     39    0.009952           AMMONIUM LACTATE, VOLTAREN, CLOTRIMAZOLE
# 33     36    0.008836  ECONAZOLE NITRATE, CICLOPIROX, AMOX TR-POTASSI...
# 34     27    0.008327                         NORVIR, TRUVADA, ISENTRESS
# 35     26    0.008013          OMEPRAZOLE, TRAZODONE HCL, CITALOPRAM HBR
# 36     48    0.007667  ATORVASTATIN CALCIUM, KLOR-CON M20, ADVAIR DISKUS
# 37      8    0.007414  CARBIDOPA-LEVODOPA, CARBIDOPA-LEVODOPA ER, PRA...
# 38     37    0.007150       LORAZEPAM, FENTANYL, OXYCODONE-ACETAMINOPHEN
# 39     16    0.007033      SERTRALINE HCL, CITALOPRAM HBR, TRAZODONE HCL
# 40     23    0.006424                            LOVAZA, CRESTOR, NEXIUM
# 41      6    0.006183  PEG-3350 AND ELECTROLYTES, TACROLIMUS, GAVILYTE-G
# 42     20    0.005965           MODAFINIL, METHYLPHENIDATE HCL, COPAXONE
# 43     22    0.005888  WARFARIN SODIUM, FUROSEMIDE, IPRATROPIUM-ALBUT...
# 44      5    0.005419                 RANITIDINE HCL, OMEPRAZOLE, NEXIUM
# 45     35    0.005169           CARISOPRODOL, BACLOFEN, PROMETHAZINE HCL
# 46     21    0.005028          SUBOXONE, VANCOMYCIN HCL, SODIUM CHLORIDE
# 47     46    0.004374   BUSPIRONE HCL, NORTRIPTYLINE HCL, PAROXETINE HCL
# 48     25    0.004131       NAMENDA, DONEPEZIL HCL, LEVOTHYROXINE SODIUM
# 49     44    0.002898  LACTULOSE, ALBUTEROL SULFATE, POLYETHYLENE GLY...

# %% [markdown]
# ## END
