# %% [markdown]
# # Predict Heart Disease

# %% [markdown]
# ## Introduction - Problem Statement

# %% [markdown]
# Coronary heart disease (CHD) is the most common type of heart disease nearly 35% US population undergo this disease. About 47% of sudden cardiac deaths occur outside a hospital. This suggests that many people with heart disease don’t act on early warning signs. In this notebook we build a machine learning model that will classify patients who undergo it.

# %% [markdown]
# <h3> About Dataset</h3>

# %% [markdown]
# Dataset holds 35% of people suffered from Heart Disease. And time window is considered before onset of the diagnosis and the entire previous history of records.

# %% [markdown]
# <h3>Type of Features considered:</h3>
#
# 1)	Demographics - It contains patient level demographic data such as Age, Race and Gender etc
#
# 2)	Diagnosis - It contains data about the several conditions the patient has been diagnosed with
#
# 3)	Observations - It contains lab measurement details of the patients
#
# 4)	Prescriptions - It contains drug details administered to the patients

# %% [markdown]
# #### Import Packages

# %%
#Packages that are needed to run the notebook
import time
import re
import random
import scipy
import json
import collections 
import psycopg2
import math
import pandas as pd
import numpy as np
import plotly
import datetime as DT
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import scipy.stats as stats
import plotly.plotly as py
import plotly.tools as tls
import seaborn as sns
import statsmodels
import statsmodels.api as sm
import matplotlib
import os
import pickle
import warnings
warnings.filterwarnings("ignore")
from datetime import timedelta
from sqlalchemy import create_engine
from datetime import timedelta
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from IPython.display import display, HTML
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, confusion_matrix,roc_auc_score, recall_score, precision_score, accuracy_score
from sklearn.preprocessing import label_binarize,StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from sklearn import svm
import matplotlib.pyplot as plt
import seaborn as se
import lightgbm as lgm
from smart_open import smart_open
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# Data Preprocessing is done by using Modularization module 1 and stored it in S3 bucket

# %%
# %%time
bucket = 'bucket-name'
object_key_data = 'file-path/usecasedatahd.csv'
path_data = 'S3://{}:{}@{}/{}'.format('XXXXXXXXXXXXXXX', 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX', bucket, object_key_data)
data = pd.read_csv(smart_open(path_data))
# Out:
# CPU times: user 3.37 s, sys: 437 ms, total: 3.81 s
# Wall time: 3.98 s

# %% [markdown]
# <h5>Encode methods</h5>

# %%
def label_encode(data, col_name):
    encode = LabelEncoder()
    data[col_name] = encode.fit_transform(data[col_name].astype('str'))
    return data


def one_hot_encode(data, col_name):
    dummies = pd.get_dummies(data[col_name], prefix = col_name)
    data = pd.concat([data, dummies], axis=1)
    del data[col_name]
    return data

# %% [markdown]
# Remove empty spaces in column names and perform encoding on top of categorical columns

# %%
print("Shape of the dataset ",data.shape)

data.columns = data.columns.str.replace(' ', '_')
col_dtypes_list = list(data.select_dtypes(include=['object']).columns)
for c_name_rd in col_dtypes_list:
    data[c_name_rd] = data[c_name_rd].str.replace(' ', '_')
for c_name in col_dtypes_list:
    if data[c_name].nunique()==2:
        data = label_encode(data, c_name)
    else:
        data = one_hot_encode(data, c_name)
final_data = data.drop(columns=['target'],axis=1)
final_data['target'] = data['target']
# Out:
# Shape of the dataset  (49018, 364)

# %% [markdown]
# <h5>Feature Scaling</h5>

# %%
def Scaling(dataframe,functionName):

    if(functionName == "standardScaler"):
        scaler = StandardScaler() 

    elif(functionName == "minMaxScaler"):
        scaler = MinMaxScaler() 

    elif(functionName == "maxAbsScaler"):
        scaler = MaxAbsScaler() 

    elif(functionName == "normalizer"):
        scaler = Normalizer() 

    elif(functionName == "robustScaler"):
        scaler = RobustScaler()
        

    features_columns = list(dataframe.columns[:-1])
    dataframe[features_columns] = scaler.fit_transform(dataframe[features_columns])
    return dataframe

feature_sel_name = input("Please enter Feature Scaling name:")
final_data = Scaling(final_data, feature_sel_name)
# Out:
# Please enter Feature Scaling name:standardScaler

# %% [markdown]
# <h5>Feature Selection</h5>

# %% [markdown]
# In this usecase, feature selection is performed using LightGBM. It is a gradient boosting framework that uses tree based learning algorithm and it grows tree vertically.

# %% [markdown]
# The parameters tweaked are<br>
# <li><b>max_depth</b>- 15, Lower max depth taken to handle model overfitting</li>
# <li><b>learning_rate</b> - 0.1, Small learning rate considered for better accuracy</li>
# <li><b>num_leaves</b>    - 900, To deal with overfitting</li>
# <li><b>n_estimators</b> - 100, the number of trees to be used in the forest</li>

# %%
def lightGBM(dataframe,Number):
    target = dataframe.columns[-1]

    x= dataframe.drop([target],axis=1)
    y= dataframe.filter([target], axis=1)

    y[target] = y[target].astype(int)

    data = lgm.Dataset(x,label=y)
    params = {"max_depth":15, "learning_rate":0.1, "num_leaves":900, "n_estimators":100}
    lgm_model = lgm.train(params=params, train_set=data, categorical_feature='auto')

    this = list(lgm_model.feature_importance())
    effe_cols = []
    for i in this:           
        if i != -1:
            effe_cols.append(lgm_model.feature_name()[this.index(i)])
            this[this.index(i)]=-1

    d = pd.DataFrame({'Score':this,'Features':effe_cols})
    selected_cols = d.sort_values(by=['Score'],ascending=False).head(Number)['Features'].tolist()
    selected_cols.append('target')
    print("Number of Features after LightGBM "+str(len(selected_cols)))
    return selected_cols


final_data = final_data[lightGBM(final_data,10)]
# Out:
# Number of Features after LightGBM 11

# %% [markdown]
# Based on the Feature importance score and after performing several iterations the final dataframe in which machine learning models are applied have top 10 features and column description are given below

# %% [raw]
# 1)  AGE = Person's Age
# 2)  72011-0 = VR-12 Social functioning (SF) score - oblique method
# 3)  72096-1 = Symptoms score [HOOS]
# 4)  72095-3 = Activities of daily living score [HOOS]
# 5)  72094-6 = Sport-recreation score [HOOS]
# 6)  72093-8 = Quality of life score [HOOS]
# 7)  72016-9 = VR-12 Physical functioning (PF) score - oblique method
# 8)  72015-1 = VR-12 Role physical (RP) score - oblique method
# 9)  72014-4 = VR-12 Bodily pain (BP) score - oblique method
# 10) 72013-6 = VR-12 General health (GH) score - oblique method

# %% [markdown]
# <h4>Data Analysis</h4>

# %%
final_data0 = final_data[final_data['target']==0][['age','72011-0','72096-1','72095-3','72094-6','72093-8','72016-9','72015-1','72014-4','72013-6']]
final_data0.plot(kind='density', subplots=True, layout=(3,4), sharex=False,figsize=(35,10))
plt.subplots_adjust(bottom=0.05)
text="The chart shows the densities of selected observation features for Non Heart Disease patients"
plt.figtext(0.05,0.00, text, fontsize=22, va="top", ha="left")
plt.show()

# %%
final_data1 = final_data[final_data['target']==1][['age','72011-0','72096-1','72095-3','72094-6','72093-8','72016-9','72015-1','72014-4','72013-6']]
final_data1.plot(kind='density', subplots=True, layout=(3,4), sharex=False,figsize=(35,10))
plt.subplots_adjust(bottom=0.05)
text="The chart shows the densities of selected observation features for Heart Disease patients"
plt.figtext(0.05,0.00, text, fontsize=22, va="top", ha="left")
plt.show()

# %% [markdown]
# <h5>Train Test Split</h5>

# %%
def split_train_test(df):
    labels = df['target'].values
    features = df.drop(['target'], axis=1).values
    print("Enter the test set split size else press <enter> to move on. It takes default as 0.3")
    test_ss = input()
    if len(test_ss)!=0:
        train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = float(test_ss), random_state = 1)
        train_test=[train_features, test_features, train_labels, test_labels]
    else:
        train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.3, random_state = 1)
        train_test=[train_features, test_features, train_labels, test_labels]
    return train_test

data_list = split_train_test(final_data)
# Out:
# Enter the test set split size else press <enter> to move on. It takes default as 0.3
# 0.3

# %% [markdown]
# <h5>Model Building</h5>

# %%
# Model
lr = LogisticRegression()
model_list = []
model_list.append(('LR',lr))

# %% [markdown]
# This function is to evaluate perfomance of algorithm on a base level. The outputs of this function are the model metrics

# %%
def compare_models(data_list):
    from matplotlib.pyplot import figure
    modelname = []
    modelaccuracy = []
    model_roc_auc_score = []
    figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
    train_features = data_list[0]
    test_features = data_list[1]
    train_labels = data_list[2]
    test_labels = data_list[3]
        
    for model_name,select_model in model_list:
        fit_model = select_model.fit(train_features,train_labels)
        model_predict = fit_model.predict(test_features)
        # Predict Probability
        probability_1 = select_model.predict_proba(test_features)[:,1]
        probability_0 = select_model.predict_proba(test_features)[:,0]
        p1_gt90 = [p90 for p90 in probability_1 if p90 >= .9]
        p0_gt90 = [p90 for p90 in probability_0 if p90 >= .9]
        model_accuracy = round(accuracy_score(test_labels,model_predict),2)
        model_recall = round(recall_score(test_labels,model_predict),2)
        model_precision = round(precision_score(test_labels,model_predict),2)
        roc_auc_score_model = round(roc_auc_score(test_labels,probability_1),2)
        model_msg = "%s %f %f" % (model_name, model_accuracy, roc_auc_score_model)
        model_confu = confusion_matrix(test_labels,model_predict)
        modelname.append(model_name)
        modelaccuracy.append(model_accuracy)
        model_roc_auc_score.append(roc_auc_score_model)
        test_labels_binary = label_binarize(test_labels, classes=[0,1])  
        fpr, tpr, threshold = roc_curve(test_labels_binary, probability_1)
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label = (model_name, round(roc_auc,2)))
        plt.legend(loc='upper left')
        #print(model_name+' Acc: '+str(model_accuracy)+' AUC: '+str(roc_auc_score_model) +' Recall: '+str(model_recall)+' Precision: '+str(model_precision)+' FPR: '+str(round(fpr[1],2)) + ' TPR: '+str(round(tpr[1],2)))
        print (('Acc: %r' % model_accuracy)+ (' AUC: %r' % roc_auc_score_model ) + (' Recall: %r' % model_recall ) + (' Precision: %r' % model_precision ))
        print ('TN , FP \nFN, TP')
        print (model_confu)
        model_lr = os.path.join(os.path.pardir,'HeartDisease','lr.pkl')
        model_pickle_lr = open(model_lr,'wb')
        pickle.dump(fit_model,model_pickle_lr)
        model_pickle_lr.close()
        
compare_models(data_list)
# Out:
# Acc: 0.7 AUC: 0.71 Recall: 0.46 Precision: 0.61
# TN , FP
# FN, TP
# [[7850 1555]
#  [2849 2452]]

# %% [markdown]
# <h4>Probability Prediction</h4>

# %%
#Function to perform probability prediction
def probability_prediction(trn_ft,tst_ft,trn_lbl,tst_lbl):
    train_features = trn_ft
    test_features = tst_ft
    train_labels = trn_lbl
    test_labels = tst_lbl  
    fit_model = lr.fit(train_features,train_labels)
    model_predict = fit_model.predict(test_features)
    probability_1 = lr.predict_proba(test_features)[:,1]
    probability_0 = lr.predict_proba(test_features)[:,0]
    p1_gt50 = [p50 for p50 in probability_1 if p50 >= .5]
    p0_gt50 = [p50 for p50 in probability_0 if p50 >= .5]
    p1_gt60 = [p60 for p60 in probability_1 if p60 >= .6]
    p0_gt60 = [p60 for p60 in probability_0 if p60 >= .6]
    p1_gt70 = [p70 for p70 in probability_1 if p70 >= .7]
    p0_gt70 = [p70 for p70 in probability_0 if p70 >= .7]
    print("Number of patients having 50% probability of predicting having Heart Disease: ", len(p1_gt50))
    print("Number of patients having 50% probability of predicting doesn't having Heart Disease: ", len(p0_gt50))
    print("Number of patients having 60% probability of predicting having Heart Disease: ", len(p1_gt60))
    print("Number of patients having 60% probability of predicting doesn't having Heart Disease: ", len(p0_gt60))
    print("Number of patients having 70% probability of predicting having Heart Disease: ", len(p1_gt70))
    print("Number of patients having 70% probability of predicting doesn't having Heart Disease: ", len(p0_gt70))
    ckd_per = ['50%','60%','70%']
    ckd_val = [len(p1_gt50),len(p1_gt60),len(p1_gt70)]
    ckd_set = {'Probability':ckd_per,'count':ckd_val}
    ckd_df = pd.DataFrame(ckd_set)
    se.barplot(x=ckd_df['Probability'],y=ckd_df['count'])
    plt.title('Heart Disease Probability')
        
probability_prediction(data_list[0],data_list[1],data_list[2],data_list[3])
# Out:
# Number of patients having 50% probability of predicting having Heart Disease:  4007
# Number of patients having 50% probability of predicting doesn't having Heart Disease:  10699
# Number of patients having 60% probability of predicting having Heart Disease:  2304
# Number of patients having 60% probability of predicting doesn't having Heart Disease:  9427
# Number of patients having 70% probability of predicting having Heart Disease:  344
# Number of patients having 70% probability of predicting doesn't having Heart Disease:  8428

# %% [markdown]
# # END
